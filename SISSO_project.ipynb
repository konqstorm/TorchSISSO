# %% [markdown]
# # Код с результатами

# %%
# %%writefile script.py
# ============================================================
# SISSO for /content/dataset_new_amo.dat  (amo + charge)
# CV5 on TRAIN (80%) -> best n_term  |  Hold-out TEST (20%)
# Saves: amo_sisso_report.txt, amo_holdout_predictions.csv,
#        amo_rmse_comparison.png, amo_parity_validation.png
# ============================================================
from src.TorchSisso import SissoModel
import sys, subprocess, importlib, re, time, gc
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
torch.set_num_threads(1)
from sklearn.model_selection import train_test_split, KFold


# ---------- 1) Load AMO dataset ----------
DATA_PATH = Path("train.dat")
if not DATA_PATH.exists():
    raise FileNotFoundError(f"Файл не найден: {DATA_PATH}")

# пробельный разделитель, игнорируем строки с '#'
new_amo_ch = pd.read_csv(DATA_PATH, delim_whitespace=True, comment="#")
print("Загружено:", new_amo_ch.shape)
#display(new_amo_ch.head(3))


# ---------- 2) Target rename + numeric-only ----------
new_amo_ch = new_amo_ch.rename(columns={'Energy_Adsorption': 'Eads'})
if "Eads" not in new_amo_ch.columns:
    raise ValueError("Не найден целевой столбец 'Eads'.")

num_cols = new_amo_ch.select_dtypes(include=["number"]).columns.tolist()
if "Eads" not in num_cols:
    new_amo_ch["Eads"] = pd.to_numeric(new_amo_ch["Eads"], errors="coerce")
    num_cols = new_amo_ch.select_dtypes(include=["number"]).columns.tolist()
    if "Eads" not in num_cols:
        raise ValueError("'Eads' не числовая и не приводится к числу.")

feature_cols = [c for c in num_cols if c != "Eads"]
df_amo_num = new_amo_ch[["Eads"] + feature_cols].copy().dropna().astype("float32")
print(f"Численных фич: {len(feature_cols)} | строк: {len(df_amo_num)}")
#display(df_amo_num.head(3))


# ---------- 3) Hyperparams ----------
FAST = False            # первый стабильный прогон; потом можно False
SEED = 42
FOLDS = 5
FOLD_TIMEOUT_SEC = 300

safe_ops = ['+','-','*','/','pow(2)','abs']   # устойчивые операторы

if FAST:
    operators   = safe_ops
    N_EXPANSION = 2         # Tier=2 (быстрее)
    K_SUBSPACE  = 8
    N_TERMS_GRID = (1, 2)   # перебор размерности дескриптора
else:
    operators   = safe_ops  # можно добавить 'sqrt','ln','exp' позже
    N_EXPANSION = 3
    K_SUBSPACE  = 10
    N_TERMS_GRID = (1, 2, 3)

USE_GPU = False


# ---------- 4) Metrics & utilities ----------
def rmse(y_true, y_pred):
    y_true = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()
    return float(np.sqrt(np.mean((y_pred - y_true) ** 2)))

def mae(y_true, y_pred):
    y_true = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()
    return float(np.mean(np.abs(y_pred - y_true)))

def r2_score(y_true, y_pred):
    y_true = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()
    ss_res = np.sum((y_true - y_pred)**2)
    ss_tot = np.sum((y_true - np.mean(y_true))**2)
    return 1 - ss_res/ss_tot

# парсинг строки уравнения в выражение (в этой версии нет sm.predict)
def _transform_equation(eq: str) -> str:
    expr = eq.strip()
    expr = re.sub(r'pow\(\s*2\s*\)\s*\(\s*([^)]+?)\s*\)', r'(\1)**2', expr)
    expr = re.sub(r'pow\(\s*3\s*\)\s*\(\s*([^)]+?)\s*\)', r'(\1)**3', expr)
    expr = re.sub(r'\^([23])', r'**\1', expr)
    return expr

def predict_from_equation(equation: str, X_df: pd.DataFrame) -> np.ndarray:
    expr = _transform_equation(equation)
    ns = {c: X_df[c].to_numpy() for c in X_df.columns}
    ns.update({'abs': np.abs, 'np': np})
    y = eval(expr, {"__builtins__": {}}, ns)
    return np.asarray(y, dtype=float).ravel()

# подстройщик конструктора для разных версий пакета
def make_sisso_model(df: pd.DataFrame, **kwargs):
    for key in ("dataframe","df","data","dataset"):
        try:
            return SissoModel(**{key: df}, **kwargs)
        except TypeError:
            pass
    return SissoModel(df, **kwargs)


# ---------- 5) Split: CV только на TRAIN (80%), TEST = 20% ----------
train_idx, val_idx = train_test_split(
    np.arange(len(df_amo_num)), test_size=0.20, random_state=SEED, shuffle=True
)
df_train = df_amo_num.iloc[train_idx].reset_index(drop=True)
df_val   = df_amo_num.iloc[val_idx].reset_index(drop=True)

class TimeoutException(Exception): pass

def cv_rmse_for_nterm_on_train(df_tr_all: pd.DataFrame, n_term: int, folds: int = 5, seed: int = 42):
    kf = KFold(n_splits=folds, shuffle=True, random_state=seed)
    ys = df_tr_all["Eads"].to_numpy()
    Xs = df_tr_all.drop(columns=["Eads"])
    cols = Xs.columns.tolist()
    Xs = Xs.to_numpy()
    rmses = []
    for i, (tr, te) in enumerate(kf.split(Xs), 1):
        df_tr = pd.DataFrame(np.column_stack([ys[tr], Xs[tr]]), columns=["Eads"] + cols)
        df_te = pd.DataFrame(np.column_stack([ys[te],  Xs[te]]), columns=["Eads"] + cols)

        try:
            sm = make_sisso_model(
                df_tr,
                operators=operators,
                n_expansion=N_EXPANSION,
                n_term=n_term,
                k=K_SUBSPACE,
                use_gpu=USE_GPU
            )
            rmse_tr, eq, r2_tr, _ = sm.fit()
            y_pred = predict_from_equation(eq, df_te.drop(columns=["Eads"]))
            rmses.append(rmse(df_te["Eads"].to_numpy(), y_pred))
        except TimeoutException:
            print(f"[CV{folds} n_term={n_term}] Fold {i} — TIMEOUT ({FOLD_TIMEOUT_SEC}s)")
            rmses.append(np.nan)
        finally:
            del sm; gc.collect()
    rmses = np.array(rmses, dtype=float)
    rmses = rmses[~np.isnan(rmses)]
    if len(rmses) == 0: return np.array([np.inf])
    return rmses

def main():
    # --- CV5 на TRAIN для выбора n_term ---
    cv_summary = []
    for n_term in N_TERMS_GRID:
        scores = cv_rmse_for_nterm_on_train(df_train, n_term, folds=FOLDS, seed=SEED)
        cv_summary.append((n_term, scores.mean(), scores.std(), scores))
        print(f"CV{FOLDS} (TRAIN) n_term={n_term}: RMSE {scores.mean():.5f} ± {scores.std():.5f} | folds={np.round(scores,5)}")

    cv_summary.sort(key=lambda x: x[1])
    best_n_term, cv_mean, cv_std, cv_all = cv_summary[0]
    print(f"\nЛучший n_term по CV{FOLDS} на TRAIN: {best_n_term} (mean RMSE={cv_mean:.5f} ± {cv_std:.5f})")


    # ---------- 6) Full-fit на ВСЕХ данных ----------
    sm_full = make_sisso_model(
        df_amo_num,
        operators=operators,
        n_expansion=N_EXPANSION,
        n_term=best_n_term,
        k=K_SUBSPACE,
        use_gpu=USE_GPU
    )
    rmse_full_fit, eq_full, r2_full_rep, _ = sm_full.fit()
    y_full_pred = predict_from_equation(eq_full, df_amo_num.drop(columns=["Eads"]))
    overall_rmse = rmse(df_amo_num["Eads"].to_numpy(), y_full_pred)
    overall_mae  = mae(df_amo_num["Eads"].to_numpy(), y_full_pred)
    overall_r2   = r2_score(df_amo_num["Eads"].to_numpy(), y_full_pred)

    print("\n=== Full-fit on ALL (AMO) ===")
    print("Equation:", eq_full)
    print(f"RMSE={overall_rmse:.5f} | MAE={overall_mae:.5f} | R²={overall_r2:.5f}")


    # ---------- 7) Hold-out TEST (20%) ----------
    sm_hold = make_sisso_model(
        df_train,
        operators=operators,
        n_expansion=N_EXPANSION,
        n_term=best_n_term,
        k=K_SUBSPACE,
        use_gpu=USE_GPU
    )
    rmse_tr_hold, eq_hold, r2_tr_hold, _ = sm_hold.fit()

    X_val = df_val.drop(columns=["Eads"])
    y_val_true = df_val["Eads"].to_numpy()
    y_val_pred = predict_from_equation(eq_hold, X_val)

    val_rmse = rmse(y_val_true, y_val_pred)
    val_mae  = mae(y_val_true, y_val_pred)
    val_r2   = r2_score(y_val_true, y_val_pred)

    print("\n=== Hold-out (20%) — AMO ===")
    print("Equation (trained on 80%):", eq_hold)
    print(f"Train RMSE (80%)={rmse_tr_hold:.5f}")
    print(f"Val  RMSE (20%)={val_rmse:.5f} | MAE={val_mae:.5f} | R²={val_r2:.5f}")


    # # ---------- 8) Save predictions & plots ----------
    # # CSV с тестовыми предсказаниями
    # holdout_df = pd.DataFrame({
    #     "Eads_true": y_val_true,
    #     "Eads_pred": y_val_pred,
    # })
    # holdout_df["residual"]  = holdout_df["Eads_pred"] - holdout_df["Eads_true"]
    # holdout_df["abs_error"] = np.abs(holdout_df["residual"])
    # holdout_df.to_csv("amo_holdout_predictions.csv", index=False)
    # print("Saved: amo_holdout_predictions.csv")

    # # RMSE bar
    # labels = ["Overall (train full)", f"CV{FOLDS} mean (train)", "Validation (20%)"]
    # values = [overall_rmse, cv_mean, val_rmse]
    # plt.figure(figsize=(5,4))
    # plt.bar(labels, values)
    # plt.ylabel("RMSE")
    # plt.title("AMO — RMSE comparison")
    # plt.tight_layout()
    # plt.savefig("amo_rmse_comparison.png", dpi=150)
    # plt.show()

    # # Parity plot (validation)
    # plt.figure(figsize=(5,5))
    # plt.scatter(y_val_true, y_val_pred, s=28)
    # mn, mx = float(np.min(y_val_true)), float(np.max(y_val_true))
    # plt.plot([mn, mx], [mn, mx], linestyle="--")
    # plt.xlabel("True Eads (validation)")
    # plt.ylabel("Predicted Eads (validation)")
    # plt.title("AMO — Parity (validation)")
    # plt.tight_layout()
    # plt.savefig("amo_parity_validation.png", dpi=150)
    # plt.show()

if __name__ == "__main__":
    main()
# Out:
# Overwriting script.py

# %%
import pstats
import cProfile

cProfile.run('main()', 'stats')

p = pstats.Stats('stats')
p.strip_dirs().sort_stats("cumulative").print_stats()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1158 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.0189516544342041  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2770994 ************************************************
#
# ************************************************ Time taken to create the space is::: 26.44432520866394  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  20.883999*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.30250298976898193
#
#
# RMSE:  0.24504461884498596
# R2:: 0.8580718553952363
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.15857148170471191  seconds ************************************************
#
#
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1085 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.016977548599243164  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2450362 ************************************************
#
# ************************************************ Time taken to create the space is::: 21.17774486541748  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  19.326754*((Avg_Adsorption_100/AEL)/(AWF-AELA))+0.5350741147994995
#
#
# RMSE:  0.22869430482387543
# R2:: 0.8858199603324397
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.13663554191589355  seconds ************************************************
#
#
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.017979145050048828  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2778102 ************************************************
#
# ************************************************ Time taken to create the space is::: 22.599605560302734  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  19.46924*((Avg_Adsorption_100/AEL)/(AWF-AELA))+0.55195152759552
#
#
# RMSE:  0.2510540783405304
# R2:: 0.8650454406300917
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.16755175590515137  seconds ************************************************
#
#
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1158 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.015956640243530273  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2770994 ************************************************
#
# ************************************************ Time taken to create the space is::: 22.184711933135986  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.505205*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.3454514741897583
#
#
# RMSE:  0.2486587017774582
# R2:: 0.8612208890914677
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.14461231231689453  seconds ************************************************
#
#
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.016954898834228516  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2779261 ************************************************
#
# ************************************************ Time taken to create the space is::: 22.27746343612671  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.761202*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.37832772731781006
#
#
# RMSE:  0.25953200459480286
# R2:: 0.8570175003000908
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.15755009651184082  seconds ************************************************
#
#
#
# CV5 (TRAIN) n_term=1: RMSE 0.24917 ± 0.03871 | folds=[0.25813 0.31328 0.23666 0.2445  0.19328]
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1158 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.01698160171508789  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2770994 ************************************************
#
# ************************************************ Time taken to create the space is::: 22.15091347694397  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  20.883997*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.30250275135040283
#
#
# RMSE:  0.24504461884498596
# R2:: 0.8580718442361939
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.17552971839904785  seconds ************************************************
#
#
#
# 1 term in the equation is 19.3957309723*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.0075734900*((Pt+Avg_Adsorption_111)*(Avg_Mass*Avg_Charge))
#
#
# Equation:   + 19.3957309723*((Avg_Adsorption_100/AEL)/(AWF-AELA))   + 0.0075734900*((Pt+Avg_Adsorption_111)*(Avg_Mass*Avg_Charge))  +0.551714777946472
#
#
# RMSE: 0.21699795126914978
#
#
# R2:: 0.8887014516932196
# ************************************************ Time taken for 2 dimension is:  0.24434781074523926  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1085 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.014966011047363281  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2450362 ************************************************
#
# ************************************************ Time taken to create the space is::: 20.010493278503418  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  19.326754*((Avg_Adsorption_100/AEL)/(AWF-AELA))+0.5350741147994995
#
#
# RMSE:  0.22869430482387543
# R2:: 0.8858199603324397
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.14060020446777344  seconds ************************************************
#
#
#
# 1 term in the equation is 20.8877201080*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -0.9140128493*((Ag+Avg_Charge)*(Ir-Avg_Charge))
#
#
# Equation:   + 20.8877201080*((Avg_Adsorption_111/AEL)/(AWF-AELA))  -0.9140128493*((Ag+Avg_Charge)*(Ir-Avg_Charge))  +0.31057393550872
#
#
# RMSE: 0.20251785218715668
#
#
# R2:: 0.9104622613147948
# ************************************************ Time taken for 2 dimension is:  0.16456103324890137  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.015964269638061523  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2778102 ************************************************
#
# ************************************************ Time taken to create the space is::: 22.35923981666565  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  19.46924*((Avg_Adsorption_100/AEL)/(AWF-AELA))+0.55195152759552
#
#
# RMSE:  0.2510540783405304
# R2:: 0.8650454406300917
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.15161871910095215  seconds ************************************************
#
#
#
# 1 term in the equation is 20.0809669495*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.4898503125*((Pt-Avg_Charge)/(AELA-CN3))
#
#
# Equation:   + 20.0809669495*((Avg_Adsorption_100/AEL)/(AWF-AELA))   + 0.4898503125*((Pt-Avg_Charge)/(AELA-CN3))  +0.598031640052795
#
#
# RMSE: 0.21931952238082886
#
#
# R2:: 0.8970070307634639
# ************************************************ Time taken for 2 dimension is:  0.15658974647521973  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1158 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.015961170196533203  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2770994 ************************************************
#
# ************************************************ Time taken to create the space is::: 22.257490634918213  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.505205*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.3454514741897583
#
#
# RMSE:  0.2486587017774582
# R2:: 0.8612208890914677
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.16755247116088867  seconds ************************************************
#
#
#
# 1 term in the equation is 20.5986595154*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -1.8766607046*((Ag+Avg_Charge)*(Ir/Site_Type))
#
#
# Equation:   + 20.5986595154*((Avg_Adsorption_111/AEL)/(AWF-AELA))  -1.8766607046*((Ag+Avg_Charge)*(Ir/Site_Type))  +0.295948386192321
#
#
# RMSE: 0.2198803871870041
#
#
# R2:: 0.8914849962981803
# ************************************************ Time taken for 2 dimension is:  0.15659785270690918  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.014987945556640625  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2779261 ************************************************
#
# ************************************************ Time taken to create the space is::: 22.341691493988037  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.761202*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.37832772731781006
#
#
# RMSE:  0.25953200459480286
# R2:: 0.8570175003000908
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.18448376655578613  seconds ************************************************
#
#
#
# 1 term in the equation is 22.0065708160*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -0.4475705326*((Ag+Pt)*(Ir-Avg_Charge))
#
#
# Equation:   + 22.0065708160*((Avg_Adsorption_111/AEL)/(AWF-AELA))  -0.4475705326*((Ag+Pt)*(Ir-Avg_Charge))  +0.407145857810974
#
#
# RMSE: 0.2277199923992157
#
#
# R2:: 0.8899212650434449
# ************************************************ Time taken for 2 dimension is:  0.21143507957458496  seconds ************************************************
#
# CV5 (TRAIN) n_term=2: RMSE 0.25424 ± 0.02073 | folds=[0.25621 0.29238 0.25034 0.23921 0.23304]
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1158 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.016954898834228516  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2770994 ************************************************
#
# ************************************************ Time taken to create the space is::: 23.003522157669067  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  20.883997*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.30250275135040283
#
#
# RMSE:  0.24504461884498596
# R2:: 0.8580718442361939
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.145582914352417  seconds ************************************************
#
#
#
# 1 term in the equation is 19.3957309723*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.0075734900*((Pt+Avg_Adsorption_111)*(Avg_Mass*Avg_Charge))
#
#
# Equation:   + 19.3957309723*((Avg_Adsorption_100/AEL)/(AWF-AELA))   + 0.0075734900*((Pt+Avg_Adsorption_111)*(Avg_Mass*Avg_Charge))  +0.551714777946472
#
#
# RMSE: 0.21699795126914978
#
#
# R2:: 0.8887014516932196
# ************************************************ Time taken for 2 dimension is:  0.1545867919921875  seconds ************************************************
#
# 1 term in the equation is 19.8089294434*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.0075068236*((Pt+Avg_Adsorption_111)*(Avg_Mass*Avg_Charge))
#
#
# 3 term in the equation is 0.0270760097*((Ag+Au)*(TotEl*Avg_Adsorption_111))
#
#
# Equation:   + 19.8089294434*((Avg_Adsorption_100/AEL)/(AWF-AELA))   + 0.0075068236*((Pt+Avg_Adsorption_111)*(Avg_Mass*Avg_Charge))   + 0.0270760097*((Ag+Au)*(TotEl*Avg_Adsorption_111))  +0.630342364311218
#
#
# RMSE: 0.20053337514400482
#
#
# R2:: 0.9049501222049053
# ************************************************ Time taken for 3 dimension is:  0.1835336685180664  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1085 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.01396322250366211  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2450362 ************************************************
#
# ************************************************ Time taken to create the space is::: 19.436058044433594  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  19.32675*((Avg_Adsorption_100/AEL)/(AWF-AELA))+0.5350738763809204
#
#
# RMSE:  0.22869430482387543
# R2:: 0.8858199603324397
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.135636568069458  seconds ************************************************
#
#
#
# 1 term in the equation is 20.8877201080*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -0.9140128493*((Ag+Avg_Charge)*(Ir-Avg_Charge))
#
#
# Equation:   + 20.8877201080*((Avg_Adsorption_111/AEL)/(AWF-AELA))  -0.9140128493*((Ag+Avg_Charge)*(Ir-Avg_Charge))  +0.31057393550872
#
#
# RMSE: 0.20251785218715668
#
#
# R2:: 0.9104622613147948
# ************************************************ Time taken for 2 dimension is:  0.13364243507385254  seconds ************************************************
#
# 1 term in the equation is 18.2752628326*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -2.2493004799*((Ag+Avg_Charge)*(Ir/Site_Type))
#
#
# 3 term in the equation is 0.4340414703*((Ag-Ru)*(Au-Rh))
#
#
# Equation:   + 18.2752628326*((Avg_Adsorption_100/AEL)/(AWF-AELA))  -2.2493004799*((Ag+Avg_Charge)*(Ir/Site_Type))   + 0.4340414703*((Ag-Ru)*(Au-Rh))  +0.458639502525329
#
#
# RMSE: 0.18078920245170593
#
#
# R2:: 0.9286449889402805
# ************************************************ Time taken for 3 dimension is:  0.17056775093078613  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.016954898834228516  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2778102 ************************************************
#
# ************************************************ Time taken to create the space is::: 22.228594541549683  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  19.46924*((Avg_Adsorption_100/AEL)/(AWF-AELA))+0.55195152759552
#
#
# RMSE:  0.2510540783405304
# R2:: 0.8650454406300917
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.1526176929473877  seconds ************************************************
#
#
#
# 1 term in the equation is 20.0809669495*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.4898503125*((Pt-Avg_Charge)/(AELA-CN3))
#
#
# Equation:   + 20.0809669495*((Avg_Adsorption_100/AEL)/(AWF-AELA))   + 0.4898503125*((Pt-Avg_Charge)/(AELA-CN3))  +0.598031640052795
#
#
# RMSE: 0.21931952238082886
#
#
# R2:: 0.8970070307634639
# ************************************************ Time taken for 2 dimension is:  0.15857911109924316  seconds ************************************************
#
# 1 term in the equation is 20.4529209137*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.0563836768*((Pt-Avg_Charge)*(ACN-CN3))
#
#
# 3 term in the equation is 0.5263875127*((Ag+Avg_Charge)*(Au+Avg_Adsorption_111))
#
#
# Equation:   + 20.4529209137*((Avg_Adsorption_100/AEL)/(AWF-AELA))   + 0.0563836768*((Pt-Avg_Charge)*(ACN-CN3))   + 0.5263875127*((Ag+Avg_Charge)*(Au+Avg_Adsorption_111))  +0.649054884910583
#
#
# RMSE: 0.19387812912464142
#
#
# R2:: 0.9195157898892465
# ************************************************ Time taken for 3 dimension is:  0.17752623558044434  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1158 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.016962289810180664  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2770994 ************************************************
#
# ************************************************ Time taken to create the space is::: 22.206951379776  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.505198*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.3454505205154419
#
#
# RMSE:  0.2486587017774582
# R2:: 0.8612208890914677
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.1685488224029541  seconds ************************************************
#
#
#
# 1 term in the equation is 20.5986595154*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -1.8766607046*((Ag+Avg_Charge)*(Ir/Site_Type))
#
#
# Equation:   + 20.5986595154*((Avg_Adsorption_111/AEL)/(AWF-AELA))  -1.8766607046*((Ag+Avg_Charge)*(Ir/Site_Type))  +0.295948386192321
#
#
# RMSE: 0.2198803871870041
#
#
# R2:: 0.8914849962981803
# ************************************************ Time taken for 2 dimension is:  0.16455984115600586  seconds ************************************************
#
# 1 term in the equation is 21.0440387726*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.1093154848*((Ir+Avg_Adsorption_111)*(Rh+ADBND))
#
#
# 3 term in the equation is 1.8155090809*((Au*Avg_Charge)/(AWF-CN2))
#
#
# Equation:   + 21.0440387726*((Avg_Adsorption_111/AEL)/(AWF-AELA))   + 0.1093154848*((Ir+Avg_Adsorption_111)*(Rh+ADBND))   + 1.8155090809*((Au*Avg_Charge)/(AWF-CN2))  +0.1248898506164550
#
#
# RMSE: 0.2029220014810562
#
#
# R2:: 0.907578069782239
# ************************************************ Time taken for 3 dimension is:  0.18849587440490723  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.018949508666992188  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2779261 ************************************************
#
# ************************************************ Time taken to create the space is::: 22.750202178955078  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.761202*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.37832772731781006
#
#
# RMSE:  0.25953200459480286
# R2:: 0.8570175003000908
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.16455936431884766  seconds ************************************************
#
#
#
# 1 term in the equation is 22.0065708160*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -0.4475705326*((Ag+Pt)*(Ir-Avg_Charge))
#
#
# Equation:   + 22.0065708160*((Avg_Adsorption_111/AEL)/(AWF-AELA))  -0.4475705326*((Ag+Pt)*(Ir-Avg_Charge))  +0.407145857810974
#
#
# RMSE: 0.2277199923992157
#
#
# R2:: 0.8899212650434449
# ************************************************ Time taken for 2 dimension is:  0.17351460456848145  seconds ************************************************
#
# 1 term in the equation is 20.7431793213*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -0.3634297848*((Ag+Pt)*(Ir-Avg_Charge))
#
#
# 3 term in the equation is 0.4815897346*((Pt-Avg_Charge)/(AELA+CN3))
#
#
# Equation:   + 20.7431793213*((Avg_Adsorption_100/AEL)/(AWF-AELA))  -0.3634297848*((Ag+Pt)*(Ir-Avg_Charge))   + 0.4815897346*((Pt-Avg_Charge)/(AELA+CN3))  +0.649430632591247
#
#
# RMSE: 0.2062908113002777
#
#
# R2:: 0.9096640002241949
# ************************************************ Time taken for 3 dimension is:  0.18650126457214355  seconds ************************************************
#
# CV5 (TRAIN) n_term=3: RMSE 0.28088 ± 0.06291 | folds=[0.25609 0.29214 0.22782 0.39788 0.23047]
#
# Лучший n_term по CV5 на TRAIN: 1 (mean RMSE=0.24917 ± 0.03871)
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.022937536239624023  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2778102 ************************************************
#
# ************************************************ Time taken to create the space is::: 57.7912495136261  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  20.627613*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.28339684009552
#
#
# RMSE:  0.2495686113834381
# R2:: 0.8634717057854383
#
#
# ************************************************ Time taken to generate one dimensional equation:  3.513416290283203  seconds ************************************************
#
#
#
#
# === Full-fit on ALL (AMO) ===
# Equation: 20.627613*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.28339684009552
# RMSE=0.24957 | MAE=0.19634 | R²=0.86347
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 8.041882276535034  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2778102 ************************************************
#
# ************************************************ Time taken to create the space is::: 29.13475775718689  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.278851*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.3356212377548218
#
#
# RMSE:  0.24741581082344055
# R2:: 0.8651618214716765
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.23399090766906738  seconds ************************************************
#
#
#
#
# === Hold-out (20%) — AMO ===
# Equation (trained on 80%): 21.278851*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.3356212377548218
# Train RMSE (80%)=0.24742
# Val  RMSE (20%)=0.26365 | MAE=0.21482 | R²=0.84858
# Tue Dec 16 18:23:31 2025    stats
#
#          111869686 function calls (111867197 primitive calls) in 556.237 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       292    0.319    0.001 1625.372    5.566 base_events.py:1909(_run_once)
#       292    0.696    0.002  753.041    2.579 selectors.py:319(select)
#       292   21.887    0.075  482.023    1.651 selectors.py:313(_select)
#       294    0.409    0.001  269.546    0.917 events.py:86(_run)
#       292  154.035    0.528  248.848    0.852 {built-in method select.select}
#       545  101.581    0.186  101.581    0.186 {built-in method torch.cat}
#        34   82.677    2.432   87.602    2.577 FeatureSpaceConstruction.py:333(combinations)
#        17    1.434    0.084   76.404    4.494 FeatureSpaceConstruction.py:457(feature_space)
#        17   67.093    3.947   67.093    3.947 {method 'std' of 'torch._C.TensorBase' objects}
#        17   10.420    0.613   63.647    3.744 Regressor.py:25(__init__)
#        68   16.809    0.247   16.809    0.247 {built-in method torch.isinf}
#       136   12.821    0.094   12.821    0.094 {built-in method torch.any}
#       294    0.117    0.000   12.109    0.041 {method 'run' of '_contextvars.Context' objects}
#  55830295   11.571    0.000   11.571    0.000 {method 'join' of 'str' objects}
#       122    0.481    0.004   10.015    0.082 zmqstream.py:573(_handle_events)
#       113    0.000    0.000   10.014    0.089 asyncio.py:206(_handle_events)
#  11166011    5.275    0.000    7.636    0.000 FeatureSpaceConstruction.py:389(<lambda>)
#       130    7.277    0.056    7.277    0.056 {built-in method torch.isnan}
#         3    0.060    0.020    6.846    2.282 1122172153.py:121(cv_rmse_for_nterm_on_train)
#  11166011    4.399    0.000    6.722    0.000 FeatureSpaceConstruction.py:388(<lambda>)
#  11166011    4.357    0.000    6.670    0.000 FeatureSpaceConstruction.py:395(<lambda>)
#  11166011    4.332    0.000    6.618    0.000 FeatureSpaceConstruction.py:381(<lambda>)
#  11166011    4.323    0.000    6.611    0.000 FeatureSpaceConstruction.py:374(<lambda>)
#        17    0.511    0.030    5.481    0.322 Regressor.py:182(regressor_fit)
#        17    0.014    0.001    5.308    0.312 model.py:87(fit)
#        98    4.612    0.047    4.612    0.047 {built-in method torch.sum}
#       151    4.417    0.029    4.417    0.029 {built-in method torch.combinations}
#        17    4.178    0.246    4.178    0.246 {built-in method torch.clone}
#    136/68    0.001    0.000    3.567    0.052 _jit_internal.py:617(fn)
#        68    0.001    0.000    3.567    0.052 functional.py:786(_unique_impl)
#        47    3.494    0.074    3.494    0.074 {built-in method torch.mm}
#        66    3.102    0.047    3.102    0.047 {method 'mean' of 'torch._C.TensorBase' objects}
#        68    2.965    0.044    2.965    0.044 {built-in method torch.div}
#        34    2.632    0.077    2.632    0.077 {built-in method torch.multiply}
#       581    2.375    0.004    2.375    0.004 {method 'extend' of 'list' objects}
#        15    0.081    0.005    2.041    0.136 Regressor.py:92(higher_dimension)
#        34    0.000    0.000    2.037    0.060 functional.py:1057(_return_inverse)
#        34    2.037    0.060    2.037    0.060 {built-in method unique_dim}
#        69    0.038    0.001    1.862    0.027 ioloop.py:750(_run_callback)
#        60    0.002    0.000    1.823    0.030 iostream.py:611(_flush)
#        34    1.532    0.045    1.532    0.045 {built-in method torch.sub}
#        34    0.000    0.000    1.530    0.045 _tensor.py:1032(unique)
#        34    0.000    0.000    1.530    0.045 functional.py:1041(_return_output)
#        34    1.530    0.045    1.530    0.045 {built-in method torch._unique2}
#        60    0.001    0.000    1.501    0.025 session.py:755(send)
#        15    1.389    0.093    1.389    0.093 {built-in method gc.collect}
#        32    1.290    0.040    1.290    0.040 {built-in method torch.topk}
#        37    0.001    0.000    1.288    0.035 frame.py:5455(drop)
#        37    0.000    0.000    1.287    0.035 generic.py:4779(drop)
#        49    1.274    0.026    1.274    0.026 {built-in method torch._C._linalg.linalg_lstsq}
#        34    0.256    0.008    1.188    0.035 FeatureSpaceConstruction.py:147(single_variable)
#        37    0.001    0.000    1.004    0.027 generic.py:4818(_drop_axis)
#        60    0.001    0.000    0.887    0.015 session.py:691(serialize)
#        60    0.000    0.000    0.877    0.015 session.py:676(sign)
#        37    0.064    0.002    0.853    0.023 base.py:7097(drop)
#        91    0.001    0.000    0.797    0.009 base.py:3827(get_indexer)
#        54    0.000    0.000    0.794    0.015 base.py:6174(get_indexer_for)
#       121    0.001    0.000    0.789    0.007 zmqstream.py:614(_handle_recv)
#       121    0.000    0.000    0.786    0.006 zmqstream.py:546(_run_callback)
#       426    0.004    0.000    0.760    0.002 {method 'to' of 'torch._C.TensorBase' objects}
#        60    0.757    0.013    0.757    0.013 {method 'copy' of '_hashlib.HMAC' objects}
#       121    0.059    0.000    0.751    0.006 iostream.py:158(_handle_event)
#   541/529    0.104    0.000    0.704    0.001 socket.py:623(send)
#   121/118    0.036    0.000    0.642    0.005 iostream.py:260(schedule)
#        17    0.001    0.000    0.638    0.038 FeatureSpaceConstruction.py:27(__init__)
#        60    0.000    0.000    0.605    0.010 iostream.py:272(send_multipart)
#       342    0.043    0.000    0.508    0.001 base.py:7659(ensure_index)
#        91    0.000    0.000    0.505    0.006 base.py:6725(_maybe_cast_listlike_indexer)
#        51    0.469    0.009    0.482    0.009 {built-in method torch.tensor}
#       101    0.008    0.000    0.469    0.005 base.py:475(__new__)
#       689    0.450    0.001    0.450    0.001 {built-in method builtins.max}
#        17    0.001    0.000    0.364    0.021 1122172153.py:95(predict_from_equation)
#        34    0.343    0.010    0.343    0.010 {built-in method torch.pow}
#        60    0.000    0.000    0.316    0.005 session.py:650(msg)
#        60    0.000    0.000    0.315    0.005 session.py:646(msg_header)
#       447    0.002    0.000    0.259    0.001 frame.py:4073(__getitem__)
#       481    0.246    0.001    0.247    0.001 base.py:5335(__contains__)
# 1029/1012    0.108    0.000    0.242    0.000 {built-in method numpy.asarray}
#        61    0.000    0.000    0.230    0.004 iostream.py:582(_schedule_in_thread)
#       117    0.001    0.000    0.230    0.002 base_events.py:743(call_later)
#        61    0.000    0.000    0.230    0.004 ioloop.py:604(call_later)
#        61    0.000    0.000    0.230    0.004 asyncio.py:216(call_at)
#        17    0.223    0.013    0.228    0.013 <frozen importlib._bootstrap>:645(parent)
#       117    0.001    0.000    0.228    0.002 base_events.py:767(call_at)
#        17    0.000    0.000    0.227    0.013 frame.py:4962(select_dtypes)
#       117    0.000    0.000    0.226    0.002 {built-in method _heapq.heappush}
#        61    0.191    0.003    0.226    0.004 events.py:127(__lt__)
#        63    0.221    0.004    0.221    0.004 base.py:3962(_get_indexer)
#       238    0.107    0.000    0.206    0.001 frame.py:1051(shape)
#        51    0.140    0.003    0.200    0.004 {built-in method builtins.eval}
#       152    0.024    0.000    0.199    0.001 construction.py:517(sanitize_array)
#        32    0.180    0.006    0.180    0.006 {built-in method torch.abs}
#       101    0.148    0.001    0.170    0.002 cast.py:1166(maybe_infer_to_datetimelike)
#       169    0.000    0.000    0.159    0.001 base.py:7754(maybe_extract_name)
#       820    0.000    0.000    0.159    0.000 inference.py:334(is_hashable)
#      1543    0.159    0.000    0.159    0.000 {built-in method builtins.hash}
#      1844    0.004    0.000    0.150    0.000 series.py:1107(__getitem__)
#        54    0.031    0.001    0.146    0.003 managers.py:727(_slice_take_blocks_ax0)
#        37    0.000    0.000    0.144    0.004 managers.py:642(reindex_indexer)
#        17    0.000    0.000    0.135    0.008 indexing.py:2668(check_bool_indexer)
#       153    0.001    0.000    0.135    0.001 generic.py:6306(__getattr__)
#        17    0.000    0.000    0.135    0.008 utils.py:419(check_array_indexer)
#        68    0.000    0.000    0.134    0.002 base.py:5449(_can_hold_identifiers_and_holds_name)
#        32    0.125    0.004    0.125    0.004 {built-in method torch.sqrt}
#        60    0.000    0.000    0.116    0.002 iostream.py:277(<lambda>)
#         1    0.021    0.021    0.115    0.115 {built-in method builtins.exec}
# 8397/6690    0.110    0.000    0.111    0.000 {built-in method builtins.len}
#        60    0.000    0.000    0.107    0.002 iostream.py:279(_really_send)
#        60    0.001    0.000    0.106    0.002 socket.py:700(send_multipart)
#       153    0.101    0.001    0.101    0.001 {built-in method torch.arange}
#        32    0.100    0.003    0.100    0.003 {built-in method torch.dot}
#       112    0.000    0.000    0.100    0.001 take.py:59(take_nd)
#       112    0.097    0.001    0.099    0.001 take.py:120(_take_nd_ndarray)
#       911    0.000    0.000    0.099    0.000 base.py:912(__len__)
#         1    0.000    0.000    0.094    0.094 <string>:1(<module>)
#         1    0.073    0.073    0.094    0.094 1122172153.py:154(main)
#        56    0.001    0.000    0.091    0.002 iostream.py:119(_run_event_pipe_gc)
#       112    0.002    0.000    0.088    0.001 tasks.py:653(sleep)
#        60    0.000    0.000    0.086    0.001 session.py:273(msg_header)
#        60    0.085    0.001    0.085    0.001 session.py:199(utcnow)
#        56    0.084    0.002    0.084    0.002 events.py:155(cancel)
#       447    0.001    0.000    0.080    0.000 frame.py:4637(_get_item_cache)
#        38    0.000    0.000    0.080    0.002 blocks.py:1353(take_nd)
#       460    0.001    0.000    0.078    0.000 frame.py:3994(_ixs)
#        71    0.075    0.001    0.075    0.001 _validators.py:226(validate_bool_kwarg)
#       477    0.002    0.000    0.070    0.000 {built-in method builtins.print}
#       202    0.068    0.000    0.068    0.000 common.py:1341(is_ea_or_datetimelike_dtype)
#      1550    0.005    0.000    0.068    0.000 interactiveshell.py:3051(write)
#        77    0.000    0.000    0.067    0.001 base.py:6436(_should_compare)
#       110    0.065    0.001    0.066    0.001 base.py:2751(inferred_type)
#        84    0.055    0.001    0.065    0.001 base.py:2320(is_unique)
#       443    0.002    0.000    0.065    0.000 managers.py:1031(iget)
#       497    0.062    0.000    0.062    0.000 managers.py:180(blknos)
#        52    0.061    0.001    0.061    0.001 {method 'format' of 'str' objects}
#       240    0.000    0.000    0.061    0.000 hmac.py:117(update)
#       240    0.060    0.000    0.060    0.000 {method 'update' of '_hashlib.HMAC' objects}
#         1    0.058    0.058    0.058    0.058 {method 'disable' of '_lsprof.Profiler' objects}
#      1550    0.008    0.000    0.052    0.000 iostream.py:650(write)
# 33964/33671    0.012    0.000    0.049    0.000 {built-in method builtins.isinstance}
#       255    0.042    0.000    0.042    0.000 {built-in method torch.empty}
#        17    0.042    0.002    0.042    0.002 {method 'view' of 'torch._C.TensorBase' objects}
#        47    0.001    0.000    0.040    0.001 frame.py:698(__init__)
#      1550    0.000    0.000    0.040    0.000 iostream.py:572(_schedule_flush)
#        17    0.000    0.000    0.037    0.002 frame.py:11752(var)
#        17    0.000    0.000    0.037    0.002 generic.py:12403(var)
#        17    0.000    0.000    0.036    0.002 generic.py:12359(_stat_function_ddof)
#        17    0.001    0.000    0.034    0.002 frame.py:11462(_reduce)
#       121    0.000    0.000    0.034    0.000 typing.py:1221(__instancecheck__)
#       121    0.000    0.000    0.034    0.000 typing.py:1492(__subclasscheck__)
#        60    0.000    0.000    0.034    0.001 hmac.py:161(hexdigest)
#      1091    0.000    0.000    0.034    0.000 {built-in method builtins.issubclass}
#        60    0.034    0.001    0.034    0.001 {method 'hexdigest' of '_hashlib.HMAC' objects}
#       157    0.000    0.000    0.034    0.000 <frozen abc>:121(__subclasscheck__)
#       157    0.033    0.000    0.033    0.000 {built-in method _abc._abc_subclasscheck}
#        17    0.000    0.000    0.033    0.002 construction.py:423(dict_to_mgr)
#        96    0.000    0.000    0.032    0.000 _tensor.py:38(wrapped)
#        96    0.032    0.000    0.032    0.000 {method 'pow' of 'torch._C.TensorBase' objects}
#        17    0.000    0.000    0.031    0.002 managers.py:1502(reduce)
#        51    0.000    0.000    0.030    0.001 missing.py:101(isna)
#        51    0.000    0.000    0.029    0.001 missing.py:184(_isna)
#        17    0.000    0.000    0.029    0.002 series.py:5792(isna)
#        17    0.000    0.000    0.029    0.002 generic.py:8720(isna)
#        17    0.001    0.000    0.028    0.002 blocks.py:400(reduce)
#        34    0.001    0.000    0.027    0.001 missing.py:261(_isna_array)
# ...
#        17    0.000    0.000    0.000    0.000 base.py:397(ensure_np_dtype)
#        34    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#        17    0.000    0.000    0.000    0.000 range.py:483(_view)
#         1    0.000    0.000    0.000    0.000 socket.py:245(close)
#        38    0.000    0.000    0.000    0.000 blocks.py:221(_can_consolidate)
#        68    0.000    0.000    0.000    0.000 generic.py:670(_info_axis)
#       176    0.000    0.000    0.000    0.000 generic.py:575(_get_axis_number)
#        68    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#       111    0.000    0.000    0.000    0.000 generic.py:699(ndim)
#       460    0.000    0.000    0.000    0.000 base.py:6718(_maybe_cast_indexer)
#       113    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#        17    0.000    0.000    0.000    0.000 generic.py:4017(_maybe_update_cacher)
#        34    0.000    0.000    0.000    0.000 nanops.py:1678(_ensure_numeric)
#        56    0.000    0.000    0.000    0.000 events.py:72(cancel)
#       155    0.000    0.000    0.000    0.000 base.py:981(dtype)
#        68    0.000    0.000    0.000    0.000 base.py:541(<genexpr>)
#       180    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#       243    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#        34    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 1122172153.py:75(mae)
#       136    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        81    0.000    0.000    0.000    0.000 construction.py:685(_sanitize_non_ordered)
#        68    0.000    0.000    0.000    0.000 nanops.py:72(check)
#        98    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#        18    0.000    0.000    0.000    0.000 frame.py:5101(predicate)
#        16    0.000    0.000    0.000    0.000 base.py:2801(_na_value)
#         1    0.000    0.000    0.000    0.000 managers.py:2295(_merge_blocks)
#        17    0.000    0.000    0.000    0.000 dispatch.py:17(should_extension_dispatch)
#       422    0.000    0.000    0.000    0.000 common.py:511(f)
#        74    0.000    0.000    0.000    0.000 managers.py:241(is_single_block)
#        18    0.000    0.000    0.000    0.000 arrayprint.py:1061(<genexpr>)
#       112    0.000    0.000    0.000    0.000 _dtype.py:326(_name_includes_bit_suffix)
#        18    0.000    0.000    0.000    0.000 validation.py:470(_make_indexable)
#        59    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.000    0.000 _dataframe.py:45(is_pandas_df)
#        65    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#        17    0.000    0.000    0.000    0.000 common.py:301(maybe_iterable_to_list)
#       112    0.000    0.000    0.000    0.000 _dtype.py:23(_kind_name)
#        60    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#        15    0.000    0.000    0.000    0.000 arrayprint.py:815(_extendLine_pretty)
#        20    0.000    0.000    0.000    0.000 base.py:802(tolist)
#         3    0.000    0.000    0.000    0.000 _split.py:515(__init__)
#        77    0.000    0.000    0.000    0.000 common.py:133(<lambda>)
#       294    0.000    0.000    0.000    0.000 base_events.py:2004(get_debug)
#        31    0.000    0.000    0.000    0.000 shape_base.py:208(_arrays_for_stack_dispatcher)
#       182    0.000    0.000    0.000    0.000 base_events.py:539(_check_closed)
#        51    0.000    0.000    0.000    0.000 frame.py:4634(_clear_item_cache)
#        17    0.000    0.000    0.000    0.000 common.py:994(is_numeric_v_string_like)
#        17    0.000    0.000    0.000    0.000 construction.py:766(_try_cast)
#        77    0.000    0.000    0.000    0.000 common.py:1124(<lambda>)
#        34    0.000    0.000    0.000    0.000 generic.py:583(_get_axis_name)
#       185    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function_unary}
#        63    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:2338(sum)
#       199    0.000    0.000    0.000    0.000 multiarray.py:1106(copyto)
#       135    0.000    0.000    0.000    0.000 construction.py:755(_maybe_repeat)
#        61    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#        15    0.000    0.000    0.000    0.000 arrayprint.py:1092(__call__)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#        18    0.000    0.000    0.000    0.000 frame.py:5083(dtype_predicate)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:3052(max)
#        96    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function}
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:3618(round)
#        18    0.000    0.000    0.000    0.000 arrayprint.py:1056(<genexpr>)
#        19    0.000    0.000    0.000    0.000 blocks.py:2868(extend_blocks)
#         3    0.000    0.000    0.000    0.000 arrayprint.py:57(_make_options_dict)
#         3    0.000    0.000    0.000    0.000 _split.py:346(__init__)
#        98    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#        77    0.000    0.000    0.000    0.000 common.py:128(_classes_and_not_datetimelike)
#         3    0.000    0.000    0.000    0.000 frame.py:1942(to_numpy)
#       135    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#        17    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        60    0.000    0.000    0.000    0.000 common.py:1272(is_1d_only_ea_dtype)
#       102    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        34    0.000    0.000    0.000    0.000 base.py:332(array)
#       152    0.000    0.000    0.000    0.000 managers.py:932(__init__)
#        37    0.000    0.000    0.000    0.000 {method 'as_arrays' of 'numpy._core._multiarray_umath._array_converter' objects}
#        47    0.000    0.000    0.000    0.000 construction.py:196(mgr_to_mgr)
#        17    0.000    0.000    0.000    0.000 generic.py:4424(_check_setitem_copy)
#        30    0.000    0.000    0.000    0.000 {built-in method numpy._core._multiarray_umath.dragon4_positional}
#        17    0.000    0.000    0.000    0.000 frame.py:1652(__len__)
#        68    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#       102    0.000    0.000    0.000    0.000 managers.py:246(items)
#        18    0.000    0.000    0.000    0.000 _sparse.py:10(issparse)
#         4    0.000    0.000    0.000    0.000 managers.py:2283(<lambda>)
#        65    0.000    0.000    0.000    0.000 base.py:693(_constructor)
#        17    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 blocks.py:227(_consolidate_key)
#        50    0.000    0.000    0.000    0.000 {built-in method numpy.lib.array_utils.normalize_axis_index}
#         3    0.000    0.000    0.000    0.000 random.py:889(getrandbits)
#        71    0.000    0.000    0.000    0.000 base.py:1678(name)
#        15    0.000    0.000    0.000    0.000 arrayprint.py:801(_extendLine)
#        34    0.000    0.000    0.000    0.000 numeric.py:1469(<genexpr>)
#        60    0.000    0.000    0.000    0.000 iostream.py:256(closed)
#        17    0.000    0.000    0.000    0.000 generic.py:4540(_check_inplace_and_allows_duplicate_labels)
#        23    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'round' of 'numpy.ndarray' objects}
#        68    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#        17    0.000    0.000    0.000    0.000 generic.py:4401(_set_is_copy)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#        91    0.000    0.000    0.000    0.000 missing.py:1073(clean_reindex_fill_method)
#        37    0.000    0.000    0.000    0.000 {method 'wrap' of 'numpy._core._multiarray_umath._array_converter' objects}
#        68    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:3190(min)
#         3    0.000    0.000    0.000    0.000 _ufunc_config.py:448(__enter__)
#        17    0.000    0.000    0.000    0.000 indexing.py:1166(_check_deprecated_callable_usage)
#        17    0.000    0.000    0.000    0.000 model.py:31(__init__)
#        17    0.000    0.000    0.000    0.000 missing.py:131(dispatch_fill_zeros)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#        20    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        34    0.000    0.000    0.000    0.000 managers.py:291(arrays)
#        17    0.000    0.000    0.000    0.000 utils.py:62(is_list_like_indexer)
#       102    0.000    0.000    0.000    0.000 base.py:367(ndim)
#        56    0.000    0.000    0.000    0.000 base_events.py:1904(_timer_handle_cancelled)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#        51    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'set' of '_contextvars.ContextVar' objects}
#       102    0.000    0.000    0.000    0.000 range.py:376(dtype)
#         1    0.000    0.000    0.000    0.000 shape_base.py:220(vstack)
#         3    0.000    0.000    0.000    0.000 {built-in method nt.urandom}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#        17    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        68    0.000    0.000    0.000    0.000 series.py:1492(_clear_item_cache)
#        30    0.000    0.000    0.000    0.000 construction.py:585(_ensure_2d)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1129(argsort)
#        34    0.000    0.000    0.000    0.000 function.py:64(__call__)
#        52    0.000    0.000    0.000    0.000 multiarray.py:188(concatenate)
#         3    0.000    0.000    0.000    0.000 arrayprint.py:460(_get_formatdict)
#        60    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#        15    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C.TensorBase' objects}
#        34    0.000    0.000    0.000    0.000 multiarray.py:1156(putmask)
#         1    0.000    0.000    0.000    0.000 context.py:283(_rm_socket)
#         1    0.000    0.000    0.000    0.000 history.py:1017(_writeout_output_cache)
#        17    0.000    0.000    0.000    0.000 frame.py:1034(axes)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#        37    0.000    0.000    0.000    0.000 _function_base_impl.py:5285(_delete_dispatcher)
#         6    0.000    0.000    0.000    0.000 {method 'reset' of '_contextvars.ContextVar' objects}
#         2    0.000    0.000    0.000    0.000 numerictypes.py:475(issubdtype)
#        17    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#        17    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        34    0.000    0.000    0.000    0.000 series.py:663(_constructor)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        18    0.000    0.000    0.000    0.000 arrayprint.py:1065(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 _ufunc_config.py:464(__exit__)
#        18    0.000    0.000    0.000    0.000 arrayprint.py:1066(<genexpr>)
#         3    0.000    0.000    0.000    0.000 _split.py:63(split)
#        15    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#        18    0.000    0.000    0.000    0.000 blocks.py:272(mgr_locs)
#        17    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'frozenset' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method numpy._core._multiarray_umath._make_extobj}
#         3    0.000    0.000    0.000    0.000 getlimits.py:494(__new__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:115(discard)
#        17    0.000    0.000    0.000    0.000 base.py:1183(_maybe_disallow_fill)
#         5    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#        21    0.000    0.000    0.000    0.000 fromnumeric.py:3730(_mean_dispatcher)
#         4    0.000    0.000    0.000    0.000 numerictypes.py:293(issubclass_)
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:1081(_stop)
#        17    0.000    0.000    0.000    0.000 managers.py:2008(index)
#        17    0.000    0.000    0.000    0.000 _shape_base_impl.py:514(_expand_dims_dispatcher)
#         1    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         1    0.000    0.000    0.000    0.000 shape_base.py:80(atleast_2d)
#        17    0.000    0.000    0.000    0.000 fromnumeric.py:964(_sort_dispatcher)
#        17    0.000    0.000    0.000    0.000 range.py:451(_should_fallback_to_positional)
#     292/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 shape_base.py:216(_vhstack_dispatcher)
#         3    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         3    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:39(_remove)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 socket.py:184(__del__)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         3    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         3    0.000    0.000    0.000    0.000 _ufunc_config.py:438(__init__)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:2333(_sum_dispatcher)
#         3    0.000    0.000    0.000    0.000 arrayprint.py:966(_none_or_positive_arg)
#         3    0.000    0.000    0.000    0.000 1122172153.py:162(<lambda>)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:3185(_min_dispatcher)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:3047(_max_dispatcher)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:3614(_round_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:1236(daemon)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 history.py:1066(hold)
#         1    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1125(_argsort_dispatcher)
#         1    0.000    0.000    0.000    0.000 shape_base.py:76(_atleast_2d_dispatcher)

# %%
# !python -m cProfile -o profiling_results/model_opt script.py --config config.yaml
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1158 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.011970758438110352  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2776779 ************************************************
#
# ************************************************ Time taken to create the space is::: 9.181434631347656  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  20.883999*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.30250298976898193
#
#
# RMSE:  0.24504461884498596
# R2:: 0.8580718553952363
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.14959979057312012  seconds ************************************************
#
#
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1085 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.010964632034301758  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2451446 ************************************************
#
# ************************************************ Time taken to create the space is::: 6.117653131484985  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  19.326752*((Avg_Adsorption_100/AEL)/(AWF-AELA))+0.5350741147994995
#
#
# RMSE:  0.22869430482387543
# R2:: 0.8858199603324397
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.1406240463256836  seconds ************************************************
#
#
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.009975671768188477  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2781579 ************************************************
#
# ************************************************ Time taken to create the space is::: 11.540863752365112  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  19.46924*((Avg_Adsorption_100/AEL)/(AWF-AELA))+0.5519517660140991
#
#
# RMSE:  0.2510540783405304
# R2:: 0.8650454406300917
#
#
# ************************************************ Time taken to generate one dimensional equation:  1.654047966003418  seconds ************************************************
#
#
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1158 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.6278386116027832  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2776779 ************************************************
#
# ************************************************ Time taken to create the space is::: 6.296198606491089  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.505205*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.3454514741897583
#
#
# RMSE:  0.2486587017774582
# R2:: 0.8612208890914677
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.15756511688232422  seconds ************************************************
#
#
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.009979724884033203  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2782738 ************************************************
#
# ************************************************ Time taken to create the space is::: 6.069777011871338  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.761202*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.37832772731781006
#
#
# RMSE:  0.25953200459480286
# R2:: 0.8570175003000908
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.15060091018676758  seconds ************************************************
#
#
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1158 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.00997304916381836  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2776779 ************************************************
#
# ************************************************ Time taken to create the space is::: 6.034871816635132  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  20.883997*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.30250275135040283
#
#
# RMSE:  0.24504461884498596
# R2:: 0.8580718442361939
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.1736907958984375  seconds ************************************************
#
#
#
# 1 term in the equation is 19.3957309723*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.0075734900*((Pt+Avg_Adsorption_111)*(Avg_Mass*Avg_Charge))
#
#
# Equation:   + 19.3957309723*((Avg_Adsorption_100/AEL)/(AWF-AELA))   + 0.0075734900*((Pt+Avg_Adsorption_111)*(Avg_Mass*Avg_Charge))  +0.551714777946472
#
#
# RMSE: 0.21699795126914978
#
#
# R2:: 0.8887014516932196
# ************************************************ Time taken for 2 dimension is:  0.6018900871276855  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1085 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.009006977081298828  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2451446 ************************************************
#
# ************************************************ Time taken to create the space is::: 5.35665225982666  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  19.326752*((Avg_Adsorption_100/AEL)/(AWF-AELA))+0.5350741147994995
#
#
# RMSE:  0.22869430482387543
# R2:: 0.8858199603324397
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.13165283203125  seconds ************************************************
#
#
#
# 1 term in the equation is 20.8877201080*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -0.9140128493*((Ag+Avg_Charge)*(Ir-Avg_Charge))
#
#
# Equation:   + 20.8877201080*((Avg_Adsorption_111/AEL)/(AWF-AELA))  -0.9140128493*((Ag+Avg_Charge)*(Ir-Avg_Charge))  +0.31057393550872
#
#
# RMSE: 0.20251785218715668
#
#
# R2:: 0.9104622613147948
# ************************************************ Time taken for 2 dimension is:  0.13364553451538086  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.009977340698242188  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2781579 ************************************************
#
# ************************************************ Time taken to create the space is::: 6.180451393127441  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  19.46924*((Avg_Adsorption_100/AEL)/(AWF-AELA))+0.5519517660140991
#
#
# RMSE:  0.2510540783405304
# R2:: 0.8650454406300917
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.17852377891540527  seconds ************************************************
#
#
#
# 1 term in the equation is 20.0809669495*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.4898503125*((Pt-Avg_Charge)/(AELA-CN3))
#
#
# Equation:   + 20.0809669495*((Avg_Adsorption_100/AEL)/(AWF-AELA))   + 0.4898503125*((Pt-Avg_Charge)/(AELA-CN3))  +0.598031640052795
#
#
# RMSE: 0.21931950747966766
#
#
# R2:: 0.897007040773207
# ************************************************ Time taken for 2 dimension is:  0.15259099006652832  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1158 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.011998653411865234  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2776779 ************************************************
#
# ************************************************ Time taken to create the space is::: 6.1555495262146  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.505205*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.3454514741897583
#
#
# RMSE:  0.2486587017774582
# R2:: 0.8612208890914677
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.160597562789917  seconds ************************************************
#
#
#
# 1 term in the equation is 20.5986595154*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -1.8766607046*((Ag+Avg_Charge)*(Ir/Site_Type))
#
#
# Equation:   + 20.5986595154*((Avg_Adsorption_111/AEL)/(AWF-AELA))  -1.8766607046*((Ag+Avg_Charge)*(Ir/Site_Type))  +0.2959488630294
#
#
# RMSE: 0.2198803871870041
#
#
# R2:: 0.8914849962981803
# ************************************************ Time taken for 2 dimension is:  0.17550277709960938  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.010971307754516602  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2782738 ************************************************
#
# ************************************************ Time taken to create the space is::: 6.791848182678223  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.761206*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.37832796573638916
#
#
# RMSE:  0.25953200459480286
# R2:: 0.8570174903764505
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.15159296989440918  seconds ************************************************
#
#
#
# 1 term in the equation is 22.0065708160*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -0.4475705326*((Ag+Pt)*(Ir-Avg_Charge))
#
#
# Equation:   + 22.0065708160*((Avg_Adsorption_111/AEL)/(AWF-AELA))  -0.4475705326*((Ag+Pt)*(Ir-Avg_Charge))  +0.407145857810974
#
#
# RMSE: 0.2277199923992157
#
#
# R2:: 0.8899212650434449
# ************************************************ Time taken for 2 dimension is:  0.1486039161682129  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1158 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.010970830917358398  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2776779 ************************************************
#
# ************************************************ Time taken to create the space is::: 6.1296186447143555  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  20.883997*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.30250275135040283
#
#
# RMSE:  0.24504461884498596
# R2:: 0.8580718442361939
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.1683197021484375  seconds ************************************************
#
#
#
# 1 term in the equation is 19.3957309723*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.0075734900*((Pt+Avg_Adsorption_111)*(Avg_Mass*Avg_Charge))
#
#
# Equation:   + 19.3957309723*((Avg_Adsorption_100/AEL)/(AWF-AELA))   + 0.0075734900*((Pt+Avg_Adsorption_111)*(Avg_Mass*Avg_Charge))  +0.551714777946472
#
#
# RMSE: 0.21699795126914978
#
#
# R2:: 0.8887014516932196
# ************************************************ Time taken for 2 dimension is:  0.1515965461730957  seconds ************************************************
#
# 1 term in the equation is 19.8089294434*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.0075068236*((Pt+Avg_Adsorption_111)*(Avg_Mass*Avg_Charge))
#
#
# 3 term in the equation is 0.0270760115*((Ag+Au)*(TotEl*Avg_Adsorption_111))
#
#
# Equation:   + 19.8089294434*((Avg_Adsorption_100/AEL)/(AWF-AELA))   + 0.0075068236*((Pt+Avg_Adsorption_111)*(Avg_Mass*Avg_Charge))   + 0.0270760115*((Ag+Au)*(TotEl*Avg_Adsorption_111))  +0.630342364311218
#
#
# RMSE: 0.20053337514400482
#
#
# R2:: 0.9049501333639478
# ************************************************ Time taken for 3 dimension is:  0.2642951011657715  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1085 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.008976221084594727  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2451446 ************************************************
#
# ************************************************ Time taken to create the space is::: 5.441458463668823  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  19.326754*((Avg_Adsorption_100/AEL)/(AWF-AELA))+0.5350743532180786
#
#
# RMSE:  0.22869430482387543
# R2:: 0.8858199603324397
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.13763022422790527  seconds ************************************************
#
#
#
# 1 term in the equation is 20.8877201080*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -0.9140128493*((Ag+Avg_Charge)*(Ir-Avg_Charge))
#
#
# Equation:   + 20.8877201080*((Avg_Adsorption_111/AEL)/(AWF-AELA))  -0.9140128493*((Ag+Avg_Charge)*(Ir-Avg_Charge))  +0.31057393550872
#
#
# RMSE: 0.20251785218715668
#
#
# R2:: 0.9104622613147948
# ************************************************ Time taken for 2 dimension is:  0.15256667137145996  seconds ************************************************
#
# 1 term in the equation is 18.2752609253*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -2.2493004799*((Ag+Avg_Charge)*(Ir/Site_Type))
#
#
# 3 term in the equation is 0.4340415001*((Ag-Ru)*(Au-Rh))
#
#
# Equation:   + 18.2752609253*((Avg_Adsorption_100/AEL)/(AWF-AELA))  -2.2493004799*((Ag+Avg_Charge)*(Ir/Site_Type))   + 0.4340415001*((Ag-Ru)*(Au-Rh))  +0.458639502525329
#
#
# RMSE: 0.18078920245170593
#
#
# R2:: 0.9286449889402805
# ************************************************ Time taken for 3 dimension is:  0.2912251949310303  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.012965917587280273  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2781579 ************************************************
#
# ************************************************ Time taken to create the space is::: 6.36798095703125  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  19.46924*((Avg_Adsorption_100/AEL)/(AWF-AELA))+0.5519517660140991
#
#
# RMSE:  0.2510540783405304
# R2:: 0.8650454406300917
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.1485748291015625  seconds ************************************************
#
#
#
# 1 term in the equation is 20.0809669495*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.4898503125*((Pt-Avg_Charge)/(AELA-CN3))
#
#
# Equation:   + 20.0809669495*((Avg_Adsorption_100/AEL)/(AWF-AELA))   + 0.4898503125*((Pt-Avg_Charge)/(AELA-CN3))  +0.598031640052795
#
#
# RMSE: 0.21931950747966766
#
#
# R2:: 0.897007040773207
# ************************************************ Time taken for 2 dimension is:  0.17254042625427246  seconds ************************************************
#
# 1 term in the equation is 20.4529209137*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.0563836806*((Pt-Avg_Charge)*(ACN-CN3))
#
#
# 3 term in the equation is 0.5263874531*((Ag+Avg_Charge)*(Au+Avg_Adsorption_111))
#
#
# Equation:   + 20.4529209137*((Avg_Adsorption_100/AEL)/(AWF-AELA))   + 0.0563836806*((Pt-Avg_Charge)*(ACN-CN3))   + 0.5263874531*((Ag+Avg_Charge)*(Au+Avg_Adsorption_111))  +0.649054884910583
#
#
# RMSE: 0.19387812912464142
#
#
# R2:: 0.9195157948941182
# ************************************************ Time taken for 3 dimension is:  0.25830936431884766  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1158 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.01196742057800293  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2776779 ************************************************
#
# ************************************************ Time taken to create the space is::: 6.174499273300171  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.505205*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.3454514741897583
#
#
# RMSE:  0.2486587017774582
# R2:: 0.8612208890914677
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.14760541915893555  seconds ************************************************
#
#
#
# 1 term in the equation is 20.5986595154*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -1.8766607046*((Ag+Avg_Charge)*(Ir/Site_Type))
#
#
# Equation:   + 20.5986595154*((Avg_Adsorption_111/AEL)/(AWF-AELA))  -1.8766607046*((Ag+Avg_Charge)*(Ir/Site_Type))  +0.2959488630294
#
#
# RMSE: 0.2198803871870041
#
#
# R2:: 0.8914849962981803
# ************************************************ Time taken for 2 dimension is:  0.1575775146484375  seconds ************************************************
#
# 1 term in the equation is 21.0440387726*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is 0.1093154848*((Ir+Avg_Adsorption_111)*(Rh+ADBND))
#
#
# 3 term in the equation is 1.8155090809*((Au*Avg_Charge)/(AWF-CN2))
#
#
# Equation:   + 21.0440387726*((Avg_Adsorption_111/AEL)/(AWF-AELA))   + 0.1093154848*((Ir+Avg_Adsorption_111)*(Rh+ADBND))   + 1.8155090809*((Au*Avg_Charge)/(AWF-CN2))  +0.1248900890350341
#
#
# RMSE: 0.2029220014810562
#
#
# R2:: 0.907578069782239
# ************************************************ Time taken for 3 dimension is:  0.26930999755859375  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.011968135833740234  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2782738 ************************************************
#
# ************************************************ Time taken to create the space is::: 6.219409942626953  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.761202*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.37832772731781006
#
#
# RMSE:  0.25953200459480286
# R2:: 0.8570175003000908
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.15555691719055176  seconds ************************************************
#
#
#
# 1 term in the equation is 22.0065708160*((Avg_Adsorption_111/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -0.4475705326*((Ag+Pt)*(Ir-Avg_Charge))
#
#
# Equation:   + 22.0065708160*((Avg_Adsorption_111/AEL)/(AWF-AELA))  -0.4475705326*((Ag+Pt)*(Ir-Avg_Charge))  +0.407145857810974
#
#
# RMSE: 0.2277199923992157
#
#
# R2:: 0.8899212650434449
# ************************************************ Time taken for 2 dimension is:  0.1725630760192871  seconds ************************************************
#
# 1 term in the equation is 20.7431812286*((Avg_Adsorption_100/AEL)/(AWF-AELA))
#
#
# 2 term in the equation is -0.3634297848*((Ag+Pt)*(Ir-Avg_Charge))
#
#
# 3 term in the equation is 0.4815897644*((Pt-Avg_Charge)/(AELA+CN3))
#
#
# Equation:   + 20.7431812286*((Avg_Adsorption_100/AEL)/(AWF-AELA))  -0.3634297848*((Ag+Pt)*(Ir-Avg_Charge))   + 0.4815897644*((Pt-Avg_Charge)/(AELA+CN3))  +0.649430632591247
#
#
# RMSE: 0.2062908113002777
#
#
# R2:: 0.9096640002241949
# ************************************************ Time taken for 3 dimension is:  0.27327775955200195  seconds ************************************************
#
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.014937877655029297  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2781579 ************************************************
#
# ************************************************ Time taken to create the space is::: 34.43721103668213  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  20.627617*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.2833975553512573
#
#
# RMSE:  0.2495686113834381
# R2:: 0.8634717057854383
#
#
# ************************************************ Time taken to generate one dimensional equation:  1.3413496017456055  seconds ************************************************
#
#
#
#
# === Full-fit on ALL (AMO) ===
# Equation: 20.627617*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.2833975553512573
# RMSE=0.24957 | MAE=0.19634 | R²=0.86347
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 1160 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.414745569229126  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 2781579 ************************************************
#
# ************************************************ Time taken to create the space is::: 7.895900011062622  Seconds...************************************************
#
#
#
# ************************************************ Starting sparse model building in cpu ************************************************
#
#
#
# Equation:  21.278845*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.3356207609176636
#
#
# RMSE:  0.24741581082344055
# R2:: 0.8651618214716765
#
#
# ************************************************ Time taken to generate one dimensional equation:  0.21941447257995605  seconds ************************************************
#
#
#
#
# === Hold-out (20%) — AMO ===
# Equation (trained on 80%): 21.278845*((Avg_Adsorption_111/AEL)/(AWF-AELA))+0.3356207609176636
# Train RMSE (80%)=0.24742
# Val  RMSE (20%)=0.26365 | MAE=0.21482 | R²=0.84858

# %%
import pstats

p = pstats.Stats('profiling_results/model_opt')
p.strip_dirs().sort_stats("cumulative").print_stats()
# Out:
# Wed Dec 17 20:56:53 2025    profiling_results/model_opt
#
#          4106346 function calls (4039078 primitive calls) in 272.777 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.429    0.429  265.922  265.922 script.py:161(main)
#        17    0.034    0.002  260.518   15.325 model.py:40(fit)
#         3    1.927    0.642  200.990   66.997 script.py:115(cv_rmse_for_nterm)
#        17    3.273    0.193  143.599    8.447 FeatureSpaceConstruction.py:548(feature_space)
#        34   50.582    1.488  123.391    3.629 FeatureSpaceConstruction.py:374(combinations)
#        17   12.696    0.747  107.905    6.347 Regressor.py:19(__init__)
#        17   94.259    5.545   94.259    5.545 {built-in method torch.std_mean}
#       341   33.492    0.098   33.492    0.098 {built-in method torch.cat}
#        68   23.255    0.342   23.255    0.342 {built-in method torch.isinf}
#       354    0.013    0.000   14.371    0.041 __init__.py:1(<module>)
#       102   13.834    0.136   13.834    0.136 {method 'any' of 'torch._C.TensorBase' objects}
#        17    0.326    0.019    8.741    0.514 Regressor.py:174(regressor_fit)
#       130    8.681    0.067    8.681    0.067 {built-in method torch.isnan}
#        34    5.090    0.150    5.090    0.150 {method 'clone' of 'torch._C.TensorBase' objects}
#        47    4.182    0.089    4.182    0.089 {built-in method torch.mm}
#        15    0.542    0.036    3.372    0.225 Regressor.py:77(higher_dimension)
#      2162    1.883    0.001    1.886    0.001 {method 'extend' of 'list' objects}
#      2412    0.029    0.000    1.874    0.001 <frozen importlib._bootstrap_external>:1062(get_code)
#    211/83    0.002    0.000    1.793    0.022 _ops.py:370(fallthrough)
#    2705/7    0.025    0.000    1.764    0.252 <frozen importlib._bootstrap>:1349(_find_and_load)
#    2672/7    0.015    0.000    1.764    0.252 <frozen importlib._bootstrap>:1304(_find_and_load_unlocked)
#    2597/8    0.011    0.000    1.757    0.220 <frozen importlib._bootstrap>:911(_load_unlocked)
#    2380/7    0.010    0.000    1.756    0.251 <frozen importlib._bootstrap_external>:989(exec_module)
#   6067/16    0.006    0.000    1.749    0.109 <frozen importlib._bootstrap>:480(_call_with_frames_removed)
#    951/70    0.003    0.000    1.424    0.020 {built-in method builtins.__import__}
#        11    0.001    0.000    1.416    0.129 base.py:1(<module>)
#         1    0.000    0.000    1.370    1.370 _chunking.py:1(<module>)
#         1    0.000    0.000    1.369    1.369 _param_validation.py:1(<module>)
#        32    1.229    0.038    1.229    0.038 {built-in method torch.topk}
#         2    0.000    0.000    1.177    0.588 _array_api.py:1(<module>)
#        15    1.176    0.078    1.176    0.078 {built-in method gc.collect}
#  2778/500    0.072    0.000    1.171    0.002 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    1.167    1.167 validation.py:1(<module>)
#      2666    0.025    0.000    1.095    0.000 <frozen importlib._bootstrap>:1240(_find_spec)
#        34    0.144    0.004    1.001    0.029 FeatureSpaceConstruction.py:155(single_variable)
#      2643    0.003    0.000    1.000    0.000 <frozen importlib._bootstrap_external>:1520(find_spec)
#      2643    0.007    0.000    0.997    0.000 <frozen importlib._bootstrap_external>:1491(_get_spec)
#     10094    0.995    0.000    0.995    0.000 {built-in method nt.stat}
#      9635    0.007    0.000    0.954    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#      2412    0.010    0.000    0.939    0.000 <frozen importlib._bootstrap_external>:1183(get_data)
# 5578/5446    0.104    0.000    0.924    0.000 {built-in method builtins.__build_class__}
#        49    0.923    0.019    0.923    0.019 {built-in method torch.combinations}
#        49    0.917    0.019    0.917    0.019 {built-in method torch._C._linalg.linalg_lstsq}
#      3222    0.035    0.000    0.913    0.000 <frozen importlib._bootstrap_external>:1593(find_spec)
#        34    0.833    0.025    0.833    0.025 {method 'nonzero' of 'torch._C.TensorBase' objects}
#         1    0.000    0.000    0.830    0.830 DimensionalFeatureSpaceConstruction.py:1(<module>)
#         1    0.000    0.000    0.803    0.803 fixes.py:1(<module>)
#      2412    0.731    0.000    0.731    0.000 {built-in method _io.open_code}
#       113    0.002    0.000    0.672    0.006 custom_ops.py:185(__init__)
#       113    0.001    0.000    0.667    0.006 custom_ops.py:598(_register_to_dispatcher)
#         1    0.000    0.000    0.629    0.629 pyplot.py:1(<module>)
#        37    0.001    0.000    0.619    0.017 frame.py:5455(drop)
#        37    0.020    0.001    0.618    0.017 generic.py:4779(drop)
#      2412    0.035    0.000    0.603    0.000 <frozen importlib._bootstrap_external>:751(_compile_bytecode)
#      10/8    0.000    0.000    0.600    0.075 _ops.py:172(py_functionalize_impl)
#    171/58    0.016    0.000    0.598    0.010 _ops.py:308(py_impl)
#         1    0.001    0.001    0.576    0.576 _stats_py.py:1(<module>)
#       113    0.001    0.000    0.567    0.005 library.py:187(_register_fake)
#      2412    0.563    0.000    0.563    0.000 {built-in method marshal.loads}
#        37    0.015    0.000    0.538    0.015 generic.py:4818(_drop_axis)
#         1    0.000    0.000    0.527    0.527 _decorators.py:325(wrapper)
#         1    0.000    0.000    0.527    0.527 generic.py:3819(to_csv)
#         1    0.000    0.000    0.525    0.525 format.py:965(to_csv)
#        12    0.000    0.000    0.519    0.043 _jit_internal.py:1027(_overload)
#       158    0.514    0.003    0.514    0.003 {method 'tolist' of 'torch._C.TensorBase' objects}
#       113    0.001    0.000    0.509    0.005 fake_impl.py:34(register)
#    343/62    0.022    0.000    0.508    0.008 library.py:287(impl)
#     83/18    0.001    0.000    0.503    0.028 custom_ops.py:334(inner)
#       141    0.001    0.000    0.494    0.004 inspect.py:1070(findsource)
#       113    0.000    0.000    0.491    0.004 utils.py:35(get_source)
#       113    0.002    0.000    0.491    0.004 inspect.py:1684(getframeinfo)
#        49    0.474    0.010    0.474    0.010 {method 'mean' of 'torch._C.TensorBase' objects}
#   356/354    0.008    0.000    0.473    0.001 inspect.py:988(getmodule)
#         8    0.000    0.000    0.452    0.057 api.py:1(<module>)
#       6/5    0.000    0.000    0.428    0.086 _ops.py:321(py_autograd_impl)
#      3682    0.005    0.000    0.375    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#       106    0.004    0.000    0.355    0.003 artist.py:158(_update_set_signature_and_docstring)
#       105    0.001    0.000    0.350    0.003 artist.py:125(__init_subclass__)
#      3357    0.003    0.000    0.349    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#        37    0.044    0.001    0.345    0.009 base.py:7097(drop)
#      1474    0.009    0.000    0.333    0.000 <frozen ntpath>:692(realpath)
#         1    0.000    0.000    0.327    0.327 figure.py:1(<module>)
#        32    0.318    0.010    0.318    0.010 {built-in method torch.abs}
#         1    0.277    0.277    0.314    0.314 __init__.py:162(_load_dll_libraries)
# 57286/56522    0.025    0.000    0.312    0.000 {built-in method builtins.hasattr}
#      2954    0.307    0.000    0.307    0.000 {built-in method nt._getfinalpathname}
#    102/51    0.037    0.000    0.307    0.006 _jit_internal.py:617(fn)
#        68    0.302    0.004    0.302    0.004 {built-in method torch.arange}
#        51    0.275    0.005    0.287    0.006 {built-in method torch.tensor}
#        94    0.002    0.000    0.282    0.003 base.py:3827(get_indexer)
#       120    0.001    0.000    0.281    0.002 artist.py:1832(kwdoc)
#        56    0.000    0.000    0.280    0.005 base.py:6174(get_indexer_for)
#         2    0.000    0.000    0.275    0.137 batchnorm.py:1(<module>)
#         2    0.000    0.000    0.275    0.137 _functions.py:1(<module>)
#        51    0.001    0.000    0.269    0.005 functional.py:786(_unique_impl)
#         3    0.000    0.000    0.265    0.088 generic.py:1(<module>)
#       119    0.261    0.002    0.261    0.002 {built-in method torch.empty}
#        34    0.258    0.008    0.258    0.008 {built-in method torch.pow}
#         1    0.000    0.000    0.253    0.253 polyfuncs.py:1(<module>)
#         1    0.000    0.000    0.252    0.252 specialpolys.py:1(<module>)
# 2629/2623    0.006    0.000    0.249    0.000 <frozen importlib._bootstrap>:806(module_from_spec)
#         1    0.000    0.000    0.247    0.247 image.py:1(<module>)
#       210    0.000    0.000    0.240    0.001 _docscrape.py:579(__init__)
#       120    0.006    0.000    0.238    0.002 artist.py:1593(pprint_setters)
#        17    0.002    0.000    0.238    0.014 FeatureSpaceConstruction.py:30(__init__)
#         1    0.000    0.000    0.236    0.236 rings.py:1(<module>)
#         7    0.000    0.000    0.231    0.033 _base.py:1(<module>)
#         1    0.000    0.000    0.231    0.231 distributions.py:1(<module>)
#         1    0.000    0.000    0.230    0.230 backend_bases.py:1(<module>)
#      2412    0.004    0.000    0.227    0.000 <frozen importlib._bootstrap_external>:1202(path_stats)
#       325    0.001    0.000    0.227    0.001 dataclasses.py:1264(wrap)
#       325    0.013    0.000    0.226    0.001 dataclasses.py:921(_process_class)
# 469852/465278    0.140    0.000    0.224    0.000 {built-in method builtins.len}
#        10    0.000    0.000    0.221    0.022 linear.py:1(<module>)
#       216    0.001    0.000    0.213    0.001 _docscrape.py:140(__init__)
#     10108    0.014    0.000    0.202    0.000 __init__.py:280(_compile)
#        34    0.001    0.000    0.198    0.006 functional.py:1057(_return_inverse)
#      7848    0.104    0.000    0.197    0.000 inspect.py:882(cleandoc)
#      7140    0.035    0.000    0.196    0.000 <frozen importlib._bootstrap>:304(acquire)
#         1    0.000    0.000    0.194    0.194 pycode.py:1(<module>)
#      4409    0.015    0.000    0.194    0.000 artist.py:1461(get_valid_values)
#   189/140    0.000    0.000    0.193    0.001 <frozen importlib._bootstrap_external>:1295(exec_module)
#   189/140    0.041    0.000    0.192    0.001 {built-in method _imp.exec_dynamic}
#         1    0.000    0.000    0.192    0.192 codeprinter.py:1(<module>)
#        34    0.184    0.005    0.184    0.005 {built-in method unique_dim}
#        40    0.000    0.000    0.177    0.004 __init__.py:73(import_module)
#        40    0.000    0.000    0.176    0.004 <frozen importlib._bootstrap>:1375(_gcd_import)
#     15771    0.114    0.000    0.176    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
#       503    0.153    0.000    0.170    0.000 {built-in method builtins.eval}
#         1    0.000    0.000    0.167    0.167 cond.py:1(<module>)
#        31    0.000    0.000    0.165    0.005 __init__.py:141(__getattr__)
#      7722    0.008    0.000    0.164    0.000 inspect.py:863(getdoc)
#         1    0.000    0.000    0.164    0.164 associative_scan.py:1(<module>)
#      2412    0.164    0.000    0.164    0.000 {method 'read' of '_io.BufferedReader' objects}
#      2803    0.003    0.000    0.163    0.000 inspect.py:3339(signature)
#       216    0.005    0.000    0.162    0.001 _docscrape.py:388(_parse)
#      2738    0.004    0.000    0.160    0.000 <frozen importlib._bootstrap>:416(__enter__)
#      2803    0.003    0.000    0.160    0.000 inspect.py:3077(from_callable)
# 4046/2807    0.026    0.000    0.157    0.000 inspect.py:2497(_signature_from_callable)
#         1    0.000    0.000    0.157    0.157 module.py:1(<module>)
# 181253/180755    0.054    0.000    0.156    0.000 {built-in method builtins.getattr}
#       665    0.000    0.000    0.154    0.000 __init__.py:226(compile)
#        55    0.028    0.001    0.154    0.003 managers.py:727(_slice_take_blocks_ax0)
#        40    0.001    0.000    0.153    0.004 managers.py:642(reindex_indexer)
#       396    0.002    0.000    0.151    0.000 _compiler.py:740(compile)
#         1    0.000    0.000    0.147    0.147 _sputils.py:1(<module>)
#         1    0.000    0.000    0.147    0.147 aoti_call_delegate.py:1(<module>)
#       189    0.000    0.000    0.147    0.001 <frozen importlib._bootstrap_external>:1287(create_module)
#        49    0.001    0.000    0.146    0.003 frame.py:698(__init__)
#         4    0.000    0.000    0.146    0.036 _util.py:1(<module>)
#         2    0.000    0.000    0.145    0.072 text.py:1(<module>)
#       189    0.138    0.001    0.145    0.001 {built-in method _imp.create_dynamic}
#         1    0.001    0.001    0.143    0.143 _continuous_distns.py:1(<module>)
#     26/10    0.000    0.000    0.143    0.014 _ops.py:280(__init__)
# 309069/309014    0.066    0.000    0.140    0.000 {built-in method builtins.isinstance}
#      1295    0.008    0.000    0.140    0.000 dataclasses.py:449(_create_fn)
#      7140    0.012    0.000    0.139    0.000 <frozen importlib._bootstrap>:162(__enter__)
#         1    0.000    0.000    0.138    0.138 _invoke_quant.py:1(<module>)
#        19    0.001    0.000    0.138    0.007 construction.py:423(dict_to_mgr)
#         1    0.000    0.000    0.138    0.138 rcsetup.py:1(<module>)
#        17    0.001    0.000    0.138    0.008 script.py:75(predict_from_equation)
#         1    0.000    0.000    0.137    0.137 frame.py:1(<module>)
#        10    0.000    0.000    0.137    0.014 __init__.py:720(__getattr__)
#        17    0.132    0.008    0.132    0.008 {method 'view' of 'torch._C.TensorBase' objects}
#      1693    0.004    0.000    0.131    0.000 inspect.py:976(getabsfile)
#         2    0.031    0.016    0.130    0.065 frame.py:4282(__setitem__)
#         1    0.005    0.005    0.127    0.127 {built-in method torch._C._initExtension}
#       325    0.000    0.000    0.125    0.000 dataclasses.py:1247(dataclass)
#      7140    0.053    0.000    0.124    0.000 <frozen importlib._bootstrap>:124(setdefault)
#         1    0.000    0.000    0.122    0.122 _orthogonal.py:1(<module>)
#      4402    0.037    0.000    0.122    0.000 <frozen importlib._bootstrap>:463(_lock_unlock_module)
#       111    0.003    0.000    0.120    0.001 base.py:475(__new__)
#       120    0.000    0.000    0.119    0.001 take.py:59(take_nd)
#      1860    0.008    0.000    0.119    0.000 inspect.py:951(getsourcefile)
#       120    0.073    0.001    0.119    0.001 take.py:120(_take_nd_ndarray)
#       365    0.001    0.000    0.118    0.000 base.py:7659(ensure_index)
#        17    0.117    0.007    0.117    0.007 {method 'sort' of 'torch._C.TensorBase' objects}
#       978    0.001    0.000    0.115    0.000 __init__.py:751(__setitem__)
#        94    0.000    0.000    0.115    0.001 base.py:6725(_maybe_cast_listlike_indexer)
#      4824    0.019    0.000    0.113    0.000 <frozen importlib._bootstrap_external>:482(cache_from_source)
#        18    0.000    0.000    0.111    0.006 _split.py:378(split)
#        18    0.000    0.000    0.111    0.006 _split.py:117(split)
#        15    0.110    0.007    0.110    0.007 {built-in method torch.matmul}
#        18    0.000    0.000    0.110    0.006 _split.py:150(_iter_test_masks)
#         1    0.000    0.000    0.110    0.110 _axes.py:1(<module>)
#        18    0.018    0.001    0.110    0.006 _split.py:518(_iter_test_indices)
#         1    0.000    0.000    0.106    0.106 csvs.py:246(save)
#        22    0.104    0.005    0.104    0.005 {built-in method torch.full}
#       110    0.002    0.000    0.103    0.001 _distn_infrastructure.py:1863(__init__)
#        24    0.001    0.000    0.102    0.004 utils.py:1(<module>)
#      2518    0.031    0.000    0.101    0.000 inspect.py:2393(_signature_from_function)
# 10405/9927    0.009    0.000    0.100    0.000 typing.py:392(inner)
#        66    0.098    0.001    0.099    0.002 base.py:3962(_get_indexer)
#         2    0.000    0.000    0.099    0.049 frame.py:4525(_set_item)
#         2    0.000    0.000    0.099    0.049 frame.py:4492(_set_item_mgr)
#         2    0.019    0.010    0.098    0.049 managers.py:1366(insert)
#         1    0.000    0.000    0.098    0.098 dataloader.py:1(<module>)
#       103    0.057    0.001    0.097    0.001 frame.py:1051(shape)
#      2074    0.010    0.000    0.096    0.000 _ops.py:1190(__getattr__)
#      1394    0.095    0.000    0.095    0.000 {built-in method nt._path_exists}
#       227    0.001    0.000    0.095    0.000 artist.py:1413(__init__)
#        44    0.000    0.000    0.094    0.002 blocks.py:1353(take_nd)
#         1    0.000    0.000    0.094    0.094 bsplines.py:1(<module>)
#       227    0.031    0.000    0.093    0.000 artist.py:1433(get_aliases)
#      2629    0.012    0.000    0.092    0.000 <frozen importlib._bootstrap>:733(_init_module_attrs)
#        17    0.092    0.005    0.092    0.005 {method 'scatter_' of 'torch._C.TensorBase' objects}
#         4    0.069    0.017    0.092    0.023 validation.py:1439(check_random_state)
#         1    0.000    0.000    0.091    0.091 rcsetup.py:272(validate_backend)
#         1    0.000    0.000    0.091    0.091 registry.py:202(is_valid_backend)
#         1    0.000    0.000    0.091    0.091 registry.py:113(_ensure_entry_points_loaded)
#         1    0.000    0.000    0.091    0.091 registry.py:128(_read_entry_points)
#         1    0.000    0.000    0.091    0.091 nested_tensor.py:1(<module>)
#      2801    0.013    0.000    0.090    0.000 textwrap.py:419(dedent)
#        32    0.090    0.003    0.090    0.003 {built-in method torch.sqrt}
#         1    0.000    0.000    0.090    0.090 nested_int.py:1(<module>)
#         1    0.000    0.000    0.089    0.089 partfrac.py:1(<module>)
#         1    0.000    0.000    0.089    0.089 decorator.py:65(xthreaded)
#         1    0.000    0.000    0.089    0.089 decorator.py:16(threaded_factory)
#         1    0.000    0.000    0.089    0.089 patches.py:1(<module>)
#       113    0.005    0.000    0.088    0.001 autograd.py:23(make_autograd_impl)
#       396    0.002    0.000    0.085    0.000 _parser.py:969(parse)
#        63    0.001    0.000    0.085    0.001 _axis_nan_policy.py:418(axis_nan_policy_decorator)
#       816    0.004    0.000    0.084    0.000 _pytree.py:1379(tree_map_)
#        30    0.025    0.001    0.082    0.003 _tensor.py:1145(__len__)
#  1208/396    0.004    0.000    0.082    0.000 _parser.py:452(_parse_sub)
#       194    0.016    0.000    0.082    0.000 construction.py:517(sanitize_array)
#      1140    0.006    0.000    0.080    0.000 _ops.py:1350(__getattr__)
#  1524/429    0.037    0.000    0.080    0.000 _parser.py:512(_parse)
#        64    0.001    0.000    0.079    0.001 _array_api.py:806(decorator)
#        18    0.000    0.000    0.079    0.004 frame.py:4962(select_dtypes)
#         1    0.000    0.000    0.077    0.077 comparison.py:1(<module>)
#      1197    0.005    0.000    0.076    0.000 _docscrape.py:201(_read_to_next_section)
#      3367    0.003    0.000    0.076    0.000 <frozen importlib._bootstrap_external>:1469(_path_importer_cache)
#         2    0.030    0.015    0.076    0.038 common.py:664(get_handle)
#         1    0.000    0.000    0.075    0.075 _classification_threshold.py:1(<module>)
#       451    0.002    0.000    0.073    0.000 frame.py:4073(__getitem__)
#       923    0.005    0.000    0.073    0.000 __init__.py:64(_add_op_to_registry)
#       319    0.002    0.000    0.073    0.000 <frozen importlib._bootstrap_external>:1456(_path_hooks)
#      5013    0.003    0.000    0.072    0.000 <frozen importlib._bootstrap>:632(cached)
#         2    0.000    0.000    0.072    0.036 base_hop.py:60(__init__)
#        17    0.000    0.000    0.072    0.004 _tensor.py:1032(unique)
#        17    0.000    0.000    0.071    0.004 functional.py:1041(_return_output)
#        17    0.071    0.004    0.071    0.004 {built-in method torch._unique2}
#      4956    0.002    0.000    0.071    0.000 <frozen abc>:117(__instancecheck__)
#        68    0.001    0.000    0.071    0.001 _util.py:1202(decorator)
#      2601    0.005    0.000    0.070    0.000 <frozen importlib._bootstrap_external>:611(_get_cached)
#        19    0.000    0.000    0.069    0.004 construction.py:96(arrays_to_mgr)
#      1229    0.003    0.000    0.069    0.000 _docscrape.py:212(_read_sections)
#      4956    0.004    0.000    0.069    0.000 {built-in method _abc._abc_instancecheck}
#        19    0.000    0.000    0.069    0.004 managers.py:2140(create_block_manager_from_column_arrays)
#        86    0.000    0.000    0.068    0.001 dispatcher.py:178(add)
#        19    0.033    0.002    0.068    0.004 managers.py:2209(_form_blocks)
#        64    0.068    0.001    0.068    0.001 {built-in method torch.sum}
#        86    0.000    0.000    0.068    0.001 dispatcher.py:222(reorder)
#         1    0.000    0.000    0.067    0.067 f2py2e.py:1(<module>)
#  2828/462    0.001    0.000    0.066    0.000 <frozen abc>:121(__subclasscheck__)
#       549    0.001    0.000    0.066    0.000 __init__.py:205(decomposition_decorator)
#  2828/462    0.005    0.000    0.066    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.066    0.066 _parallel_backends.py:1(<module>)
#         4    0.000    0.000    0.066    0.016 functional.py:1(<module>)
#         1    0.000    0.000    0.066    0.066 axes3d.py:1(<module>)
#        15    0.065    0.004    0.065    0.004 {method 'repeat' of 'torch._C.TensorBase' objects}
#       430    0.013    0.000    0.065    0.000 doccer.py:29(docformat)
#       241    0.065    0.000    0.065    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#       432    0.001    0.000    0.064    0.000 basic.py:212(__init_subclass__)
#         1    0.000    0.000    0.064    0.064 graph_settings.py:1(<module>)
#        80    0.000    0.000    0.064    0.001 base.py:6436(_should_compare)
#         1    0.000    0.000    0.063    0.063 _fontconfig_pattern.py:1(<module>)
#       433    0.028    0.000    0.063    0.000 assumptions.py:614(_prepare_class_assumptions)
#         3    0.000    0.000    0.063    0.021 __config__.py:1(<module>)
#         1    0.000    0.000    0.063    0.063 colors.py:1(<module>)
#       115    0.061    0.001    0.062    0.001 base.py:2751(inferred_type)
#         1    0.000    0.000    0.062    0.062 generic.py:2189(__array_ufunc__)
#         1    0.062    0.062    0.062    0.062 arraylike.py:253(array_ufunc)
#         1    0.000    0.000    0.062    0.062 graph_drawer.py:1(<module>)
#        20    0.000    0.000    0.061    0.003 common.py:301(maybe_iterable_to_list)
#         1    0.000    0.000    0.061    0.061 cm.py:1(<module>)
#       227    0.020    0.000    0.061    0.000 artist.py:1511(get_setters)
#        18    0.000    0.000    0.061    0.003 common.py:62(new_method)
#       112    0.039    0.000    0.061    0.001 cast.py:1166(maybe_infer_to_datetimelike)
#        12    0.000    0.000    0.061    0.005 warnings.py:133(filterwarnings)
#    225728    0.061    0.000    0.061    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.060    0.060 widgets.py:1(<module>)
#         2    0.000    0.000    0.060    0.030 executor.py:1(<module>)
#       206    0.026    0.000    0.060    0.000 <frozen _collections_abc>:288(__subclasshook__)
#        77    0.060    0.001    0.060    0.001 _validators.py:226(validate_bool_kwarg)
#         1    0.000    0.000    0.059    0.059 shape_prop.py:1(<module>)
#       131    0.001    0.000    0.059    0.000 _distn_infrastructure.py:830(_construct_doc)
#      7140    0.059    0.000    0.059    0.000 <frozen importlib._bootstrap>:79(__init__)
#         1    0.000    0.000    0.059    0.059 _memmapping_reducer.py:1(<module>)
#         1    0.000    0.000    0.058    0.058 collections.py:1(<module>)
#        23    0.000    0.000    0.058    0.003 managers.py:576(copy)
#         2    0.000    0.000    0.058    0.029 expr.py:1(<module>)
#         1    0.000    0.000    0.058    0.058 ctx_fp.py:1(<module>)
#         2    0.000    0.000    0.058    0.029 array.py:1(<module>)
#       473    0.057    0.000    0.057    0.000 {built-in method builtins.print}
#         3    0.000    0.000    0.057    0.019 numbers.py:1(<module>)
#  1225/876    0.001    0.000    0.057    0.000 typing.py:515(__getitem__)
#         1    0.000    0.000    0.056    0.056 polytools.py:1(<module>)
#        34    0.001    0.000    0.056    0.002 grad_mode.py:84(__exit__)
#       570    0.000    0.000    0.056    0.000 __init__.py:214(register)
#         1    0.000    0.000    0.056    0.056 arraylike.py:192(__sub__)
#         1    0.000    0.000    0.056    0.056 series.py:6152(_arith_method)
#         2    0.000    0.000    0.055    0.028 _support_alternative_backends.py:1(<module>)
#        68    0.001    0.000    0.055    0.001 grad_mode.py:184(__init__)
#       102    0.055    0.001    0.055    0.001 {built-in method torch.is_grad_enabled}
#         1    0.015    0.015    0.055    0.055 base.py:1380(_arith_method)
#         5    0.000    0.000    0.055    0.011 memory.py:1(<module>)
#       438    0.005    0.000    0.055    0.000 _docscrape.py:224(_parse_param_list)
#         1    0.000    0.000    0.054    0.054 ctx_base.py:1(<module>)
#       396    0.001    0.000    0.054    0.000 _compiler.py:573(_code)
#        61    0.001    0.000    0.053    0.001 typing_extensions.py:2942(__call__)
#         9    0.000    0.000    0.053    0.006 _base.py:783(__init_subclass__)
#     14006    0.026    0.000    0.053    0.000 inspect.py:2739(__init__)
#      5933    0.004    0.000    0.052    0.000 __init__.py:174(search)
#        34    0.052    0.002    0.052    0.002 {built-in method torch.ones_like}
#         2    0.000    0.000    0.052    0.026 constructor.py:1(<module>)
#         8    0.001    0.000    0.052    0.007 core.py:1(<module>)
#         1    0.000    0.000    0.052    0.052 fake_tensor.py:1(<module>)
#      4277    0.016    0.000    0.051    0.000 _ops.py:1137(_has_script_object_arg)
#         3    0.000    0.000    0.051    0.017 function.py:1(<module>)
#       325    0.003    0.000    0.050    0.000 dataclasses.py:568(_init_fn)
#        88    0.032    0.000    0.049    0.001 base.py:2320(is_unique)
#       834    0.005    0.000    0.049    0.000 typing.py:694(Union)
#         1    0.000    0.000    0.049    0.049 capi_maps.py:1(<module>)
#         1    0.000    0.000    0.048    0.048 _arraypad_impl.py:1(<module>)
#         1    0.000    0.000    0.047    0.047 point.py:1(<module>)
#         1    0.000    0.000    0.047    0.047 _cloudpickle_wrapper.py:1(<module>)
#         2    0.000    0.000    0.047    0.024 _adapters.py:1(<module>)
#        32    0.047    0.001    0.047    0.001 {built-in method torch.dot}
#         1    0.000    0.000    0.047    0.047 _distn_infrastructure.py:1(<module>)
#         1    0.000    0.000    0.047    0.047 immutable.py:1(<module>)
#      1389    0.007    0.000    0.046    0.000 typing.py:1269(__init__)
#         1    0.000    0.000    0.046    0.046 _index_tricks_impl.py:1(<module>)
#         6    0.000    0.000    0.045    0.008 linear_relu.py:1(<module>)
#         4    0.000    0.000    0.045    0.011 _internal.py:1(<module>)
#   128/117    0.001    0.000    0.045    0.000 _docstring.py:122(__call__)
#         1    0.000    0.000    0.045    0.045 dynamic_shapes.py:1(<module>)
#       320    0.007    0.000    0.045    0.000 <frozen importlib._bootstrap_external>:1644(_fill_cache)
#         1    0.000    0.000    0.045    0.045 entity.py:1(<module>)
#         1    0.000    0.000    0.045    0.045 _linprog.py:1(<module>)
#      4871    0.015    0.000    0.045    0.000 _docscrape.py:67(read_to_condition)
#       590    0.045    0.000    0.045    0.000 {built-in method numpy.empty}
#        71    0.000    0.000    0.045    0.001 managers.py:1801(_consolidate_inplace)
#         2    0.000    0.000    0.045    0.022 __init__.py:901(entry_points)
#         3    0.000    0.000    0.045    0.015 _basic.py:1(<module>)
#       457    0.007    0.000    0.044    0.000 wrappers.py:255(_out_wrapper)
#         4    0.000    0.000    0.044    0.011 managers.py:2278(_consolidate)
#         1    0.000    0.000    0.044    0.044 message.py:1(<module>)
#       112    0.000    0.000    0.044    0.000 __init__.py:910(<genexpr>)
#       418    0.001    0.000    0.044    0.000 linecache.py:52(checkcache)
#       131    0.001    0.000    0.043    0.000 traceback.py:221(extract_stack)
#         1    0.000    0.000    0.043    0.043 interpreter.py:1(<module>)
#         1    0.000    0.000    0.043    0.043 crackfortran.py:1(<module>)
#       131    0.000    0.000    0.042    0.000 traceback.py:377(extract)
#        31    0.006    0.000    0.042    0.001 __init__.py:887(_rc_params_in_file)
# 17820/16785    0.020    0.000    0.042    0.000 {built-in method __new__ of type object at 0x00007FFA720E38F0}
#       131    0.002    0.000    0.042    0.000 traceback.py:399(_extract_from_extended_frame_gen)
#       978    0.002    0.000    0.042    0.000 _ops.py:1146(__init__)
#  2863/396    0.016    0.000    0.041    0.000 _compiler.py:37(_compile)
#       127    0.001    0.000    0.040    0.000 library.py:95(__init__)
#         1    0.000    0.000    0.040    0.040 cm.py:32(_gen_cmap_registry)
#         1    0.000    0.000    0.039    0.039 _python_dispatch.py:1(<module>)
#        18    0.000    0.000    0.039    0.002 array_ops.py:189(_na_arithmetic_op)
#         1    0.000    0.000    0.039    0.039 exported_program.py:1(<module>)
#        18    0.000    0.000    0.039    0.002 expressions.py:226(evaluate)
#       831    0.001    0.000    0.039    0.000 base.py:912(__len__)
#        18    0.039    0.002    0.039    0.002 expressions.py:67(_evaluate_standard)
#         1    0.000    0.000    0.039    0.039 _registrations.py:1(<module>)
#         1    0.000    0.000    0.039    0.039 array_ops.py:240(arithmetic_op)
#         1    0.000    0.000    0.039    0.039 defmatrix.py:1(<module>)
#        39    0.001    0.000    0.039    0.001 colors.py:1081(from_list)
#      3616    0.003    0.000    0.039    0.000 _docscrape.py:77(read_to_next_empty_line)
#        30    0.038    0.001    0.038    0.001 {built-in method torch._C._get_tracing_state}
# 1441/1409    0.034    0.000    0.038    0.000 {built-in method numpy.asarray}
#      4581    0.021    0.000    0.038    0.000 functools.py:35(update_wrapper)
#         6    0.000    0.000    0.038    0.006 managers.py:2295(_merge_blocks)
#        47    0.000    0.000    0.038    0.001 fromnumeric.py:51(_wrapfunc)
#         6    0.000    0.000    0.038    0.006 fromnumeric.py:1129(argsort)
#         6    0.038    0.006    0.038    0.006 {method 'argsort' of 'numpy.ndarray' objects}
#      1617    0.028    0.000    0.038    0.000 {built-in method builtins.next}
#      3832    0.016    0.000    0.037    0.000 _docscrape.py:168(_is_at_section)
#        14    0.000    0.000    0.037    0.003 _docstring.py:73(__missing__)
#        43    0.000    0.000    0.037    0.001 dispatcher.py:147(_)
#      2666    0.001    0.000    0.037    0.000 <frozen importlib._bootstrap>:982(find_spec)
#       319    0.001    0.000    0.037    0.000 <frozen importlib._bootstrap_external>:1685(path_hook_for_FileFinder)
# 56059/56056    0.031    0.000    0.037    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.037    0.037 mul.py:1(<module>)
#        86    0.009    0.000    0.037    0.000 conflict.py:24(ambiguities)
#      5366    0.036    0.000    0.037    0.000 {method 'sub' of 're.Pattern' objects}
#         1    0.000    0.000    0.036    0.036 _invoke_quant.py:26(__init__)
#        24    0.001    0.000    0.036    0.002 _util.py:277(decorator)
#         3    0.000    0.000    0.036    0.012 _linalg.py:1(<module>)
#         2    0.000    0.000    0.036    0.018 indexing.py:1(<module>)
#         1    0.000    0.000    0.036    0.036 _unsupervised.py:1(<module>)
#       398    0.005    0.000    0.036    0.000 _util.py:511(getfullargspec_no_self)
#      1972    0.034    0.000    0.036    0.000 _ops.py:773(__init__)
#         1    0.000    0.000    0.035    0.035 _symbolic_trace.py:1(<module>)
#      2666    0.035    0.000    0.035    0.000 {built-in method _imp.is_builtin}
#         1    0.000    0.000    0.035    0.035 _invoke_quant.py:12(__init__)
#      2601    0.006    0.000    0.035    0.000 <frozen importlib._bootstrap_external>:1588(_get_spec)
#         1    0.000    0.000    0.035    0.035 autograd_function.py:1(<module>)
#         2    0.000    0.000    0.035    0.017 dense.py:1(<module>)
#         1    0.000    0.000    0.035    0.035 pairwise.py:1(<module>)
#       336    0.034    0.000    0.034    0.000 {built-in method nt.listdir}
#         1    0.000    0.000    0.034    0.034 _morestats.py:1(<module>)
#       319    0.002    0.000    0.034    0.000 <frozen zipimport>:64(__init__)
#        28    0.034    0.001    0.034    0.001 managers.py:2196(_grouping_func)
#         3    0.000    0.000    0.034    0.011 platform.py:1016(machine)
#         5    0.000    0.000    0.034    0.007 platform.py:890(uname)
#         2    0.000    0.000    0.034    0.017 model.py:1(<module>)
#         2    0.000    0.000    0.034    0.017 platform.py:322(_wmi_query)
#    137177    0.034    0.000    0.034    0.000 {method 'append' of 'list' objects}
#         2    0.034    0.017    0.034    0.017 {built-in method _wmi.exec_query}
#      2495    0.034    0.000    0.034    0.000 {method '__exit__' of '_io._IOBase' objects}
#        20    0.034    0.002    0.034    0.002 <frozen _collections_abc>:104(_check_methods)
#       113    0.000    0.000    0.034    0.000 custom_ops.py:902(get_library_allowing_overwrite)
#       322    0.001    0.000    0.034    0.000 dataclasses.py:627(_repr_fn)
#       328    0.001    0.000    0.034    0.000 dataclasses.py:661(_cmp_fn)
#         1    0.000    0.000    0.033    0.033 base_events.py:1(<module>)
#    146431    0.033    0.000    0.033    0.000 {method 'lstrip' of 'str' objects}
#         9    0.000    0.000    0.033    0.004 _typing.py:1(<module>)
#         1    0.000    0.000    0.033    0.033 _axes.py:67(Axes)
#        34    0.000    0.000    0.033    0.001 core.py:59(_)
#         1    0.000    0.000    0.033    0.033 art3d.py:1(<module>)
#         3    0.000    0.000    0.033    0.011 config.py:1(<module>)
#      7140    0.015    0.000    0.033    0.000 <frozen importlib._bootstrap>:426(_get_module_lock)
#        39    0.001    0.000    0.032    0.001 colors.py:419(to_rgba_array)
#         1    0.000    0.000    0.032    0.032 _new_distributions.py:1(<module>)
#       439    0.017    0.000    0.032    0.000 doccer.py:225(indentcount_lines)
#         1    0.000    0.000    0.032    0.032 von_mises.py:1(<module>)
#         3    0.000    0.000    0.032    0.011 _distribution_infrastructure.py:1317(_combine_docs)
#      1140    0.002    0.000    0.032    0.000 _ops.py:1387(_get_packet)
#         1    0.000    0.000    0.031    0.031 sympify.py:1(<module>)
#       123    0.014    0.000    0.031    0.000 pathlib.py:711(joinpath)
#       222    0.031    0.000    0.031    0.000 common.py:1341(is_ea_or_datetimelike_dtype)
#         1    0.000    0.000    0.031    0.031 _guards.py:1(<module>)
#         1    0.000    0.000    0.031    0.031 csvs.py:272(_save)
#        86    0.004    0.000    0.031    0.000 conflict.py:56(ordering)
#      4404    0.021    0.000    0.031    0.000 inspect.py:3025(__init__)
#        12    0.000    0.000    0.030    0.003 pathlib.py:719(__truediv__)
#     18498    0.026    0.000    0.030    0.000 _ops.py:1138(<genexpr>)
#         1    0.000    0.000    0.030    0.030 csvs.py:305(_save_body)
#       531    0.013    0.000    0.030    0.000 <frozen abc>:105(__new__)
#         1    0.001    0.001    0.030    0.030 csvs.py:315(_save_chunk)
#         1    0.000    0.000    0.030    0.030 reusable_executor.py:1(<module>)
#         1    0.000    0.000    0.030    0.030 _linprog_ip.py:1(<module>)
#         1    0.000    0.000    0.029    0.029 torchbind.py:1(<module>)
#       325    0.000    0.000    0.029    0.000 <frozen importlib._bootstrap_external>:164(_path_isdir)
#      3283    0.002    0.000    0.029    0.000 _ops.py:1160(<genexpr>)
#         1    0.000    0.000    0.029    0.029 slice.py:1(<module>)
#        96    0.001    0.000    0.029    0.000 _tensor.py:38(wrapped)
#         1    0.000    0.000    0.029    0.029 process_executor.py:1(<module>)
#      2601    0.010    0.000    0.028    0.000 <frozen importlib._bootstrap_external>:802(spec_from_file_location)
#         1    0.000    0.000    0.028    0.028 torchbind.py:30(__init__)
#        20    0.001    0.000    0.028    0.001 common.py:266(index_labels_to_array)
#        96    0.028    0.000    0.028    0.000 {method 'pow' of 'torch._C.TensorBase' objects}
#       228    0.010    0.000    0.028    0.000 __init__.py:355(namedtuple)
#      2835    0.028    0.000    0.028    0.000 {method 'findall' of 're.Pattern' objects}
#        12    0.000    0.000    0.028    0.002 common.py:1(<module>)
#        45    0.001    0.000    0.028    0.001 common.py:231(asarray_tuplesafe)
#      1819    0.002    0.000    0.028    0.000 _docscrape.py:573(dedent_lines)
#         1    0.000    0.000    0.028    0.028 _lazy_graph_module.py:1(<module>)
#         1    0.000    0.000    0.028    0.028 matexpr.py:1(<module>)
#      1140    0.028    0.000    0.028    0.000 {built-in method torch._C._jit_get_operation}
#         1    0.000    0.000    0.028    0.028 _jit_internal.py:1(<module>)
#       108    0.000    0.000    0.028    0.000 dataclasses.py:638(_frozen_get_del_attr)
#         1    0.000    0.000    0.027    0.027 matrixbase.py:1(<module>)
#         1    0.000    0.000    0.027    0.027 _json.py:1(<module>)
#         1    0.000    0.000    0.027    0.027 csvs.py:1(<module>)
#       133    0.004    0.000    0.027    0.000 enum.py:528(__new__)
#         2    0.000    0.000    0.027    0.013 core.py:198(read_style_directory)
#       131    0.002    0.000    0.027    0.000 _distn_infrastructure.py:749(_construct_argparser)
#         1    0.000    0.000    0.027    0.027 _linprog_util.py:1(<module>)
#         1    0.000    0.000    0.026    0.026 intersection.py:1(<module>)
#      4824    0.009    0.000    0.026    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#       169    0.022    0.000    0.026    0.000 {built-in method _io.open}
#  8349/217    0.012    0.000    0.026    0.000 copy.py:118(deepcopy)
#         1    0.000    0.000    0.026    0.026 simplify.py:1(<module>)
#         4    0.000    0.000    0.026    0.007 graph.py:1(<module>)
#         1    0.000    0.000    0.026    0.026 socket.py:1(<module>)
#         6    0.010    0.002    0.026    0.004 base.py:7836(get_values_for_csv)
#         1    0.000    0.000    0.026    0.026 graph_module.py:1(<module>)
#      7140    0.017    0.000    0.026    0.000 <frozen importlib._bootstrap>:372(release)
#         2    0.000    0.000    0.026    0.013 _ops.py:1(<module>)
#       110    0.000    0.000    0.026    0.000 __init__.py:469(entry_points)
#         6    0.000    0.000    0.026    0.004 rnn.py:1(<module>)
#         1    0.000    0.000    0.025    0.025 _remove_redundancy.py:1(<module>)
#         2    0.000    0.000    0.025    0.013 loader.py:1(<module>)
#   442/217    0.003    0.000    0.025    0.000 copy.py:217(_deepcopy_dict)
#         1    0.000    0.000    0.025    0.025 _minimize.py:1(<module>)
#    107378    0.025    0.000    0.025    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.025    0.025 geo.py:1(<module>)
#       216    0.001    0.000    0.025    0.000 _docscrape.py:366(_parse_summary)
#      6054    0.008    0.000    0.025    0.000 typing.py:1546(__getitem__)
#       267    0.001    0.000    0.025    0.000 _meta_registrations.py:55(wrapper)
#         1    0.000    0.000    0.024    0.024 algorithms.py:1(<module>)
#         1    0.000    0.000    0.024    0.024 interpolative.py:1(<module>)
#        23    0.000    0.000    0.024    0.001 _support_alternative_backends.py:46(wrapper)
#         6    0.000    0.000    0.024    0.004 _docscrape.py:626(__init__)
#         1    0.000    0.000    0.024    0.024 _mgc.py:1(<module>)
#       349    0.001    0.000    0.024    0.000 typing.py:747(Optional)
#     78751    0.024    0.000    0.024    0.000 {method 'endswith' of 'str' objects}
#      3159    0.024    0.000    0.024    0.000 {built-in method torch._C._dispatch_has_kernel_for_dispatch_key}
# 10249/4033    0.014    0.000    0.023    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.023    0.023 products.py:1(<module>)
#         1    0.000    0.000    0.023    0.023 rnn.py:1165(GRU)
#      5923    0.002    0.000    0.023    0.000 conflict.py:19(ambiguous)
#     10377    0.023    0.000    0.023    0.000 {method 'search' of 're.Pattern' objects}
#         1    0.000    0.000    0.023    0.023 platform.py:446(win32_ver)
#         1    0.000    0.000    0.023    0.023 platform.py:384(_win32_ver)
#         1    0.000    0.000    0.023    0.023 Image.py:1(<module>)
#         1    0.000    0.000    0.023    0.023 descriptors.py:1(<module>)
#        14    0.001    0.000    0.023    0.002 _ufunc_config.py:472(inner)
#      2529    0.002    0.000    0.023    0.000 __init__.py:179(sub)
#        15    0.023    0.002    0.023    0.002 {built-in method torch.min}
#     12694    0.005    0.000    0.023    0.000 conflict.py:43(edge)
#         3    0.000    0.000    0.023    0.008 series.py:1(<module>)
#     14843    0.014    0.000    0.022    0.000 enum.py:726(__call__)
#         1    0.000    0.000    0.022    0.022 _discrete_distns.py:1(<module>)
#        23    0.022    0.001    0.022    0.001 {method 'reset' of '_contextvars.ContextVar' objects}
#       210    0.007    0.000    0.022    0.000 numeric.py:324(full)
#       533    0.022    0.000    0.022    0.000 {built-in method builtins.dir}
#         2    0.000    0.000    0.022    0.011 bn_relu.py:1(<module>)
#       111    0.001    0.000    0.022    0.000 __init__.py:811(read_text)
#      3169    0.008    0.000    0.022    0.000 typing.py:175(_type_check)
#         1    0.000    0.000    0.022    0.022 font_manager.py:1(<module>)
#         1    0.000    0.000    0.022    0.022 power.py:1(<module>)
#       228    0.001    0.000    0.022    0.000 function.py:164(__init__)
#         1    0.000    0.000    0.021    0.021 offsetbox.py:1(<module>)
#         1    0.000    0.000    0.021    0.021 common.py:605(check_parent_directory)
#         1    0.000    0.000    0.021    0.021 rnn.py:800(LSTM)
#         7    0.021    0.003    0.021    0.003 pathlib.py:731(parent)
#       450    0.002    0.000    0.021    0.000 frame.py:4637(_get_item_cache)
#       131    0.001    0.000    0.020    0.000 _distn_infrastructure.py:735(_attach_argparser_methods)
#         2    0.000    0.000    0.020    0.010 conv_fused.py:1(<module>)
#         3    0.000    0.000    0.020    0.007 {method 'std' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.020    0.007 _methods.py:220(_std)
#       200    0.001    0.000    0.020    0.000 pyplot.py:175(_copy_docstring_and_deprecators)
#         3    0.020    0.007    0.020    0.007 _methods.py:150(_var)
#         1    0.000    0.000    0.020    0.020 axis.py:1(<module>)
#       113    0.000    0.000    0.020    0.000 pathlib.py:1022(read_text)
#         5    0.000    0.000    0.020    0.004 transforms.py:1(<module>)
#         1    0.000    0.000    0.020    0.020 readers.py:1(<module>)
#         1    0.000    0.000    0.020    0.020 rnn.py:470(RNN)
#        18    0.000    0.000    0.020    0.001 frame.py:5658(rename)
#       110    0.001    0.000    0.020    0.000 _distn_infrastructure.py:1923(_attach_methods)
#        18    0.000    0.000    0.020    0.001 generic.py:1073(_rename)
#        21    0.000    0.000    0.020    0.001 _distn_infrastructure.py:3319(__init__)
#         2    0.000    0.000    0.020    0.010 format.py:1(<module>)
#        80    0.019    0.000    0.019    0.000 generic.py:589(_get_axis)
#         2    0.019    0.010    0.019    0.010 {built-in method _codecs.lookup_error}
#         1    0.000    0.000    0.019    0.019 summations.py:1(<module>)
#      9178    0.010    0.000    0.019    0.000 typing.py:1215(__setattr__)
#      5923    0.009    0.000    0.019    0.000 conflict.py:12(consistent)
#     41511    0.016    0.000    0.019    0.000 {built-in method builtins.setattr}
#         2    0.000    0.000    0.019    0.010 _delegation.py:1(<module>)
# 23174/23173    0.007    0.000    0.019    0.000 {built-in method builtins.all}
#      2920    0.002    0.000    0.019    0.000 <frozen importlib._bootstrap_external>:185(_path_abspath)
#     15261    0.012    0.000    0.019    0.000 conflict.py:7(supercedes)
#        30    0.019    0.001    0.019    0.001 {method 'dim' of 'torch._C.TensorBase' objects}
#       463    0.002    0.000    0.019    0.000 frame.py:3994(_ixs)
#         1    0.000    0.000    0.019    0.019 matmul.py:1(<module>)
#     66/64    0.000    0.000    0.018    0.000 missing.py:101(isna)
#         2    0.000    0.000    0.018    0.009 managers.py:1421(_insert_update_mgr_locs)
#       270    0.002    0.000    0.018    0.000 _decorators.py:363(decorator)
#         2    0.018    0.009    0.018    0.009 managers.py:2330(_fast_count_smallints)
#     66/64    0.000    0.000    0.018    0.000 missing.py:184(_isna)
#         4    0.000    0.000    0.018    0.005 basic.py:1(<module>)
#       165    0.000    0.000    0.018    0.000 pathlib.py:380(with_segments)
#       112    0.001    0.000    0.018    0.000 _itertools.py:4(unique_everseen)
#        28    0.000    0.000    0.018    0.001 managers.py:317(apply)
#       353    0.000    0.000    0.018    0.000 _meta_registrations.py:58(register)
#         1    0.000    0.000    0.018    0.018 describe.py:1(<module>)
#         1    0.000    0.000    0.018    0.018 lines.py:1(<module>)
#         4    0.000    0.000    0.018    0.004 _aliases.py:1(<module>)
#       456    0.001    0.000    0.018    0.000 artist.py:1530(number_of_parameters)
#       236    0.017    0.000    0.018    0.000 pathlib.py:1157(__init__)
#         2    0.000    0.000    0.018    0.009 quantization_mappings.py:1(<module>)
#         1    0.000    0.000    0.018    0.018 __init__.py:2817(_import_device_backends)
#      1844    0.004    0.000    0.018    0.000 series.py:1107(__getitem__)
#      5576    0.008    0.000    0.018    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.018    0.018 polar.py:1(<module>)
#         1    0.000    0.000    0.017    0.017 _rotation_groups.py:1(<module>)
#        88    0.015    0.000    0.017    0.000 base.py:843(_engine)
#       228    0.001    0.000    0.017    0.000 function.py:124(arity)
#         2    0.000    0.000    0.017    0.009 resource_tracker.py:1(<module>)
#      2920    0.007    0.000    0.017    0.000 <frozen importlib._bootstrap_external>:172(_path_isabs)
#     19555    0.017    0.000    0.017    0.000 {method 'split' of 'str' objects}
#       113    0.000    0.000    0.017    0.000 pathlib.py:1005(open)
#         1    0.000    0.000    0.017    0.017 dataframes.py:1(<module>)
#      1984    0.017    0.000    0.017    0.000 {built-in method torch._C._get_operation_overload}
#       210    0.002    0.000    0.017    0.000 _docscrape.py:599(__str__)
#        94    0.001    0.000    0.017    0.000 __init__.py:1450(_preprocess_data)
#         1    0.000    0.000    0.017    0.017 plot.py:1(<module>)
#         1    0.000    0.000    0.017    0.017 string_.py:1(<module>)
#     61326    0.016    0.000    0.016    0.000 {method 'get' of 'dict' objects}
#        26    0.000    0.000    0.016    0.001 _jit_internal.py:995(_check_overload_body)
#        43    0.016    0.000    0.016    0.000 missing.py:261(_isna_array)
#        26    0.000    0.000    0.016    0.001 _sources.py:120(parse_def)
#        93    0.001    0.000    0.016    0.000 typing.py:2790(_make_nmtuple)
#        26    0.000    0.000    0.016    0.001 _sources.py:103(make_source_context)
#         1    0.000    0.000    0.016    0.016 frame.py:1404(_get_values_for_csv)
#         1    0.000    0.000    0.016    0.016 managers.py:478(get_values_for_csv)
#         4    0.000    0.000    0.016    0.004 blocks.py:801(get_values_for_csv)
#         1    0.000    0.000    0.016    0.016 _root.py:1(<module>)
#      1033    0.009    0.000    0.016    0.000 enum.py:254(__set_name__)
#         3    0.000    0.000    0.016    0.005 datetimes.py:1(<module>)
#        20    0.001    0.000    0.016    0.001 indexing.py:1177(__getitem__)
#       129    0.008    0.000    0.016    0.000 library.py:137(define)
#      2644    0.002    0.000    0.016    0.000 <frozen importlib._bootstrap>:1128(find_spec)
#         1    0.000    0.000    0.016    0.016 library.py:1(<module>)
#       984    0.001    0.000    0.015    0.000 artist.py:1536(is_alias)
#       113    0.015    0.000    0.015    0.000 {method 'unsqueeze' of 'torch._C.TensorBase' objects}
# ...
#         1    0.000    0.000    0.000    0.000 exceptions.py:200(DTypePromotionError)
#         1    0.000    0.000    0.000    0.000 pickle.py:84(UnpicklingError)
#         1    0.000    0.000    0.000    0.000 __init__.py:178(c_ulong)
#         1    0.000    0.000    0.000    0.000 __init__.py:203(c_longdouble)
#         1    0.000    0.000    0.000    0.000 __init__.py:217(c_ulonglong)
#         1    0.000    0.000    0.000    0.000 __init__.py:224(c_ubyte)
#         1    0.000    0.000    0.000    0.000 __init__.py:231(c_byte)
#         1    0.000    0.000    0.000    0.000 __init__.py:252(c_bool)
#         1    0.000    0.000    0.000    0.000 __init__.py:262(c_wchar)
#         1    0.000    0.000    0.000    0.000 _endian.py:34(_swapped_struct_meta)
#         1    0.000    0.000    0.000    0.000 _nbit_base.py:81(_32Bit)
#         1    0.000    0.000    0.000    0.000 _nbit_base.py:86(_16Bit)
#         1    0.000    0.000    0.000    0.000 _nbit_base.py:91(_8Bit)
#         1    0.000    0.000    0.000    0.000 _iotools.py:439(ConversionWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:42(AmbiguousTimeError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:53(NonExistentTimeError)
#         1    0.000    0.000    0.000    0.000 threading.py:833(BrokenBarrierError)
#         1    0.000    0.000    0.000    0.000 _tzpath.py:36(_parse_python_tzpath)
#         1    0.000    0.000    0.000    0.000 config_init.py:512(is_valid_string_storage)
#         1    0.000    0.000    0.000    0.000 six.py:480(Module_six_moves_urllib_robotparser)
#         1    0.000    0.000    0.000    0.000 calendar.py:201(setfirstweekday)
#         1    0.000    0.000    0.000    0.000 __init__.py:46(PerformanceWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:118(ParserError)
#         1    0.000    0.000    0.000    0.000 __init__.py:143(DtypeWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:212(ParserWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:253(MergeError)
#         1    0.000    0.000    0.000    0.000 __init__.py:311(NumbaUtilError)
#         1    0.000    0.000    0.000    0.000 __init__.py:328(DuplicateLabelError)
#         1    0.000    0.000    0.000    0.000 __init__.py:347(InvalidIndexError)
#         1    0.000    0.000    0.000    0.000 __init__.py:367(DataError)
#         1    0.000    0.000    0.000    0.000 __init__.py:455(ChainedAssignmentError)
#         1    0.000    0.000    0.000    0.000 __init__.py:553(NumExprClobberingError)
#         1    0.000    0.000    0.000    0.000 __init__.py:641(CSSWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:662(PossibleDataLossError)
#         1    0.000    0.000    0.000    0.000 __init__.py:687(IncompatibilityWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:693(AttributeConflictWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:714(DatabaseError)
#         1    0.000    0.000    0.000    0.000 __init__.py:727(PossiblePrecisionLoss)
#         1    0.000    0.000    0.000    0.000 __init__.py:742(ValueLabelTypeMismatch)
#         1    0.000    0.000    0.000    0.000 __init__.py:754(InvalidColumnName)
#         1    0.000    0.000    0.000    0.000 __init__.py:769(CategoricalConversionWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:793(NoBufferPresent)
#         1    0.000    0.000    0.000    0.000 extras.py:357(_fromnxfunction_allargs)
#         1    0.000    0.000    0.000    0.000 nanops.py:57(set_use_bottleneck)
#         1    0.000    0.000    0.000    0.000 shutil.py:80(ReadError)
#         1    0.000    0.000    0.000    0.000 shutil.py:83(RegistryError)
#         1    0.000    0.000    0.000    0.000 shutil.py:87(_GiveupOnFastCopy)
#         1    0.000    0.000    0.000    0.000 range.py:216(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 format.py:531(_initialize_formatters)
#         1    0.000    0.000    0.000    0.000 format.py:612(_adjust_max_rows)
#         1    0.000    0.000    0.000    0.000 gzip.py:120(BadGzipFile)
#         1    0.000    0.000    0.000    0.000 tarfile.py:276(ReadError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:288(EmptyHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:294(EOFHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:297(InvalidHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:300(SubsequentHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:723(FilterError)
#         1    0.000    0.000    0.000    0.000 expr.py:320(add_ops)
#         1    0.000    0.000    0.000    0.000 _version_meson.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 unicode.py:304(CJK)
#         1    0.000    0.000    0.000    0.000 errors.py:16(HeaderParseError)
#         1    0.000    0.000    0.000    0.000 errors.py:20(BoundaryError)
#         1    0.000    0.000    0.000    0.000 errors.py:28(CharsetError)
#         1    0.000    0.000    0.000    0.000 errors.py:32(HeaderWriteError)
#         1    0.000    0.000    0.000    0.000 errors.py:45(NoBoundaryInMultipartDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:51(CloseBoundaryNotFoundDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:54(FirstHeaderLineIsContinuationDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:57(MisplacedEnvelopeHeaderDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:60(MissingHeaderBodySeparatorDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:65(MultipartInvariantViolationDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:68(InvalidMultipartContentTransferEncodingDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:71(UndecodableBytesDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:77(InvalidBase64CharactersDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:80(InvalidBase64LengthDefect)
#         1    0.000    0.000    0.000    0.000 exceptions.py:40(UnknownEditVariable)
#         1    0.000    0.000    0.000    0.000 errors.py:91(InvalidHeaderDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:94(HeaderMissingRequiredValue)
#         1    0.000    0.000    0.000    0.000 errors.py:111(NonASCIILocalPartDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:116(InvalidDateDefect)
#         1    0.000    0.000    0.000    0.000 cp1251.py:25(StreamWriter)
#         1    0.000    0.000    0.000    0.000 cp1251.py:28(StreamReader)
#         1    0.000    0.000    0.000    0.000 patches.py:3544(CurveFilledB)
#         1    0.000    0.000    0.000    0.000 _mathtext.py:960(DejaVuSerifFontConstants)
#         1    0.000    0.000    0.000    0.000 _mathtext.py:964(DejaVuSansFontConstants)
#         1    0.000    0.000    0.000    0.000 streamplot.py:434(InvalidIndexError)
#         1    0.000    0.000    0.000    0.000 streamplot.py:510(OutOfBounds)
#         1    0.000    0.000    0.000    0.000 glob.py:214(_join)
#         1    0.000    0.000    0.000    0.000 typing_extensions.py:2098(_EllipsisDummy)
#         1    0.000    0.000    0.000    0.000 _distribution_infrastructure.py:1823(tol)
#         1    0.000    0.000    0.000    0.000 _base.py:49(CancelledError)
#         1    0.000    0.000    0.000    0.000 _base.py:55(InvalidStateError)
#         1    0.000    0.000    0.000    0.000 events.py:734(_RunningLoop)
#         1    0.000    0.000    0.000    0.000 exceptions.py:61(BrokenBarrierError)
#         1    0.000    0.000    0.000    0.000 windows_events.py:306(_WindowsSelectorEventLoop)
#         1    0.000    0.000    0.000    0.000 context.py:20(TimeoutError)
#         1    0.000    0.000    0.000    0.000 context.py:23(AuthenticationError)
#         1    0.000    0.000    0.000    0.000 distributed_c10d.py:735(GroupMember)
#         1    0.000    0.000    0.000    0.000 dataframes.py:385(CaptureDataFrame)
#         1    0.000    0.000    0.000    0.000 _typing.py:38(Integer)
#         1    0.000    0.000    0.000    0.000 package_importer.py:714(_ExternNode)
#         1    0.000    0.000    0.000    0.000 __init__.py:17(is_available)
#         1    0.000    0.000    0.000    0.000 __init__.py:91(__init__)
#         1    0.000    0.000    0.000    0.000 _script.py:347(ScriptWarning)
#         1    0.000    0.000    0.000    0.000 frontend.py:178(FrontendTypeError)
#         1    0.000    0.000    0.000    0.000 client.py:1482(HTTPException)
#         1    0.000    0.000    0.000    0.000 client.py:1487(NotConnected)
#         1    0.000    0.000    0.000    0.000 client.py:1490(InvalidURL)
#         1    0.000    0.000    0.000    0.000 client.py:1498(UnknownTransferEncoding)
#         1    0.000    0.000    0.000    0.000 client.py:1518(ImproperConnectionState)
#         1    0.000    0.000    0.000    0.000 client.py:1521(CannotSendRequest)
#         1    0.000    0.000    0.000    0.000 client.py:1527(ResponseNotReady)
#         1    0.000    0.000    0.000    0.000 mock.py:2170(AsyncMagicMixin)
#         1    0.000    0.000    0.000    0.000 checkpoint.py:987(CheckpointError)
#         1    0.000    0.000    0.000    0.000 verifier.py:330(TrainingIRVerifier)
#         1    0.000    0.000    0.000    0.000 exceptions.py:76(DataConversionWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:94(DataDimensionalityWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:108(EfficiencyWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:131(SkipTestWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:140(UndefinedMetricWarning)
#         1    0.000    0.000    0.000    0.000 _pep440.py:150(<lambda>)
#         1    0.000    0.000    0.000    0.000 _csr.py:437(csr_matrix)
#         1    0.000    0.000    0.000    0.000 process_executor.py:1025(BrokenProcessPool)
#         1    0.000    0.000    0.000    0.000 process_executor.py:1034(TerminatedWorkerError)
#         1    0.000    0.000    0.000    0.000 process_executor.py:1046(ShutdownExecutorError)
#         1    0.000    0.000    0.000    0.000 function.py:118(BadArgumentsError)
#         1    0.000    0.000    0.000    0.000 boolalg.py:446(__eq__)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:67(HeuristicGCDFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:71(ModularGCDFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:74(HomomorphismFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:78(IsomorphismFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:82(ExtraneousFactors)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:86(EvaluationFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:90(RefinementFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:98(NotInvertible)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:102(NotReversible)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:110(DomainError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:118(UnificationFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:128(GeneratorsError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:132(GeneratorsNeeded)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:151(MultivariatePolynomialError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:177(OptionError)
#         1    0.000    0.000    0.000    0.000 rationalfield.py:45(__init__)
#         1    0.000    0.000    0.000    0.000 expressionrawdomain.py:28(__init__)
#         1    0.000    0.000    0.000    0.000 alphabets.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 exceptions.py:33(DMFormatError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:38(DMNonInvertibleMatrixError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:43(DMRankError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:48(DMShapeError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:53(DMNonSquareMatrixError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:58(DMValueError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:15(NonSquareMatrixError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:19(NonInvertibleMatrixError)
#         1    0.000    0.000    0.000    0.000 modules.py:1096(ModuleOrder)
#         1    0.000    0.000    0.000    0.000 systems.py:37(ODENonlinearError)
#         1    0.000    0.000    0.000    0.000 simplex.py:96(InfeasibleLPError)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_native_id}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy._core._multiarray_umath._set_madvise_hugepage}
#         1    0.000    0.000    0.000    0.000 tokens.py:45(BlockMappingStartToken)
#         1    0.000    0.000    0.000    0.000 tokens.py:48(BlockEndToken)
#         1    0.000    0.000    0.000    0.000 tokens.py:72(FlowEntryToken)
#         1    0.000    0.000    0.000    0.000 events.py:31(CollectionEndEvent)
#         1    0.000    0.000    0.000    0.000 events.py:84(MappingEndEvent)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2584(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 __init__.py:213(c_longlong)
#         1    0.000    0.000    0.000    0.000 random.py:903(seed)
#         1    0.000    0.000    0.000    0.000 config_init.py:673(register_plotting_backend_cb)
#         1    0.000    0.000    0.000    0.000 six.py:239(exec_module)
#         1    0.000    0.000    0.000    0.000 __init__.py:198(EmptyDataError)
#         1    0.000    0.000    0.000    0.000 __init__.py:411(SettingWithCopyError)
#         1    0.000    0.000    0.000    0.000 __init__.py:433(SettingWithCopyWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:598(IndexingError)
#         1    0.000    0.000    0.000    0.000 __init__.py:783(LossySetitemError)
#         1    0.000    0.000    0.000    0.000 base.py:1986(nlevels)
#         1    0.000    0.000    0.000    0.000 managers.py:1847(ndim)
#         1    0.000    0.000    0.000    0.000 tarfile.py:282(StreamError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:285(HeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:291(TruncatedHeaderError)
#         1    0.000    0.000    0.000    0.000 errors.py:24(MultipartConversionError)
#         1    0.000    0.000    0.000    0.000 errors.py:48(StartBoundaryNotFoundDefect)
#         2    0.000    0.000    0.000    0.000 _functools.py:83(<lambda>)
#         1    0.000    0.000    0.000    0.000 streamplot.py:438(TerminateTrajectory)
#         1    0.000    0.000    0.000    0.000 _new_distributions.py:96(_mode_formula)
#         1    0.000    0.000    0.000    0.000 client.py:1501(UnimplementedFileMode)
#         1    0.000    0.000    0.000    0.000 client.py:1524(CannotSendHeader)
#         1    0.000    0.000    0.000    0.000 _environment.py:1(is_fbcode)
#         1    0.000    0.000    0.000    0.000 exceptions.py:119(FitFailedWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:148(PositiveSpectrumWarning)
#         1    0.000    0.000    0.000    0.000 release.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:106(NotAlgebraic)
#         1    0.000    0.000    0.000    0.000 integerring.py:51(__init__)
#         1    0.000    0.000    0.000    0.000 gaussiandomains.py:442(__init__)
#         1    0.000    0.000    0.000    0.000 gaussiandomains.py:647(__init__)
#         1    0.000    0.000    0.000    0.000 expressiondomain.py:163(__init__)
#         1    0.000    0.000    0.000    0.000 readers.py:1987(__enter__)
#         1    0.000    0.000    0.000    0.000 _new_distributions.py:93(_median_formula)
#         1    0.000    0.000    0.000    0.000 expr.py:1021(_eval_power)
#       1/0    0.000    0.000    0.000          custom_ops.py:144(inner)
#    3876/0    0.162    0.000    0.000          {built-in method builtins.exec}

# %%
p = pstats.Stats('profiling_results/comb_full_opt')
p.strip_dirs().sort_stats("cumulative").print_stats()
# Out:
# Wed Dec 17 19:03:42 2025    profiling_results/comb_full_opt
#
#          4054962 function calls (3987007 primitive calls) in 288.445 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.128    0.128  256.872  256.872 script.py:154(main)
#        17    1.416    0.083  254.047   14.944 model.py:87(fit)
#         3    0.888    0.296  203.758   67.919 script.py:121(cv_rmse_for_nterm_on_train)
#        17    2.446    0.144  125.798    7.400 FeatureSpaceConstruction.py:548(feature_space)
#        34   52.331    1.539  112.626    3.313 FeatureSpaceConstruction.py:374(combinations)
#        17   11.038    0.649  111.638    6.567 Regressor.py:25(__init__)
#        17   91.400    5.376   91.400    5.376 {method 'std' of 'torch._C.TensorBase' objects}
#       353    0.041    0.000   71.141    0.202 __init__.py:1(<module>)
#       341   20.725    0.061   20.725    0.061 {built-in method torch.cat}
#        68   16.613    0.244   16.613    0.244 {built-in method torch.isinf}
#        17    1.148    0.068   14.539    0.855 Regressor.py:182(regressor_fit)
#       102   14.108    0.138   14.108    0.138 {method 'any' of 'torch._C.TensorBase' objects}
# 2610/2518    0.006    0.000   12.696    0.005 <frozen importlib._bootstrap>:806(module_from_spec)
#   188/186    0.001    0.000   12.591    0.068 <frozen importlib._bootstrap_external>:1287(create_module)
#   188/186   12.263    0.065   12.590    0.068 {built-in method _imp.create_dynamic}
#         1    0.000    0.000   11.060   11.060 Regressor_dimension.py:1(<module>)
#         1    0.001    0.001    9.457    9.457 _stats_py.py:1(<module>)
#        13    0.001    0.000    9.141    0.703 _jit_internal.py:1027(_overload)
#       130    8.087    0.062    8.087    0.062 {built-in method torch.isnan}
#      2394    0.033    0.000    7.344    0.003 <frozen importlib._bootstrap_external>:1062(get_code)
#      2396    0.012    0.000    6.418    0.003 <frozen importlib._bootstrap_external>:1183(get_data)
#   188/131    0.000    0.000    5.364    0.041 <frozen importlib._bootstrap_external>:1295(exec_module)
#   188/131    0.194    0.001    5.363    0.041 {built-in method _imp.exec_dynamic}
#        47    4.991    0.106    4.991    0.106 {built-in method torch.mm}
#        66    4.957    0.075    4.957    0.075 {method 'mean' of 'torch._C.TensorBase' objects}
#        34    4.901    0.144    4.901    0.144 {method 'clone' of 'torch._C.TensorBase' objects}
#      2396    4.718    0.002    4.718    0.002 {method 'read' of '_io.BufferedReader' objects}
#    211/83    0.003    0.000    4.676    0.056 _ops.py:370(fallthrough)
#        17    4.032    0.237    4.032    0.237 {built-in method torch.clone}
#        49    3.874    0.079    3.874    0.079 {built-in method torch._C._linalg.linalg_lstsq}
#         1    3.444    3.444    3.508    3.508 __init__.py:162(_load_dll_libraries)
#        15    0.189    0.013    3.170    0.211 Regressor.py:92(higher_dimension)
#         8    0.000    0.000    2.758    0.345 api.py:1(<module>)
#       203    2.489    0.012    2.489    0.012 {method 'tolist' of 'torch._C.TensorBase' objects}
#      2647    0.029    0.000    2.239    0.001 <frozen importlib._bootstrap>:1240(_find_spec)
#      2624    0.003    0.000    2.179    0.001 <frozen importlib._bootstrap_external>:1520(find_spec)
#      2624    0.008    0.000    2.176    0.001 <frozen importlib._bootstrap_external>:1491(_get_spec)
#     10037    2.165    0.000    2.165    0.000 {built-in method nt.stat}
#      9573    0.007    0.000    2.123    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#         1    0.000    0.000    2.105    2.105 DimensionalFeatureSpaceConstruction.py:1(<module>)
#      3197    0.036    0.000    2.087    0.001 <frozen importlib._bootstrap_external>:1593(find_spec)
#         2    0.000    0.000    2.086    1.043 model.py:1(<module>)
#        32    1.892    0.059    1.892    0.059 {built-in method torch.topk}
#    952/22    0.003    0.000    1.683    0.076 {built-in method builtins.__import__}
# 56695/55292    0.025    0.000    1.643    0.000 {built-in method builtins.hasattr}
#   2778/85    0.007    0.000    1.618    0.019 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#      2396    1.611    0.001    1.611    0.001 {built-in method _io.open_code}
#     40/39    0.000    0.000    1.610    0.041 __init__.py:73(import_module)
#     40/39    0.000    0.000    1.610    0.041 <frozen importlib._bootstrap>:1375(_gcd_import)
#      2067    1.599    0.001    1.602    0.001 {method 'extend' of 'list' objects}
#     31/30    0.000    0.000    1.571    0.052 __init__.py:141(__getattr__)
#      3662    0.006    0.000    1.514    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#         1    0.000    0.000    1.493    1.493 distributions.py:1(<module>)
#      3336    0.003    0.000    1.487    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#         1    0.000    0.000    1.338    1.338 _geometric_slerp.py:1(<module>)
#         2    0.000    0.000    1.334    0.667 _misc.py:1(<module>)
#         2    0.000    0.000    1.320    0.660 distance.py:1(<module>)
#         1    0.000    0.000    1.260    1.260 pyplot.py:1(<module>)
#      10/8    0.000    0.000    1.245    0.156 _ops.py:172(py_functionalize_impl)
#    171/58    0.024    0.000    1.243    0.021 _ops.py:308(py_impl)
#         3    0.000    0.000    1.133    0.378 __config__.py:1(<module>)
#         1    0.000    0.000    1.115    1.115 blas.py:1(<module>)
#        15    1.069    0.071    1.069    0.071 {built-in method gc.collect}
# 5490/5358    0.087    0.000    1.042    0.000 {built-in method builtins.__build_class__}
#        11    0.001    0.000    1.033    0.094 base.py:1(<module>)
#        11    0.000    0.000    1.033    0.094 __init__.py:720(__getattr__)
#         1    0.000    0.000    1.033    1.033 multiarray.py:1(<module>)
#       167    1.005    0.006    1.010    0.006 {built-in method _io.open}
#         3    0.000    0.000    0.948    0.316 generic.py:1(<module>)
#       6/5    0.000    0.000    0.896    0.179 _ops.py:321(py_autograd_impl)
#        34    0.214    0.006    0.876    0.026 FeatureSpaceConstruction.py:155(single_variable)
#        49    0.849    0.017    0.849    0.017 {built-in method torch.combinations}
#        51    0.809    0.016    0.822    0.016 {built-in method torch.tensor}
#         2    0.000    0.000    0.804    0.402 batchnorm.py:1(<module>)
#         2    0.000    0.000    0.804    0.402 _functions.py:1(<module>)
#         1    0.000    0.000    0.794    0.794 _classification_threshold.py:1(<module>)
#         1    0.001    0.001    0.786    0.786 _continuous_distns.py:1(<module>)
#         2    0.000    0.000    0.772    0.386 _array_api.py:1(<module>)
#         7    0.000    0.000    0.754    0.108 _base.py:1(<module>)
#         1    0.000    0.000    0.749    0.749 _linprog.py:1(<module>)
#         1    0.000    0.000    0.740    0.740 polyfuncs.py:1(<module>)
#         1    0.000    0.000    0.739    0.739 specialpolys.py:1(<module>)
#         1    0.000    0.000    0.672    0.672 _unsupervised.py:1(<module>)
#         1    0.000    0.000    0.670    0.670 pairwise.py:1(<module>)
#         1    0.000    0.000    0.662    0.662 _sputils.py:1(<module>)
#         1    0.000    0.000    0.661    0.661 _optimize.py:1(<module>)
#         4    0.000    0.000    0.659    0.165 _util.py:1(<module>)
#       113    0.002    0.000    0.656    0.006 custom_ops.py:185(__init__)
#        17    0.025    0.001    0.655    0.039 FeatureSpaceConstruction.py:30(__init__)
#       113    0.000    0.000    0.651    0.006 custom_ops.py:598(_register_to_dispatcher)
#         1    0.000    0.000    0.648    0.648 rings.py:1(<module>)
#        37    0.000    0.000    0.598    0.016 frame.py:5455(drop)
#        37    0.001    0.000    0.597    0.016 generic.py:4779(drop)
#         1    0.000    0.000    0.580    0.580 image.py:1(<module>)
#        37    0.002    0.000    0.565    0.015 generic.py:4818(_drop_axis)
#         1    0.000    0.000    0.562    0.562 backend_bases.py:1(<module>)
#       113    0.001    0.000    0.536    0.005 library.py:187(_register_fake)
#         1    0.000    0.000    0.530    0.530 _chunking.py:1(<module>)
#         1    0.000    0.000    0.528    0.528 _param_validation.py:1(<module>)
#         1    0.000    0.000    0.521    0.521 validation.py:1(<module>)
#         1    0.000    0.000    0.515    0.515 _multicomp.py:1(<module>)
#         3    0.000    0.000    0.513    0.171 config.py:1(<module>)
#       141    0.001    0.000    0.510    0.004 inspect.py:1070(findsource)
#      2392    0.187    0.000    0.504    0.000 <frozen importlib._bootstrap_external>:751(_compile_bytecode)
#         1    0.000    0.000    0.499    0.499 _dispatcher.py:1(<module>)
#         1    0.000    0.000    0.498    0.498 _qmc.py:1(<module>)
#         1    0.000    0.000    0.494    0.494 _linprog_highs.py:1(<module>)
#         1    0.000    0.000    0.491    0.491 _highs_wrapper.py:1(<module>)
#         1    0.000    0.000    0.488    0.488 _distn_infrastructure.py:1(<module>)
#     26/10    0.000    0.000    0.483    0.048 _ops.py:280(__init__)
#    343/62    0.030    0.000    0.470    0.008 library.py:287(impl)
#        10    0.000    0.000    0.466    0.047 linear.py:1(<module>)
#         9    0.000    0.000    0.463    0.051 _typing.py:1(<module>)
#     83/18    0.001    0.000    0.457    0.025 custom_ops.py:334(inner)
#        34    0.456    0.013    0.456    0.013 {method 'nonzero' of 'torch._C.TensorBase' objects}
#         1    0.000    0.000    0.454    0.454 frame.py:1(<module>)
#       113    0.001    0.000    0.450    0.004 fake_impl.py:34(register)
#         1    0.033    0.033    0.447    0.447 {built-in method torch._C._initExtension}
#        37    0.078    0.002    0.445    0.012 base.py:7097(drop)
#         1    0.001    0.001    0.444    0.444 pycode.py:1(<module>)
#         1    0.000    0.000    0.432    0.432 codeprinter.py:1(<module>)
#         1    0.000    0.000    0.427    0.427 nested_tensor.py:1(<module>)
#         1    0.000    0.000    0.425    0.425 nested_int.py:1(<module>)
#        32    0.423    0.013    0.423    0.013 {built-in method torch.abs}
#        56    0.001    0.000    0.421    0.008 base.py:6174(get_indexer_for)
#         2    0.000    0.000    0.407    0.203 text.py:1(<module>)
#         2    0.000    0.000    0.405    0.203 _matfuncs.py:1(<module>)
#       113    0.000    0.000    0.404    0.004 utils.py:35(get_source)
#       113    0.002    0.000    0.403    0.004 inspect.py:1684(getframeinfo)
#   356/354    0.005    0.000    0.385    0.001 inspect.py:988(getmodule)
#       496    0.000    0.000    0.383    0.001 linecache.py:36(getlines)
#        84    0.000    0.000    0.382    0.005 linecache.py:80(updatecache)
#        94    0.001    0.000    0.378    0.004 base.py:3827(get_indexer)
#         2    0.000    0.000    0.376    0.188 array.py:1(<module>)
#         1    0.000    0.000    0.376    0.376 rcsetup.py:1(<module>)
#        18    0.000    0.000    0.371    0.021 tokenize.py:445(open)
#        32    0.361    0.011    0.361    0.011 {built-in method torch.sqrt}
#         1    0.000    0.000    0.351    0.351 cond.py:1(<module>)
#         1    0.000    0.000    0.350    0.350 figure.py:1(<module>)
#         8    0.001    0.000    0.349    0.044 core.py:1(<module>)
#       106    0.004    0.000    0.349    0.003 artist.py:158(_update_set_signature_and_docstring)
#         1    0.000    0.000    0.348    0.348 associative_scan.py:1(<module>)
#       105    0.001    0.000    0.344    0.003 artist.py:125(__init_subclass__)
#        31    0.007    0.000    0.324    0.010 __init__.py:887(_rc_params_in_file)
#         1    0.000    0.000    0.321    0.321 _interpolate.py:1(<module>)
#         1    0.000    0.000    0.315    0.315 aoti_call_delegate.py:1(<module>)
#      1771    0.001    0.000    0.312    0.000 {built-in method builtins.next}
#      2392    0.311    0.000    0.311    0.000 {built-in method marshal.loads}
#       479    0.311    0.001    0.311    0.001 {built-in method builtins.print}
#       131    0.001    0.000    0.310    0.002 traceback.py:221(extract_stack)
#       131    0.000    0.000    0.309    0.002 traceback.py:377(extract)
#       131    0.003    0.000    0.309    0.002 traceback.py:399(_extract_from_extended_frame_gen)
#         1    0.000    0.000    0.304    0.304 _invoke_quant.py:1(<module>)
#         2    0.001    0.000    0.300    0.150 core.py:198(read_style_directory)
#         1    0.000    0.000    0.294    0.294 _svds.py:1(<module>)
#        62    0.000    0.000    0.285    0.005 __init__.py:869(_open_file_or_url)
#       128    0.000    0.000    0.285    0.002 contextlib.py:132(__enter__)
#       111    0.000    0.000    0.284    0.003 pathlib.py:1022(read_text)
#       111    0.000    0.000    0.280    0.003 pathlib.py:1005(open)
#         1    0.001    0.001    0.279    0.279 module.py:1(<module>)
#         1    0.000    0.000    0.278    0.278 interpreter.py:1(<module>)
#       120    0.001    0.000    0.276    0.002 artist.py:1832(kwdoc)
#       555    0.001    0.000    0.276    0.000 traceback.py:318(line)
#         1    0.000    0.000    0.275    0.275 _svdp.py:1(<module>)
#       355    0.000    0.000    0.275    0.001 linecache.py:26(getline)
#         3    0.000    0.000    0.273    0.091 function.py:1(<module>)
#         1    0.000    0.000    0.272    0.272 _minimize.py:1(<module>)
#         1    0.000    0.000    0.272    0.272 _registrations.py:1(<module>)
#         3    0.000    0.000    0.271    0.090 _basic.py:1(<module>)
#         4    0.000    0.000    0.271    0.068 _internal.py:1(<module>)
#         1    0.000    0.000    0.270    0.270 _mgc.py:1(<module>)
#         2    0.000    0.000    0.264    0.132 _support_alternative_backends.py:1(<module>)
#         1    0.000    0.000    0.257    0.257 _new_distributions.py:1(<module>)
#         3    0.000    0.000    0.256    0.085 _distribution_infrastructure.py:1317(_combine_docs)
#        15    0.254    0.017    0.254    0.017 {built-in method torch.matmul}
#         1    0.000    0.000    0.252    0.252 _guards.py:1(<module>)
#         1    0.000    0.000    0.241    0.241 colors.py:1(<module>)
# 466609/462223    0.190    0.000    0.236    0.000 {built-in method builtins.len}
#      2394    0.004    0.000    0.235    0.000 <frozen importlib._bootstrap_external>:1202(path_stats)
#       120    0.006    0.000    0.235    0.002 artist.py:1593(pprint_setters)
#       210    0.000    0.000    0.235    0.001 _docscrape.py:579(__init__)
#         1    0.000    0.000    0.233    0.233 _fitpack_py.py:1(<module>)
#         1    0.000    0.000    0.232    0.232 _ndimage_api.py:1(<module>)
#       325    0.001    0.000    0.226    0.001 dataclasses.py:1264(wrap)
#       325    0.014    0.000    0.226    0.001 dataclasses.py:921(_process_class)
#         1    0.000    0.000    0.224    0.224 f2py2e.py:1(<module>)
#       976    0.006    0.000    0.219    0.000 <frozen ntpath>:692(realpath)
#       108    0.012    0.000    0.219    0.002 base.py:475(__new__)
#         2    0.000    0.000    0.219    0.110 __init__.py:901(entry_points)
#       503    0.211    0.000    0.219    0.000 {built-in method builtins.eval}
#       110    0.000    0.000    0.218    0.002 __init__.py:910(<genexpr>)
#       361    0.002    0.000    0.218    0.001 base.py:7659(ensure_index)
#        10    0.000    0.000    0.215    0.021 __init__.py:343(__init__)
#         9    0.214    0.024    0.214    0.024 {built-in method _ctypes.LoadLibrary}
#         3    0.000    0.000    0.214    0.071 _distributor_init.py:1(<module>)
#         1    0.000    0.000    0.211    0.211 autograd_function.py:1(<module>)
#         1    0.000    0.000    0.209    0.209 _pickle.py:1(<module>)
#       216    0.001    0.000    0.208    0.001 _docscrape.py:140(__init__)
#       108    0.000    0.000    0.204    0.002 __init__.py:469(entry_points)
#         2    0.000    0.000    0.204    0.102 indexing.py:1(<module>)
#      1958    0.202    0.000    0.202    0.000 {built-in method nt._getfinalpathname}
#         1    0.000    0.000    0.202    0.202 __init__.py:2817(_import_device_backends)
#       109    0.001    0.000    0.200    0.002 __init__.py:811(read_text)
#         1    0.000    0.000    0.199    0.199 _linprog_ip.py:1(<module>)
#         1    0.000    0.000    0.198    0.198 dataloader.py:1(<module>)
#        68    0.196    0.003    0.196    0.003 {built-in method torch.arange}
#         1    0.000    0.000    0.196    0.196 _linprog_util.py:1(<module>)
#      7848    0.103    0.000    0.195    0.000 inspect.py:882(cleandoc)
#         3    0.013    0.004    0.195    0.065 _distribution_infrastructure.py:1368(_generate_example)
#         1    0.000    0.000    0.194    0.194 _remove_redundancy.py:1(<module>)
#         1    0.000    0.000    0.194    0.194 _ode.py:1(<module>)
#    102/51    0.001    0.000    0.193    0.004 _jit_internal.py:617(fn)
#         1    0.000    0.000    0.193    0.193 interpolative.py:1(<module>)
#        51    0.003    0.000    0.192    0.004 functional.py:786(_unique_impl)
#      4409    0.015    0.000    0.191    0.000 artist.py:1461(get_valid_values)
#       127    0.001    0.000    0.189    0.001 library.py:95(__init__)
#         1    0.000    0.000    0.189    0.189 _kdtree.py:1(<module>)
#        94    0.000    0.000    0.188    0.002 base.py:6725(_maybe_cast_listlike_indexer)
#         1    0.000    0.000    0.186    0.186 _csr.py:1(<module>)
#        34    0.000    0.000    0.185    0.005 functional.py:1057(_return_inverse)
#         1    0.000    0.000    0.185    0.185 capi_maps.py:1(<module>)
#         1    0.000    0.000    0.183    0.183 textpath.py:1(<module>)
#        34    0.182    0.005    0.182    0.005 {built-in method unique_dim}
#        66    0.160    0.002    0.181    0.003 base.py:3962(_get_indexer)
#     15649    0.115    0.000    0.178    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
#         1    0.000    0.000    0.176    0.176 crackfortran.py:1(<module>)
#         4    0.000    0.000    0.174    0.044 functional.py:1(<module>)
#         2    0.000    0.000    0.174    0.087 expr.py:1(<module>)
#         1    0.000    0.000    0.165    0.165 tunable.py:1(<module>)
#      7722    0.008    0.000    0.163    0.000 inspect.py:863(getdoc)
#       957    0.162    0.000    0.162    0.000 {built-in method nt._path_exists}
#         1    0.000    0.000    0.160    0.160 lapack.py:1(<module>)
#      1195    0.003    0.000    0.159    0.000 inspect.py:976(getabsfile)
#         1    0.000    0.000    0.158    0.158 bsplines.py:1(<module>)
#       216    0.005    0.000    0.158    0.001 _docscrape.py:388(_parse)
#      1140    0.005    0.000    0.158    0.000 _ops.py:1350(__getattr__)
#         1    0.000    0.000    0.158    0.158 partfrac.py:1(<module>)
#         1    0.000    0.000    0.158    0.158 decorator.py:65(xthreaded)
#         1    0.000    0.000    0.158    0.158 decorator.py:16(threaded_factory)
#      2803    0.003    0.000    0.157    0.000 inspect.py:3339(signature)
# 180266/179768    0.054    0.000    0.155    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.155    0.155 _fitpack_impl.py:1(<module>)
#      2803    0.003    0.000    0.154    0.000 inspect.py:3077(from_callable)
#      1362    0.006    0.000    0.153    0.000 inspect.py:951(getsourcefile)
# 4046/2807    0.025    0.000    0.151    0.000 inspect.py:2497(_signature_from_callable)
#         1    0.000    0.000    0.150    0.150 ctx_fp.py:1(<module>)
#         2    0.000    0.000    0.148    0.074 base_hop.py:60(__init__)
#         1    0.145    0.145    0.146    0.146 _text_helpers.py:1(<module>)
#        40    0.001    0.000    0.145    0.004 managers.py:642(reindex_indexer)
#     10083    0.012    0.000    0.140    0.000 __init__.py:280(_compile)
#      1295    0.008    0.000    0.139    0.000 dataclasses.py:449(_create_fn)
#       226    0.136    0.001    0.136    0.001 base.py:650(_simple_new)
#         1    0.000    0.000    0.135    0.135 autograd_function.py:741(__init__)
#         1    0.000    0.000    0.132    0.132 autograd_function.py:33(__init__)
#        55    0.066    0.001    0.131    0.002 managers.py:727(_slice_take_blocks_ax0)
#         1    0.000    0.000    0.129    0.129 _cloudpickle_wrapper.py:1(<module>)
#         1    0.000    0.000    0.128    0.128 _discrete_distns.py:1(<module>)
#         1    0.000    0.000    0.128    0.128 _arraypad_impl.py:1(<module>)
#         1    0.000    0.000    0.127    0.127 _axes.py:1(<module>)
#         1    0.000    0.000    0.126    0.126 _index_tricks_impl.py:1(<module>)
#         1    0.000    0.000    0.126    0.126 ctx_base.py:1(<module>)
#       325    0.000    0.000    0.125    0.000 dataclasses.py:1247(dataclass)
# 10405/9926    0.020    0.000    0.124    0.000 typing.py:392(inner)
#         1    0.000    0.000    0.124    0.124 mul.py:1(<module>)
#         4    0.000    0.000    0.124    0.031 basic.py:1(<module>)
#         1    0.000    0.000    0.123    0.123 sympify.py:1(<module>)
#         1    0.000    0.000    0.123    0.123 polytools.py:1(<module>)
#        34    0.121    0.004    0.121    0.004 {built-in method torch.pow}
#         3    0.000    0.000    0.120    0.040 numbers.py:1(<module>)
#         1    0.000    0.000    0.118    0.118 _ccallback.py:1(<module>)
#        28    0.000    0.000    0.118    0.004 inspect.py:1258(getsourcelines)
#        17    0.001    0.000    0.116    0.007 script.py:95(predict_from_equation)
#      4788    0.020    0.000    0.116    0.000 <frozen importlib._bootstrap_external>:482(cache_from_source)
#       381    0.002    0.000    0.115    0.000 _compiler.py:740(compile)
#         1    0.008    0.008    0.115    0.115 readers.py:868(read_csv)
#      7119    0.036    0.000    0.115    0.000 <frozen importlib._bootstrap>:304(acquire)
#        18    0.001    0.000    0.114    0.006 frame.py:4962(select_dtypes)
#         3    0.000    0.000    0.112    0.037 __init__.py:338(_lazy_call)
#         3    0.000    0.000    0.112    0.037 traceback.py:214(format_stack)
#         1    0.000    0.000    0.111    0.111 graph_drawer.py:1(<module>)
#       448    0.002    0.000    0.110    0.000 frame.py:4073(__getitem__)
#        18    0.000    0.000    0.110    0.006 frame.py:5658(rename)
#        18    0.000    0.000    0.110    0.006 generic.py:1073(_rename)
#         1    0.000    0.000    0.108    0.108 shape_prop.py:1(<module>)
#         1    0.000    0.000    0.108    0.108 defmatrix.py:1(<module>)
#         1    0.000    0.000    0.107    0.107 array_ops.py:1(<module>)
#         1    0.000    0.000    0.107    0.107 _trustregion_krylov.py:1(<module>)
#         1    0.000    0.000    0.107    0.107 readers.py:583(_read)
#        15    0.106    0.007    0.106    0.007 {method 'repeat' of 'torch._C.TensorBase' objects}
#      2074    0.009    0.000    0.106    0.000 _ops.py:1190(__getattr__)
#         1    0.000    0.000    0.106    0.106 _fontconfig_pattern.py:1(<module>)
#         1    0.000    0.000    0.105    0.105 _root.py:1(<module>)
#        30    0.104    0.003    0.104    0.003 {built-in method torch.squeeze}
#       113    0.005    0.000    0.104    0.001 autograd.py:23(make_autograd_impl)
#        18    0.000    0.000    0.103    0.006 managers.py:514(_get_data_subset)
#        18    0.002    0.000    0.103    0.006 managers.py:543(_combine)
#         3    0.000    0.000    0.101    0.034 _linalg.py:1(<module>)
#        18    0.000    0.000    0.100    0.006 fromnumeric.py:968(sort)
#         5    0.000    0.000    0.100    0.020 transforms.py:1(<module>)
#        18    0.099    0.006    0.099    0.006 {method 'sort' of 'numpy.ndarray' objects}
# 305989/305936    0.068    0.000    0.099    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.099    0.099 fake_tensor.py:1(<module>)
#         1    0.000    0.000    0.098    0.098 chebyshev.py:1(<module>)
#         1    0.000    0.000    0.098    0.098 _minpack_py.py:1(<module>)
#       110    0.002    0.000    0.098    0.001 _distn_infrastructure.py:1863(__init__)
#      2610    0.012    0.000    0.097    0.000 <frozen importlib._bootstrap>:733(_init_module_attrs)
#         6    0.000    0.000    0.097    0.016 random.py:1(<module>)
#         1    0.000    0.000    0.096    0.096 _numdiff.py:1(<module>)
#        26    0.000    0.000    0.096    0.004 _jit_internal.py:995(_check_overload_body)
#         3    0.000    0.000    0.096    0.032 _distribution_infrastructure.py:2043(_draw)
#      4400    0.009    0.000    0.096    0.000 <frozen importlib._bootstrap>:463(_lock_unlock_module)
#        26    0.000    0.000    0.096    0.004 _sources.py:120(parse_def)
#      2518    0.031    0.000    0.096    0.000 inspect.py:2393(_signature_from_function)
#        26    0.000    0.000    0.096    0.004 _sources.py:103(make_source_context)
#         1    0.000    0.000    0.096    0.096 algorithms.py:1(<module>)
#         1    0.000    0.000    0.096    0.096 apis.py:1(<module>)
#         2    0.000    0.000    0.096    0.048 context.py:1(<module>)
#        34    0.095    0.003    0.095    0.003 {built-in method torch.ones_like}
#         1    0.000    0.000    0.095    0.095 _quadpack_py.py:1(<module>)
#         3    0.000    0.000    0.095    0.032 _distribution_infrastructure.py:868(draw)
#         6    0.015    0.003    0.095    0.016 _distribution_infrastructure.py:605(draw)
#         2    0.000    0.000    0.095    0.047 library.py:666(wrap)
#        24    0.001    0.000    0.094    0.004 utils.py:1(<module>)
#         1    0.000    0.000    0.094    0.094 _symbolic_trace.py:1(<module>)
#       227    0.001    0.000    0.093    0.000 artist.py:1413(__init__)
#       227    0.030    0.000    0.092    0.000 artist.py:1433(get_aliases)
#        48    0.001    0.000    0.091    0.002 frame.py:698(__init__)
#         1    0.000    0.000    0.091    0.091 constructor.py:1(<module>)
#      2801    0.013    0.000    0.091    0.000 textwrap.py:419(dedent)
#       644    0.000    0.000    0.091    0.000 __init__.py:226(compile)
#         1    0.000    0.000    0.091    0.091 estimator.py:1(<module>)
#         3    0.000    0.000    0.091    0.030 ops.py:1(<module>)
#        26    0.000    0.000    0.091    0.003 _sources.py:12(get_source_lines_and_file)
#         1    0.000    0.000    0.089    0.089 _lil.py:1(<module>)
#        86    0.072    0.001    0.089    0.001 base.py:2320(is_unique)
#         1    0.000    0.000    0.088    0.088 patches.py:1(<module>)
#         1    0.000    0.000    0.088    0.088 _morestats.py:1(<module>)
#         1    0.000    0.000    0.087    0.087 estimator.py:26(_get_css_style)
#         1    0.000    0.000    0.086    0.086 scale.py:1(<module>)
#      1140    0.002    0.000    0.085    0.000 _ops.py:1387(_get_packet)
#         3    0.000    0.000    0.085    0.028 series.py:1(<module>)
#         1    0.000    0.000    0.084    0.084 _lazy_graph_module.py:1(<module>)
#         1    0.000    0.000    0.084    0.084 string_.py:1(<module>)
#        18    0.001    0.000    0.084    0.005 construction.py:423(dict_to_mgr)
#         1    0.000    0.000    0.084    0.084 _json.py:1(<module>)
#       816    0.004    0.000    0.084    0.000 _pytree.py:1379(tree_map_)
#         1    0.000    0.000    0.084    0.084 _spherical_voronoi.py:1(<module>)
#         1    0.000    0.000    0.083    0.083 von_mises.py:1(<module>)
#        63    0.001    0.000    0.083    0.001 _axis_nan_policy.py:418(axis_nan_policy_decorator)
#         1    0.000    0.000    0.083    0.083 Image.py:1(<module>)
#         1    0.000    0.000    0.082    0.082 graph_settings.py:1(<module>)
#      1140    0.082    0.000    0.082    0.000 {built-in method torch._C._jit_get_operation}
#        17    0.081    0.005    0.081    0.005 {method 'sort' of 'torch._C.TensorBase' objects}
#      3341    0.003    0.000    0.081    0.000 <frozen importlib._bootstrap_external>:1469(_path_importer_cache)
#         1    0.000    0.000    0.081    0.081 _parallel_backends.py:1(<module>)
#         1    0.000    0.000    0.080    0.080 readers.py:1907(read)
#         1    0.000    0.000    0.080    0.080 _kde.py:1(<module>)
#      2482    0.079    0.000    0.079    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.000    0.000    0.079    0.079 _jit_internal.py:1(<module>)
#        24    0.002    0.000    0.078    0.003 _distribution_infrastructure.py:386(draw)
#      2719    0.004    0.000    0.078    0.000 <frozen importlib._bootstrap>:416(__enter__)
#         2    0.000    0.000    0.078    0.039 linsolve.py:1(<module>)
#       318    0.002    0.000    0.078    0.000 <frozen importlib._bootstrap_external>:1456(_path_hooks)
#         1    0.000    0.000    0.078    0.078 _filters.py:1(<module>)
#         1    0.000    0.000    0.077    0.077 _rbfinterp.py:1(<module>)
#        64    0.001    0.000    0.077    0.001 _array_api.py:806(decorator)
# 9251/2824    0.012    0.000    0.077    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.077    0.077 ticker.py:1(<module>)
#         1    0.000    0.000    0.077    0.077 __init__.py:245(_check_versions)
#         1    0.000    0.000    0.077    0.077 font_manager.py:1(<module>)
#         2    0.000    0.000    0.076    0.038 dense.py:1(<module>)
#         3    0.075    0.025    0.076    0.025 _distribution_infrastructure.py:410(ints)
#      4976    0.003    0.000    0.076    0.000 <frozen importlib._bootstrap>:632(cached)
#         1    0.000    0.000    0.076    0.076 _measurements.py:1(<module>)
#         2    0.000    0.000    0.075    0.038 _helper.py:1(<module>)
#         1    0.000    0.000    0.075    0.075 _bsplines.py:1(<module>)
#         1    0.000    0.000    0.075    0.075 _invoke_quant.py:26(__init__)
#      4277    0.016    0.000    0.075    0.000 _ops.py:1137(_has_script_object_arg)
#       120    0.000    0.000    0.075    0.001 take.py:59(take_nd)
#         6    0.000    0.000    0.075    0.013 _jit_internal.py:1080(_overload_method)
#      1197    0.005    0.000    0.075    0.000 _docscrape.py:201(_read_to_next_section)
#       120    0.058    0.000    0.075    0.001 take.py:120(_take_nd_ndarray)
#         1    0.000    0.000    0.074    0.074 arpack.py:1(<module>)
#         2    0.000    0.000    0.074    0.037 testing.py:1(<module>)
#         1    0.000    0.000    0.073    0.073 _invoke_quant.py:12(__init__)
#         1    0.000    0.000    0.073    0.073 graph_module.py:1(<module>)
#      2582    0.005    0.000    0.073    0.000 <frozen importlib._bootstrap_external>:611(_get_cached)
#       923    0.005    0.000    0.072    0.000 __init__.py:64(_add_op_to_registry)
#         3    0.000    0.000    0.072    0.024 datetimes.py:1(<module>)
#         1    0.000    0.000    0.071    0.071 immutable.py:1(<module>)
#       104    0.048    0.000    0.071    0.001 frame.py:1051(shape)
#         1    0.000    0.000    0.071    0.071 masked.py:1(<module>)
#         1    0.000    0.000    0.071    0.071 _multivariate.py:1(<module>)
#        64    0.069    0.001    0.069    0.001 {built-in method torch.sum}
#       188    0.003    0.000    0.069    0.000 construction.py:517(sanitize_array)
#         1    0.000    0.000    0.069    0.069 cbook.py:1(<module>)
#         1    0.000    0.000    0.068    0.068 _isotonic.py:1(<module>)
#        68    0.001    0.000    0.068    0.001 _util.py:1202(decorator)
#      1229    0.002    0.000    0.068    0.000 _docscrape.py:212(_read_sections)
#         1    0.000    0.000    0.068    0.068 __init__.py:599(matplotlib_fname)
#         1    0.000    0.000    0.068    0.068 ewm.py:1(<module>)
#         6    0.000    0.000    0.067    0.011 rnn.py:1(<module>)
#       381    0.001    0.000    0.067    0.000 _parser.py:969(parse)
#       549    0.001    0.000    0.067    0.000 __init__.py:205(decomposition_decorator)
#         4    0.000    0.000    0.067    0.017 graph.py:1(<module>)
#      4579    0.050    0.000    0.067    0.000 functools.py:35(update_wrapper)
#         2    0.000    0.000    0.067    0.033 <frozen importlib._bootstrap_external>:1207(_cache_bytecode)
#         2    0.000    0.000    0.066    0.033 <frozen importlib._bootstrap_external>:1212(set_data)
#       978    0.002    0.000    0.066    0.000 _ops.py:1146(__init__)
#         1    0.000    0.000    0.066    0.066 axes3d.py:1(<module>)
#         2    0.000    0.000    0.066    0.033 <frozen importlib._bootstrap_external>:195(_write_atomic)
#       119    0.066    0.001    0.066    0.001 {built-in method torch.empty}
#       432    0.001    0.000    0.065    0.000 basic.py:212(__init_subclass__)
#        86    0.000    0.000    0.065    0.001 dispatcher.py:178(add)
#         1    0.000    0.000    0.065    0.065 rnn.py:1165(GRU)
#         1    0.000    0.000    0.065    0.065 matrixbase.py:1(<module>)
#        17    0.065    0.004    0.065    0.004 {method 'scatter_' of 'torch._C.TensorBase' objects}
#  1155/381    0.004    0.000    0.065    0.000 _parser.py:452(_parse_sub)
#        86    0.000    0.000    0.065    0.001 dispatcher.py:222(reorder)
#       433    0.028    0.000    0.064    0.000 assumptions.py:614(_prepare_class_assumptions)
#       430    0.012    0.000    0.064    0.000 doccer.py:29(docformat)
#  1228/878    0.001    0.000    0.064    0.000 typing.py:515(__getitem__)
#        15    0.063    0.004    0.063    0.004 {built-in method torch.min}
#         1    0.000    0.000    0.063    0.063 pretty.py:1(<module>)
#         1    0.000    0.000    0.063    0.063 rnn.py:800(LSTM)
#  1429/413    0.022    0.000    0.063    0.000 _parser.py:512(_parse)
#         1    0.000    0.000    0.063    0.063 font_manager.py:1625(_load_fontmanager)
#         1    0.000    0.000    0.062    0.062 rnn.py:470(RNN)
#         1    0.000    0.000    0.062    0.062 font_manager.py:1030(json_load)
#         1    0.000    0.000    0.061    0.061 widgets.py:1(<module>)
#       113    0.000    0.000    0.060    0.001 custom_ops.py:902(get_library_allowing_overwrite)
#       227    0.019    0.000    0.060    0.000 artist.py:1511(get_setters)
#         2    0.000    0.000    0.060    0.030 _pytree.py:1(<module>)
#         5    0.000    0.000    0.060    0.012 memory.py:1(<module>)
#         1    0.000    0.000    0.060    0.060 take.py:1(<module>)
#    222963    0.060    0.000    0.060    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.060    0.060 _vmap_internals.py:1(<module>)
#       105    0.000    0.000    0.059    0.001 __init__.py:336(wrapper)
#         2    0.000    0.000    0.059    0.030 __init__.py:522(_get_config_or_cache_dir)
#         1    0.000    0.000    0.059    0.059 lsq_linear.py:1(<module>)
#        32    0.059    0.002    0.059    0.002 {built-in method torch.dot}
# 55868/55865    0.053    0.000    0.058    0.000 {method 'join' of 'str' objects}
#       131    0.001    0.000    0.058    0.000 _distn_infrastructure.py:830(_construct_doc)
#         4    0.000    0.000    0.058    0.015 __init__.py:620(gen_candidates)
#         1    0.000    0.000    0.058    0.058 __init__.py:563(get_configdir)
#         2    0.000    0.000    0.058    0.029 _delegation.py:1(<module>)
#         1    0.000    0.000    0.058    0.058 _odepack_py.py:1(<module>)
#         2    0.000    0.000    0.058    0.029 pathlib.py:1306(mkdir)
#       318    0.007    0.000    0.058    0.000 <frozen importlib._bootstrap_external>:1644(_fill_cache)
#         2    0.000    0.000    0.058    0.029 construction.py:1(<module>)
#         2    0.058    0.029    0.058    0.029 {built-in method nt.mkdir}
#         1    0.000    0.000    0.058    0.058 collections.py:1(<module>)
#        34    0.000    0.000    0.057    0.002 grad_mode.py:84(__exit__)
#       102    0.057    0.001    0.057    0.001 {built-in method torch.is_grad_enabled}
#        68    0.000    0.000    0.057    0.001 grad_mode.py:184(__init__)
#         1    0.000    0.000    0.057    0.057 power.py:1(<module>)
#         1    0.000    0.000    0.056    0.056 _indexing.py:1(<module>)
#         6    0.000    0.000    0.056    0.009 linear_relu.py:1(<module>)
#         1    0.000    0.000    0.056    0.056 trf_linear.py:1(<module>)
#        61    0.001    0.000    0.056    0.001 typing_extensions.py:2942(__call__)
#       570    0.000    0.000    0.056    0.000 __init__.py:214(register)
#         1    0.000    0.000    0.056    0.056 products.py:1(<module>)
#      7119    0.012    0.000    0.055    0.000 <frozen importlib._bootstrap>:162(__enter__)
#       836    0.005    0.000    0.055    0.000 typing.py:694(Union)
#       113    0.055    0.000    0.055    0.000 {method 'unsqueeze' of 'torch._C.TensorBase' objects}
#         1    0.000    0.000    0.055    0.055 torchbind.py:1(<module>)
#        22    0.000    0.000    0.055    0.002 _distribution_infrastructure.py:1083(filtered)
#       129    0.008    0.000    0.055    0.000 library.py:137(define)
#      1391    0.007    0.000    0.055    0.000 typing.py:1269(__init__)
#         1    0.000    0.000    0.055    0.055 point.py:1(<module>)
#         1    0.000    0.000    0.054    0.054 fixes.py:1(<module>)
#         1    0.000    0.000    0.054    0.054 extmath.py:1(<module>)
#         1    0.000    0.000    0.054    0.054 serialization.py:1(<module>)
#     18498    0.049    0.000    0.054    0.000 _ops.py:1138(<genexpr>)
#         1    0.000    0.000    0.054    0.054 torchbind.py:30(__init__)
#         1    0.000    0.000    0.053    0.053 _python_dispatch.py:1(<module>)
#      3283    0.002    0.000    0.053    0.000 _ops.py:1160(<genexpr>)
#       438    0.005    0.000    0.053    0.000 _docscrape.py:224(_parse_param_list)
#     28/22    0.000    0.000    0.052    0.002 _distribution_infrastructure.py:1136(wrapped)
#      5933    0.004    0.000    0.052    0.000 __init__.py:174(search)
#         2    0.000    0.000    0.052    0.026 _funcs.py:1(<module>)
#         1    0.052    0.052    0.052    0.052 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.052    0.052 sparsefuncs.py:1(<module>)
#         1    0.000    0.000    0.051    0.051 node.py:1(<module>)
#         9    0.000    0.000    0.051    0.006 _base.py:783(__init_subclass__)
#         1    0.000    0.000    0.051    0.051 device_mesh.py:1(<module>)
#        22    0.050    0.002    0.050    0.002 {built-in method torch.full}
#         2    0.000    0.000    0.050    0.025 dtypes.py:1(<module>)
#       109    0.048    0.000    0.050    0.000 cast.py:1166(maybe_infer_to_datetimelike)
#         2    0.049    0.025    0.049    0.025 {built-in method nt.replace}
#       325    0.003    0.000    0.049    0.000 dataclasses.py:568(_init_fn)
#         1    0.000    0.000    0.049    0.049 eval.py:1(<module>)
#         1    0.000    0.000    0.049    0.049 uarray.py:1(<module>)
#         2    0.000    0.000    0.049    0.024 custom_ops.py:1(<module>)
#         2    0.000    0.000    0.049    0.024 _at.py:1(<module>)
#         1    0.000    0.000    0.049    0.049 _utils_internal.py:1(<module>)
#     14006    0.027    0.000    0.048    0.000 inspect.py:2739(__init__)
#         2    0.000    0.000    0.048    0.024 _backend.py:1(<module>)
#       228    0.001    0.000    0.048    0.000 function.py:164(__init__)
#         1    0.000    0.000    0.048    0.048 _linprog_rs.py:1(<module>)
#         1    0.000    0.000    0.047    0.047 entity.py:1(<module>)
#       334    0.047    0.000    0.047    0.000 {built-in method nt.listdir}
#         2    0.000    0.000    0.047    0.023 hashing.py:1(<module>)
#         1    0.000    0.000    0.047    0.047 _search.py:1(<module>)
#       152    0.000    0.000    0.046    0.000 base.py:6324(_index_as_unique)
#         2    0.000    0.000    0.045    0.023 parallel.py:1(<module>)
#       290    0.045    0.000    0.045    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#         1    0.000    0.000    0.045    0.045 find_first_use_of_broken_modules.py:1(<module>)
#         1    0.000    0.000    0.045    0.045 error_functions.py:1(<module>)
#       381    0.001    0.000    0.045    0.000 _compiler.py:573(_code)
#       424    0.001    0.000    0.044    0.000 linecache.py:52(checkcache)
#        34    0.044    0.001    0.044    0.001 {method 'reshape' of 'torch._C.TensorBase' objects}
#   128/117    0.001    0.000    0.044    0.000 _docstring.py:122(__call__)
#         1    0.000    0.000    0.044    0.044 cm.py:1(<module>)
#         1    0.000    0.000    0.044    0.044 summations.py:1(<module>)
#        15    0.000    0.000    0.044    0.003 _tensor.py:1145(__len__)
#       457    0.007    0.000    0.044    0.000 wrappers.py:255(_out_wrapper)
# 17779/16744    0.020    0.000    0.044    0.000 {built-in method __new__ of type object at 0x00007FFA720E38F0}
#         1    0.000    0.000    0.044    0.044 _target_encoder.py:1(<module>)
#        15    0.044    0.003    0.044    0.003 {built-in method torch._C._get_tracing_state}
#         1    0.000    0.000    0.044    0.044 engines.py:1(<module>)
#         1    0.000    0.000    0.044    0.044 _plotutils.py:1(<module>)
#      4871    0.015    0.000    0.043    0.000 _docscrape.py:67(read_to_condition)
#         3    0.000    0.000    0.043    0.014 accessor.py:1(<module>)
#         1    0.000    0.000    0.043    0.043 package_exporter.py:1(<module>)
#         1    0.000    0.000    0.042    0.042 slice.py:1(<module>)
#        71    0.016    0.000    0.042    0.001 managers.py:1801(_consolidate_inplace)
#        44    0.000    0.000    0.042    0.001 blocks.py:1353(take_nd)
#        18    0.000    0.000    0.042    0.002 construction.py:96(arrays_to_mgr)
#       978    0.001    0.000    0.041    0.000 __init__.py:751(__setitem__)
#        18    0.000    0.000    0.041    0.002 managers.py:2140(create_block_manager_from_column_arrays)
#         2    0.000    0.000    0.041    0.021 quantization_mappings.py:1(<module>)
#     72/54    0.001    0.000    0.041    0.001 series.py:392(__init__)
#         1    0.000    0.000    0.041    0.041 _freeze.py:1(<module>)
#      7119    0.019    0.000    0.041    0.000 <frozen importlib._bootstrap>:124(setdefault)
#         1    0.000    0.000    0.041    0.041 symbol.py:1(<module>)
#         1    0.000    0.000    0.040    0.040 _pocketfft.py:1(<module>)
#         1    0.000    0.000    0.040    0.040 matexpr.py:1(<module>)
#       447    0.002    0.000    0.039    0.000 frame.py:4637(_get_item_cache)
#         1    0.000    0.000    0.039    0.039 readers.py:1(<module>)
#         1    0.000    0.000    0.039    0.039 plot.py:1(<module>)
#         3    0.000    0.000    0.039    0.013 reductions.py:1(<module>)
#         1    0.000    0.000    0.039    0.039 _script.py:1(<module>)
#         3    0.000    0.000    0.039    0.013 platform.py:1016(machine)
#         5    0.000    0.000    0.039    0.008 platform.py:890(uname)
#         1    0.000    0.000    0.039    0.039 _polynomial.py:1(<module>)
#         2    0.000    0.000    0.039    0.019 platform.py:322(_wmi_query)
#         2    0.039    0.019    0.039    0.019 {built-in method _wmi.exec_query}
#       318    0.002    0.000    0.038    0.000 <frozen zipimport>:64(__init__)
#      2835    0.038    0.000    0.038    0.000 {method 'findall' of 're.Pattern' objects}
#         2    0.000    0.000    0.038    0.019 _ops.py:1(<module>)
#         1    0.000    0.000    0.038    0.038 _slsqp_py.py:1(<module>)
#         1    0.000    0.000    0.038    0.038 stringpict.py:1(<module>)
#        43    0.000    0.000    0.038    0.001 dispatcher.py:147(_)
#      2582    0.007    0.000    0.038    0.000 <frozen importlib._bootstrap_external>:1588(_get_spec)
#         1    0.000    0.000    0.038    0.038 _supervised.py:1(<module>)
#      3616    0.003    0.000    0.038    0.000 _docscrape.py:77(read_to_next_empty_line)
#         1    0.037    0.037    0.038    0.038 {built-in method torch._C._c10d_init}
#       460    0.001    0.000    0.038    0.000 frame.py:3994(_ixs)
#         1    0.000    0.000    0.037    0.037 distributed_c10d.py:1(<module>)
#         2    0.000    0.000    0.037    0.019 exponential.py:1(<module>)
#         1    0.000    0.000    0.037    0.037 _show_versions.py:1(<module>)
#      3832    0.016    0.000    0.037    0.000 _docscrape.py:168(_is_at_section)
#       318    0.001    0.000    0.037    0.000 <frozen importlib._bootstrap_external>:1685(path_hook_for_FileFinder)
#         1    0.000    0.000    0.037    0.037 base_events.py:1(<module>)
#         3    0.000    0.000    0.036    0.012 _distribution_infrastructure.py:1339(_generate_domain_support)
#        14    0.000    0.000    0.036    0.003 _docstring.py:73(__missing__)
#      5363    0.036    0.000    0.036    0.000 {method 'sub' of 're.Pattern' objects}
#  2729/381    0.015    0.000    0.036    0.000 _compiler.py:37(_compile)
#         7    0.000    0.000    0.036    0.005 _distribution_infrastructure.py:464(__str__)
#        14    0.036    0.003    0.036    0.003 _distribution_infrastructure.py:473(_get_endpoint_str)
#         1    0.000    0.000    0.036    0.036 pretty_symbology.py:1(<module>)
#         1    0.000    0.000    0.036    0.036 apply.py:1(<module>)
#        24    0.000    0.000    0.036    0.001 _util.py:277(decorator)
#         2    0.000    0.000    0.036    0.018 executor.py:1(<module>)
#         1    0.000    0.000    0.036    0.036 gradcheck.py:1(<module>)
#       328    0.001    0.000    0.035    0.000 dataclasses.py:661(_cmp_fn)
#        50    0.000    0.000    0.035    0.001 fromnumeric.py:51(_wrapfunc)
#         1    0.000    0.000    0.035    0.035 evalf.py:1(<module>)
#      1972    0.033    0.000    0.035    0.000 _ops.py:773(__init__)
#      7119    0.016    0.000    0.034    0.000 <frozen importlib._bootstrap>:426(_get_module_lock)
#         6    0.000    0.000    0.034    0.006 fromnumeric.py:1129(argsort)
#         1    0.000    0.000    0.034    0.034 fake_impls.py:1(<module>)
#         6    0.034    0.006    0.034    0.006 {method 'argsort' of 'numpy.ndarray' objects}
#       347    0.000    0.000    0.034    0.000 pretty_symbology.py:10(U)
#       347    0.034    0.000    0.034    0.000 {built-in method unicodedata.lookup}
#         1    0.000    0.000    0.034    0.034 numpy_.py:1(<module>)
#        17    0.034    0.002    0.034    0.002 {method 'view' of 'torch._C.TensorBase' objects}
#        86    0.006    0.000    0.033    0.000 conflict.py:24(ambiguities)
#         3    0.000    0.000    0.033    0.011 generic.py:4164(_take_with_is_copy)
#    134042    0.033    0.000    0.033    0.000 {method 'append' of 'list' objects}
#         3    0.000    0.000    0.033    0.011 generic.py:4049(take)
#         3    0.000    0.000    0.033    0.011 managers.py:888(take)
#        12    0.015    0.001    0.033    0.003 common.py:1(<module>)
#         1    0.000    0.000    0.033    0.033 art3d.py:1(<module>)
#         1    0.000    0.000    0.033    0.033 iterative.py:1(<module>)
#         1    0.000    0.000    0.033    0.033 threadpoolctl.py:1(<module>)
#    146433    0.033    0.000    0.033    0.000 {method 'lstrip' of 'str' objects}
#         1    0.000    0.000    0.032    0.032 _axes.py:67(Axes)
#       322    0.001    0.000    0.032    0.000 dataclasses.py:627(_repr_fn)
#       439    0.017    0.000    0.032    0.000 doccer.py:225(indentcount_lines)
#        11    0.000    0.000    0.031    0.003 exceptions.py:1(<module>)
#        77    0.031    0.000    0.031    0.000 _validators.py:226(validate_bool_kwarg)
#         2    0.000    0.000    0.031    0.016 _validation.py:1(<module>)
#         1    0.000    0.000    0.031    0.031 library.py:1(<module>)
#         1    0.000    0.000    0.031    0.031 _rgi.py:1(<module>)
#         1    0.000    0.000    0.031    0.031 metadata_routing.py:1(<module>)
#      4404    0.021    0.000    0.031    0.000 inspect.py:3025(__init__)
#        86    0.004    0.000    0.031    0.000 conflict.py:56(ordering)
#         1    0.000    0.000    0.031    0.031 _rotation_groups.py:1(<module>)
#        48    0.000    0.000    0.031    0.001 pretty_symbology.py:100(<lambda>)
#         1    0.000    0.000    0.030    0.030 _decomp_lu.py:1(<module>)
#      2582    0.010    0.000    0.030    0.000 <frozen importlib._bootstrap_external>:802(spec_from_file_location)
#       113    0.001    0.000    0.030    0.000 fake_impl.py:88(construct_meta_kernel)
#       326    0.000    0.000    0.030    0.000 <frozen importlib._bootstrap_external>:164(_path_isdir)
#         1    0.000    0.000    0.030    0.030 ivp.py:1(<module>)
#      5260    0.028    0.000    0.030    0.000 {built-in method builtins.sorted}
#         2    0.000    0.000    0.030    0.015 _config_module.py:164(install_config_module)
#         1    0.000    0.000    0.030    0.030 runtime_assert.py:1(<module>)
#        15    0.000    0.000    0.030    0.002 _distribution_infrastructure.py:3136(moment)
# ...
#         1    0.000    0.000    0.000    0.000 exceptions.py:15(BadRequiredStrength)
#         1    0.000    0.000    0.000    0.000 backend_tools.py:622(ConfigureSubplotsBase)
#         1    0.000    0.000    0.000    0.000 cp1251.py:28(StreamReader)
#         1    0.000    0.000    0.000    0.000 cp1251.py:21(IncrementalDecoder)
#         1    0.000    0.000    0.000    0.000 hatch.py:48(NorthEastHatch)
#         1    0.000    0.000    0.000    0.000 patches.py:2729(Roundtooth)
#         1    0.000    0.000    0.000    0.000 patches.py:3524(CurveA)
#         1    0.000    0.000    0.000    0.000 patches.py:3529(CurveB)
#         1    0.000    0.000    0.000    0.000 patches.py:3539(CurveFilledA)
#         1    0.000    0.000    0.000    0.000 _mathtext.py:858(StixSansFonts)
#         1    0.000    0.000    0.000    0.000 _mathtext.py:1414(Vrule)
#         1    0.000    0.000    0.000    0.000 legend_handler.py:238(HandlerLine2DCompound)
#         1    0.000    0.000    0.000    0.000 legend_handler.py:513(HandlerCircleCollection)
#         1    0.000    0.000    0.000    0.000 streamplot.py:434(InvalidIndexError)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy._core._multiarray_umath._set_madvise_hugepage}
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.lt}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencodeerrors}
#         1    0.000    0.000    0.000    0.000 contextlib.py:357(__enter__)
#         1    0.000    0.000    0.000    0.000 __init__.py:178(c_ulong)
#         1    0.000    0.000    0.000    0.000 __init__.py:195(c_float)
#         1    0.000    0.000    0.000    0.000 __init__.py:199(c_double)
#         1    0.000    0.000    0.000    0.000 __init__.py:203(c_longdouble)
#         1    0.000    0.000    0.000    0.000 __init__.py:217(c_ulonglong)
#         1    0.000    0.000    0.000    0.000 __init__.py:224(c_ubyte)
#         1    0.000    0.000    0.000    0.000 __init__.py:231(c_byte)
#         1    0.000    0.000    0.000    0.000 __init__.py:236(c_char)
#         1    0.000    0.000    0.000    0.000 __init__.py:252(c_bool)
#         1    0.000    0.000    0.000    0.000 glob.py:214(_join)
#         1    0.000    0.000    0.000    0.000 __init__.py:262(c_wchar)
#         1    0.000    0.000    0.000    0.000 _endian.py:34(_swapped_struct_meta)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 threading.py:833(BrokenBarrierError)
#         1    0.000    0.000    0.000    0.000 typing_extensions.py:2098(_EllipsisDummy)
#         1    0.000    0.000    0.000    0.000 shutil.py:83(RegistryError)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2584(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 _nbit_base.py:71(_96Bit)
#         1    0.000    0.000    0.000    0.000 _nbit_base.py:76(_64Bit)
#         1    0.000    0.000    0.000    0.000 _nbit_base.py:81(_32Bit)
#         1    0.000    0.000    0.000    0.000 _nbit_base.py:91(_8Bit)
#         1    0.000    0.000    0.000    0.000 _iotools.py:431(ConverterLockError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:282(StreamError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:285(HeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:288(EmptyHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:297(InvalidHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:300(SubsequentHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:723(FilterError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:61(BrokenBarrierError)
#         1    0.000    0.000    0.000    0.000 context.py:17(BufferTooShort)
#         1    0.000    0.000    0.000    0.000 context.py:23(AuthenticationError)
#         1    0.000    0.000    0.000    0.000 package_importer.py:714(_ExternNode)
#         1    0.000    0.000    0.000    0.000 errors.py:12(MessageParseError)
#         1    0.000    0.000    0.000    0.000 errors.py:16(HeaderParseError)
#         1    0.000    0.000    0.000    0.000 errors.py:20(BoundaryError)
#         1    0.000    0.000    0.000    0.000 errors.py:24(MultipartConversionError)
#         1    0.000    0.000    0.000    0.000 errors.py:28(CharsetError)
#         1    0.000    0.000    0.000    0.000 errors.py:32(HeaderWriteError)
#         1    0.000    0.000    0.000    0.000 errors.py:45(NoBoundaryInMultipartDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:48(StartBoundaryNotFoundDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:51(CloseBoundaryNotFoundDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:54(FirstHeaderLineIsContinuationDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:57(MisplacedEnvelopeHeaderDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:60(MissingHeaderBodySeparatorDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:71(UndecodableBytesDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:74(InvalidBase64PaddingDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:77(InvalidBase64CharactersDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:80(InvalidBase64LengthDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:91(InvalidHeaderDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:94(HeaderMissingRequiredValue)
#         1    0.000    0.000    0.000    0.000 errors.py:108(ObsoleteHeaderDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:111(NonASCIILocalPartDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:116(InvalidDateDefect)
#         1    0.000    0.000    0.000    0.000 client.py:1487(NotConnected)
#         1    0.000    0.000    0.000    0.000 client.py:1490(InvalidURL)
#         1    0.000    0.000    0.000    0.000 client.py:1498(UnknownTransferEncoding)
#         1    0.000    0.000    0.000    0.000 client.py:1501(UnimplementedFileMode)
#         1    0.000    0.000    0.000    0.000 client.py:1521(CannotSendRequest)
#         1    0.000    0.000    0.000    0.000 client.py:1524(CannotSendHeader)
#         1    0.000    0.000    0.000    0.000 client.py:1527(ResponseNotReady)
#         1    0.000    0.000    0.000    0.000 proxy.py:459(TraceError)
#         1    0.000    0.000    0.000    0.000 case.py:39(_UnexpectedSuccess)
#         1    0.000    0.000    0.000    0.000 argparse.py:784(ArgumentTypeError)
#         1    0.000    0.000    0.000    0.000 mock.py:2170(AsyncMagicMixin)
#         1    0.000    0.000    0.000    0.000 _environment.py:1(is_fbcode)
#         1    0.000    0.000    0.000    0.000 proxy_tensor.py:1742(_ModuleNotInstalledAsSubmoduleError)
#         1    0.000    0.000    0.000    0.000 _tzpath.py:36(_parse_python_tzpath)
#         1    0.000    0.000    0.000    0.000 exceptions.py:42(AmbiguousTimeError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:53(NonExistentTimeError)
#         1    0.000    0.000    0.000    0.000 config_init.py:512(is_valid_string_storage)
#         1    0.000    0.000    0.000    0.000 six.py:239(exec_module)
#         1    0.000    0.000    0.000    0.000 six.py:402(Module_six_moves_urllib_request)
#         1    0.000    0.000    0.000    0.000 six.py:480(Module_six_moves_urllib_robotparser)
#         1    0.000    0.000    0.000    0.000 __init__.py:46(PerformanceWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:91(UnsortedIndexError)
#         1    0.000    0.000    0.000    0.000 __init__.py:118(ParserError)
#         1    0.000    0.000    0.000    0.000 __init__.py:143(DtypeWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:212(ParserWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:253(MergeError)
#         1    0.000    0.000    0.000    0.000 __init__.py:328(DuplicateLabelError)
#         1    0.000    0.000    0.000    0.000 __init__.py:347(InvalidIndexError)
#         1    0.000    0.000    0.000    0.000 __init__.py:367(DataError)
#         1    0.000    0.000    0.000    0.000 __init__.py:383(SpecificationError)
#         1    0.000    0.000    0.000    0.000 __init__.py:433(SettingWithCopyWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:455(ChainedAssignmentError)
#         1    0.000    0.000    0.000    0.000 __init__.py:553(NumExprClobberingError)
#         1    0.000    0.000    0.000    0.000 __init__.py:598(IndexingError)
#         1    0.000    0.000    0.000    0.000 __init__.py:641(CSSWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:662(PossibleDataLossError)
#         1    0.000    0.000    0.000    0.000 __init__.py:674(ClosedFileError)
#         1    0.000    0.000    0.000    0.000 __init__.py:693(AttributeConflictWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:727(PossiblePrecisionLoss)
#         1    0.000    0.000    0.000    0.000 __init__.py:754(InvalidColumnName)
#         1    0.000    0.000    0.000    0.000 __init__.py:783(LossySetitemError)
#         1    0.000    0.000    0.000    0.000 __init__.py:793(NoBufferPresent)
#         1    0.000    0.000    0.000    0.000 __init__.py:799(InvalidComparison)
#         1    0.000    0.000    0.000    0.000 base.py:1986(nlevels)
#         1    0.000    0.000    0.000    0.000 range.py:216(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 managers.py:1847(ndim)
#         1    0.000    0.000    0.000    0.000 readers.py:559(_validate_names)
#         1    0.000    0.000    0.000    0.000 readers.py:1987(__enter__)
#         1    0.000    0.000    0.000    0.000 _pep440.py:150(<lambda>)
#         1    0.000    0.000    0.000    0.000 _optimize.py:3113(BracketError)
#         1    0.000    0.000    0.000    0.000 ivp.py:24(OdeResult)
#         1    0.000    0.000    0.000    0.000 release.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 boolalg.py:446(__eq__)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:67(HeuristicGCDFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:71(ModularGCDFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:74(HomomorphismFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:78(IsomorphismFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:82(ExtraneousFactors)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:86(EvaluationFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:90(RefinementFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:94(CoercionFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:98(NotInvertible)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:102(NotReversible)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:106(NotAlgebraic)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:110(DomainError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:114(PolynomialError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:118(UnificationFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:122(UnsolvableFactorError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:128(GeneratorsError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:151(MultivariatePolynomialError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:177(OptionError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:181(FlagError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:23(DMDomainError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:28(DMNotAField)
#         1    0.000    0.000    0.000    0.000 exceptions.py:33(DMFormatError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:38(DMNonInvertibleMatrixError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:43(DMRankError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:48(DMShapeError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:53(DMNonSquareMatrixError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:58(DMValueError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:24(NonPositiveDefiniteMatrixError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:76(DataConversionWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:94(DataDimensionalityWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:108(EfficiencyWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:119(FitFailedWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:131(SkipTestWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:140(UndefinedMetricWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:148(PositiveSpectrumWarning)
#         1    0.000    0.000    0.000    0.000 process.py:146(_WorkItem)
#         1    0.000    0.000    0.000    0.000 process_executor.py:1025(BrokenProcessPool)
#         1    0.000    0.000    0.000    0.000 rcsetup.py:375(validate_fontsize_None)
#         1    0.000    0.000    0.000    0.000 cp1251.py:25(StreamWriter)
#         1    0.000    0.000    0.000    0.000 patches.py:3534(CurveAB)
#         1    0.000    0.000    0.000    0.000 patches.py:3544(CurveFilledB)
#         1    0.000    0.000    0.000    0.000 _mathtext.py:964(DejaVuSansFontConstants)
#         1    0.000    0.000    0.000    0.000 streamplot.py:438(TerminateTrajectory)
#         1    0.000    0.000    0.000    0.000 streamplot.py:510(OutOfBounds)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_native_id}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 copy.py:102(_copy_immutable)
#         1    0.000    0.000    0.000    0.000 __init__.py:247(c_void_p)
#         1    0.000    0.000    0.000    0.000 errors.py:65(MultipartInvariantViolationDefect)
#         1    0.000    0.000    0.000    0.000 __init__.py:91(__init__)
#         1    0.000    0.000    0.000    0.000 config_init.py:673(register_plotting_backend_cb)
#         1    0.000    0.000    0.000    0.000 __init__.py:198(EmptyDataError)
#         1    0.000    0.000    0.000    0.000 __init__.py:714(DatabaseError)
#         1    0.000    0.000    0.000    0.000 nanops.py:57(set_use_bottleneck)
#         1    0.000    0.000    0.000    0.000 _new_distributions.py:93(_median_formula)
#         1    0.000    0.000    0.000    0.000 _new_distributions.py:96(_mode_formula)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:147(UnivariatePolynomialError)
#         2    0.000    0.000    0.000    0.000 groundtypes.py:26(__init__)
#         1    0.000    0.000    0.000    0.000 integerring.py:51(__init__)
#         1    0.000    0.000    0.000    0.000 rationalfield.py:45(__init__)
#         1    0.000    0.000    0.000    0.000 gaussiandomains.py:647(__init__)
#         1    0.000    0.000    0.000    0.000 expressionrawdomain.py:28(__init__)
#         1    0.000    0.000    0.000    0.000 process_executor.py:1034(TerminatedWorkerError)
#         1    0.000    0.000    0.000    0.000 patches.py:3549(CurveFilledAB)
#         1    0.000    0.000    0.000    0.000 _mathtext.py:960(DejaVuSerifFontConstants)
#         1    0.000    0.000    0.000    0.000 expr.py:1021(_eval_power)
#         1    0.000    0.000    0.000    0.000 gaussiandomains.py:442(__init__)
#         1    0.000    0.000    0.000    0.000 expressiondomain.py:163(__init__)
#       1/0    0.000    0.000    0.000          custom_ops.py:144(inner)
#    2687/0    0.039    0.000    0.000          <frozen importlib._bootstrap>:1349(_find_and_load)
#    2654/0    0.015    0.000    0.000          <frozen importlib._bootstrap>:1304(_find_and_load_unlocked)
#    2361/0    0.010    0.000    0.000          <frozen importlib._bootstrap_external>:989(exec_module)
#    3857/0    0.163    0.000    0.000          {built-in method builtins.exec}

# %%
p = pstats.Stats('profiling_results/initial')
p.strip_dirs().sort_stats("cumulative").print_stats()
# Out:
# Tue Dec 16 18:48:29 2025    profiling_results/initial
#
#          115716099 function calls (115647857 primitive calls) in 607.251 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.111    0.111  599.279  599.279 script.py:154(main)
#        17    1.580    0.093  589.691   34.688 model.py:87(fit)
#         3    1.030    0.343  522.786  174.262 script.py:121(cv_rmse_for_nterm_on_train)
#        17    2.008    0.118  466.872   27.463 FeatureSpaceConstruction.py:457(feature_space)
#        34  255.614    7.518  452.489   13.308 FeatureSpaceConstruction.py:333(combinations)
#        17   11.307    0.665  111.926    6.584 Regressor.py:25(__init__)
#       545  107.023    0.196  107.023    0.196 {built-in method torch.cat}
#        17   91.895    5.406   91.895    5.406 {method 'std' of 'torch._C.TensorBase' objects}
#        68   18.531    0.273   18.531    0.273 {built-in method torch.isinf}
#       136   18.267    0.134   18.267    0.134 {built-in method torch.any}
#       353    0.013    0.000   15.109    0.043 __init__.py:1(<module>)
#       130   12.390    0.095   12.390    0.095 {built-in method torch.isnan}
# 55885923/55885920   11.487    0.000   11.493    0.000 {method 'join' of 'str' objects}
#        17    0.436    0.026    8.219    0.483 Regressor.py:182(regressor_fit)
#  11166011    5.191    0.000    7.536    0.000 FeatureSpaceConstruction.py:389(<lambda>)
#  11166011    4.823    0.000    7.114    0.000 FeatureSpaceConstruction.py:395(<lambda>)
#  11166011    4.321    0.000    6.611    0.000 FeatureSpaceConstruction.py:388(<lambda>)
#  11166011    4.294    0.000    6.566    0.000 FeatureSpaceConstruction.py:381(<lambda>)
#  11166011    4.280    0.000    6.538    0.000 FeatureSpaceConstruction.py:374(<lambda>)
#        15    6.032    0.402    6.032    0.402 {built-in method gc.collect}
#        98    4.877    0.050    4.877    0.050 {built-in method torch.sum}
#        17    4.214    0.248    4.214    0.248 {built-in method torch.clone}
#        66    4.129    0.063    4.129    0.063 {method 'mean' of 'torch._C.TensorBase' objects}
#        47    3.840    0.082    3.840    0.082 {built-in method torch.mm}
#        15    0.202    0.013    3.553    0.237 Regressor.py:92(higher_dimension)
#      2203    3.514    0.002    3.517    0.002 {method 'extend' of 'list' objects}
#        68    3.025    0.044    3.025    0.044 {built-in method torch.div}
#    211/83    0.003    0.000    2.537    0.031 _ops.py:370(fallthrough)
#      2394    0.031    0.000    2.369    0.001 <frozen importlib._bootstrap_external>:1062(get_code)
#       151    2.317    0.015    2.317    0.015 {built-in method torch.combinations}
#        13    0.001    0.000    1.927    0.148 _jit_internal.py:1027(_overload)
#        34    0.342    0.010    1.886    0.055 FeatureSpaceConstruction.py:147(single_variable)
#        37    0.045    0.001    1.645    0.044 frame.py:5455(drop)
#      2394    0.011    0.000    1.615    0.001 <frozen importlib._bootstrap_external>:1183(get_data)
#        37    0.039    0.001    1.600    0.043 generic.py:4779(drop)
#        37    0.018    0.000    1.506    0.041 generic.py:4818(_drop_axis)
#        34    1.447    0.043    1.447    0.043 {built-in method torch.multiply}
#         1    0.000    0.000    1.329    1.329 Regressor_dimension.py:1(<module>)
#        34    1.310    0.039    1.310    0.039 {built-in method torch.sub}
#      2647    0.028    0.000    1.191    0.000 <frozen importlib._bootstrap>:1240(_find_spec)
#     10033    1.138    0.000    1.138    0.000 {built-in method nt.stat}
#         1    0.001    0.001    1.136    1.136 _stats_py.py:1(<module>)
#      2624    0.003    0.000    1.133    0.000 <frozen importlib._bootstrap_external>:1520(find_spec)
#      2624    0.008    0.000    1.130    0.000 <frozen importlib._bootstrap_external>:1491(_get_spec)
#        32    1.108    0.035    1.108    0.035 {built-in method torch.topk}
#      9569    0.007    0.000    1.094    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#      2394    1.074    0.000    1.074    0.000 {built-in method _io.open_code}
#        17    0.001    0.000    1.072    0.063 FeatureSpaceConstruction.py:27(__init__)
#      3197    0.036    0.000    1.041    0.000 <frozen importlib._bootstrap_external>:1593(find_spec)
#         1    0.000    0.000    1.029    1.029 DimensionalFeatureSpaceConstruction.py:1(<module>)
# 5490/5358    0.088    0.000    0.966    0.000 {built-in method builtins.__build_class__}
#        49    0.963    0.020    0.963    0.020 {built-in method torch._C._linalg.linalg_lstsq}
#      10/8    0.000    0.000    0.907    0.113 _ops.py:172(py_functionalize_impl)
#    171/58    0.028    0.000    0.905    0.016 _ops.py:308(py_impl)
#       503    0.817    0.002    0.848    0.002 {built-in method builtins.eval}
#        37    0.054    0.001    0.770    0.021 base.py:7097(drop)
#         1    0.000    0.000    0.726    0.726 pyplot.py:1(<module>)
#       6/5    0.000    0.000    0.684    0.137 _ops.py:321(py_autograd_impl)
#    136/68    0.000    0.000    0.645    0.009 _jit_internal.py:617(fn)
#        68    0.000    0.000    0.644    0.009 functional.py:786(_unique_impl)
#       113    0.002    0.000    0.612    0.005 custom_ops.py:185(__init__)
#       113    0.001    0.000    0.607    0.005 custom_ops.py:598(_register_to_dispatcher)
#         8    0.000    0.000    0.582    0.073 api.py:1(<module>)
#        94    0.003    0.000    0.582    0.006 base.py:3827(get_indexer)
#       113    0.001    0.000    0.504    0.004 library.py:187(_register_fake)
# 2610/2518    0.006    0.000    0.499    0.000 <frozen importlib._bootstrap>:806(module_from_spec)
#      2394    0.492    0.000    0.492    0.000 {method 'read' of '_io.BufferedReader' objects}
#        56    0.001    0.000    0.486    0.009 base.py:6174(get_indexer_for)
#        17    0.003    0.000    0.474    0.028 script.py:95(predict_from_equation)
#       113    0.001    0.000    0.442    0.004 fake_impl.py:34(register)
#      3660    0.005    0.000    0.431    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#    343/62    0.023    0.000    0.418    0.007 library.py:287(impl)
#        51    0.402    0.008    0.414    0.008 {built-in method torch.tensor}
#     83/18    0.001    0.000    0.412    0.023 custom_ops.py:334(inner)
#      3336    0.003    0.000    0.405    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#      2394    0.089    0.000    0.404    0.000 <frozen importlib._bootstrap_external>:751(_compile_bytecode)
#       141    0.001    0.000    0.402    0.003 inspect.py:1070(findsource)
#       113    0.000    0.000    0.399    0.004 utils.py:35(get_source)
#       113    0.002    0.000    0.399    0.004 inspect.py:1684(getframeinfo)
#   188/186    0.000    0.000    0.396    0.002 <frozen importlib._bootstrap_external>:1287(create_module)
#   188/186    0.170    0.001    0.395    0.002 {built-in method _imp.create_dynamic}
#         2    0.000    0.000    0.389    0.194 batchnorm.py:1(<module>)
#         2    0.000    0.000    0.388    0.194 _functions.py:1(<module>)
#   356/354    0.008    0.000    0.380    0.001 inspect.py:988(getmodule)
#        40    0.024    0.001    0.377    0.009 managers.py:642(reindex_indexer)
#       106    0.004    0.000    0.360    0.003 artist.py:158(_update_set_signature_and_docstring)
#    952/22    0.003    0.000    0.358    0.016 {built-in method builtins.__import__}
#       105    0.001    0.000    0.354    0.003 artist.py:125(__init_subclass__)
#        55    0.085    0.002    0.354    0.006 managers.py:727(_slice_take_blocks_ax0)
#         1    0.300    0.300    0.348    0.348 __init__.py:162(_load_dll_libraries)
#         1    0.000    0.000    0.345    0.345 figure.py:1(<module>)
#         2    0.000    0.000    0.341    0.170 model.py:1(<module>)
#        34    0.000    0.000    0.332    0.010 functional.py:1057(_return_inverse)
#        34    0.331    0.010    0.331    0.010 {built-in method unique_dim}
#        94    0.007    0.000    0.330    0.004 base.py:6725(_maybe_cast_listlike_indexer)
#       361    0.027    0.000    0.326    0.001 base.py:7659(ensure_index)
#     10083    0.106    0.000    0.324    0.000 __init__.py:280(_compile)
#       108    0.009    0.000    0.323    0.003 base.py:475(__new__)
#       153    0.323    0.002    0.323    0.002 {built-in method torch.arange}
#        18    0.000    0.000    0.319    0.018 frame.py:4962(select_dtypes)
#         1    0.000    0.000    0.319    0.319 image.py:1(<module>)
# 56695/55292    0.026    0.000    0.315    0.000 {built-in method builtins.hasattr}
#        34    0.000    0.000    0.313    0.009 _tensor.py:1032(unique)
#        34    0.000    0.000    0.313    0.009 functional.py:1041(_return_output)
#        34    0.312    0.009    0.312    0.009 {built-in method torch._unique2}
#      2394    0.310    0.000    0.310    0.000 {built-in method marshal.loads}
#       188    0.029    0.000    0.306    0.002 construction.py:517(sanitize_array)
#         1    0.000    0.000    0.302    0.302 backend_bases.py:1(<module>)
#   188/131    0.000    0.000    0.294    0.002 <frozen importlib._bootstrap_external>:1295(exec_module)
#   188/131    0.040    0.000    0.293    0.002 {built-in method _imp.exec_dynamic}
#       120    0.001    0.000    0.285    0.002 artist.py:1832(kwdoc)
#     40/39    0.000    0.000    0.284    0.007 __init__.py:73(import_module)
#     40/39    0.000    0.000    0.284    0.007 <frozen importlib._bootstrap>:1375(_gcd_import)
#   2778/85    0.007    0.000    0.279    0.003 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.276    0.276 cond.py:1(<module>)
#        86    0.099    0.001    0.276    0.003 base.py:2320(is_unique)
#     31/30    0.000    0.000    0.274    0.009 __init__.py:141(__getattr__)
#         1    0.000    0.000    0.273    0.273 associative_scan.py:1(<module>)
#       976    0.007    0.000    0.264    0.000 <frozen ntpath>:692(realpath)
#        10    0.000    0.000    0.258    0.026 linear.py:1(<module>)
#         3    0.000    0.000    0.256    0.085 generic.py:1(<module>)
#       109    0.129    0.001    0.251    0.002 cast.py:1166(maybe_infer_to_datetimelike)
#        15    0.249    0.017    0.249    0.017 {built-in method torch.matmul}
#         1    0.000    0.000    0.246    0.246 polyfuncs.py:1(<module>)
#         1    0.000    0.000    0.245    0.245 specialpolys.py:1(<module>)
#       210    0.001    0.000    0.244    0.001 _docscrape.py:579(__init__)
#      1958    0.243    0.000    0.243    0.000 {built-in method nt._getfinalpathname}
#       120    0.006    0.000    0.242    0.002 artist.py:1593(pprint_setters)
#      2394    0.004    0.000    0.241    0.000 <frozen importlib._bootstrap_external>:1202(path_stats)
#         7    0.000    0.000    0.237    0.034 _base.py:1(<module>)
#         1    0.000    0.000    0.237    0.237 distributions.py:1(<module>)
#       325    0.001    0.000    0.234    0.001 dataclasses.py:1264(wrap)
#       325    0.014    0.000    0.233    0.001 dataclasses.py:921(_process_class)
#       479    0.232    0.000    0.232    0.000 {built-in method builtins.print}
#       120    0.015    0.000    0.232    0.002 take.py:59(take_nd)
#         1    0.000    0.000    0.227    0.227 rings.py:1(<module>)
#        17    0.000    0.000    0.226    0.013 frame.py:11752(var)
#        17    0.000    0.000    0.226    0.013 generic.py:12403(var)
#        17    0.000    0.000    0.226    0.013 generic.py:12359(_stat_function_ddof)
# 1435/1418    0.132    0.000    0.226    0.000 {built-in method numpy.asarray}
#        17    0.020    0.001    0.226    0.013 frame.py:11462(_reduce)
#        15    0.223    0.015    0.223    0.015 {method 'repeat' of 'torch._C.TensorBase' objects}
#        34    0.223    0.007    0.223    0.007 {built-in method torch.pow}
# 467581/462923    0.087    0.000    0.220    0.000 {built-in method builtins.len}
#       120    0.132    0.001    0.217    0.002 take.py:120(_take_nd_ndarray)
#       216    0.001    0.000    0.216    0.001 _docscrape.py:140(__init__)
#         2    0.000    0.000    0.214    0.107 text.py:1(<module>)
#        11    0.000    0.000    0.212    0.019 base.py:1(<module>)
#        18    0.000    0.000    0.211    0.012 managers.py:514(_get_data_subset)
#        18    0.001    0.000    0.211    0.012 managers.py:543(_combine)
#         2    0.000    0.000    0.211    0.105 _array_api.py:1(<module>)
#        18    0.000    0.000    0.209    0.012 fromnumeric.py:968(sort)
#      7848    0.106    0.000    0.201    0.000 inspect.py:882(cleandoc)
#       381    0.007    0.000    0.200    0.001 _compiler.py:740(compile)
#        18    0.198    0.011    0.198    0.011 {method 'sort' of 'numpy.ndarray' objects}
#      4409    0.015    0.000    0.196    0.000 artist.py:1461(get_valid_values)
#         1    0.000    0.000    0.195    0.195 aoti_call_delegate.py:1(<module>)
#         1    0.001    0.001    0.195    0.195 module.py:1(<module>)
#     26/10    0.000    0.000    0.194    0.019 _ops.py:280(__init__)
#        18    0.000    0.000    0.186    0.010 _split.py:378(split)
#        18    0.014    0.001    0.185    0.010 _split.py:117(split)
#         1    0.000    0.000    0.184    0.184 _invoke_quant.py:1(<module>)
#     15649    0.116    0.000    0.180    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
#         1    0.000    0.000    0.179    0.179 pycode.py:1(<module>)
#        86    0.100    0.001    0.178    0.002 base.py:843(_engine)
#         1    0.000    0.000    0.177    0.177 codeprinter.py:1(<module>)
#        18    0.000    0.000    0.171    0.010 _split.py:150(_iter_test_masks)
#        18    0.028    0.002    0.171    0.009 _split.py:518(_iter_test_indices)
#        44    0.001    0.000    0.169    0.004 blocks.py:1353(take_nd)
#      7722    0.008    0.000    0.166    0.000 inspect.py:863(getdoc)
#       216    0.005    0.000    0.164    0.001 _docscrape.py:388(_parse)
#      2803    0.003    0.000    0.161    0.000 inspect.py:3339(signature)
# 180266/179768    0.056    0.000    0.160    0.000 {built-in method builtins.getattr}
#        17    0.000    0.000    0.159    0.009 managers.py:1502(reduce)
#      2803    0.003    0.000    0.158    0.000 inspect.py:3077(from_callable)
#        17    0.000    0.000    0.157    0.009 blocks.py:400(reduce)
#         1    0.000    0.000    0.157    0.157 _chunking.py:1(<module>)
#        17    0.000    0.000    0.157    0.009 frame.py:11485(blk_func)
#        17    0.000    0.000    0.157    0.009 nanops.py:76(_f)
#        17    0.000    0.000    0.156    0.009 nanops.py:111(f)
#        17    0.066    0.004    0.156    0.009 nanops.py:954(nanvar)
#         4    0.106    0.027    0.156    0.039 validation.py:1439(check_random_state)
#         1    0.000    0.000    0.156    0.156 _param_validation.py:1(<module>)
# 4046/2807    0.026    0.000    0.155    0.000 inspect.py:2497(_signature_from_callable)
#         1    0.000    0.000    0.154    0.154 validation.py:1(<module>)
#       644    0.000    0.000    0.154    0.000 __init__.py:226(compile)
#         1    0.000    0.000    0.153    0.153 _sputils.py:1(<module>)
#      2526    0.002    0.000    0.152    0.000 __init__.py:179(sub)
#         6    0.000    0.000    0.151    0.025 arrayprint.py:619(array2string)
#        24    0.000    0.000    0.151    0.006 arrayprint.py:564(wrapper)
#         4    0.000    0.000    0.151    0.038 _util.py:1(<module>)
#         6    0.000    0.000    0.151    0.025 arrayprint.py:581(_array2string)
#        21    0.000    0.000    0.151    0.007 arrayprint.py:1704(_array_str_implementation)
#        34    0.079    0.002    0.149    0.004 __init__.py:209(findall)
#      1295    0.008    0.000    0.143    0.000 dataclasses.py:449(_create_fn)
#        20    0.018    0.001    0.141    0.007 common.py:266(index_labels_to_array)
#         1    0.001    0.001    0.140    0.140 _continuous_distns.py:1(<module>)
#        17    0.009    0.001    0.140    0.008 script.py:88(_transform_equation)
#         6    0.000    0.000    0.138    0.023 arrayprint.py:510(_get_format_function)
#         6    0.000    0.000    0.138    0.023 arrayprint.py:469(<lambda>)
#         6    0.000    0.000    0.138    0.023 arrayprint.py:975(__init__)
#         6    0.048    0.008    0.138    0.023 arrayprint.py:1001(fillFormat)
#       381    0.002    0.000    0.135    0.000 _parser.py:969(parse)
#         1    0.000    0.000    0.135    0.135 frame.py:1(<module>)
#        10    0.000    0.000    0.135    0.013 __init__.py:720(__getattr__)
#         1    0.000    0.000    0.133    0.133 _geometric_slerp.py:1(<module>)
#  1155/381    0.004    0.000    0.133    0.000 _parser.py:452(_parse_sub)
#         1    0.005    0.005    0.132    0.132 {built-in method torch._C._initExtension}
#         2    0.000    0.000    0.132    0.066 distance.py:1(<module>)
#         1    0.000    0.000    0.132    0.132 dataloader.py:1(<module>)
#        15    0.033    0.002    0.131    0.009 _tensor.py:1145(__len__)
#  1429/413    0.026    0.000    0.131    0.000 _parser.py:512(_parse)
#       325    0.000    0.000    0.130    0.000 dataclasses.py:1247(dataclass)
# 10405/9926    0.022    0.000    0.128    0.000 typing.py:392(inner)
#         3    0.000    0.000    0.128    0.043 function.py:1(<module>)
#         2    0.000    0.000    0.126    0.063 expr.py:1(<module>)
#       432    0.061    0.000    0.126    0.000 basic.py:212(__init_subclass__)
#         1    0.000    0.000    0.123    0.123 _axes.py:1(<module>)
#        43    0.030    0.001    0.123    0.003 common.py:231(asarray_tuplesafe)
#       204    0.027    0.000    0.122    0.001 numeric.py:324(full)
#         3    0.000    0.000    0.121    0.040 numbers.py:1(<module>)
#        32    0.118    0.004    0.118    0.004 {built-in method torch.abs}
#         1    0.000    0.000    0.117    0.117 rcsetup.py:1(<module>)
#      4788    0.020    0.000    0.116    0.000 <frozen importlib._bootstrap_external>:482(cache_from_source)
#        24    0.000    0.000    0.116    0.005 managers.py:576(copy)
#        17    0.116    0.007    0.116    0.007 {method 'view' of 'torch._C.TensorBase' objects}
#        80    0.011    0.000    0.115    0.001 base.py:6436(_should_compare)
# 306048/305995    0.071    0.000    0.114    0.000 {built-in method builtins.isinstance}
#      7119    0.036    0.000    0.113    0.000 <frozen importlib._bootstrap>:304(acquire)
#       482    0.110    0.000    0.111    0.000 base.py:5335(__contains__)
#         1    0.000    0.000    0.109    0.109 autograd_function.py:1(<module>)
#      1844    0.003    0.000    0.108    0.000 series.py:1107(__getitem__)
#         2    0.000    0.000    0.107    0.054 base_hop.py:60(__init__)
#      1195    0.004    0.000    0.106    0.000 inspect.py:976(getabsfile)
#       115    0.098    0.001    0.103    0.001 base.py:2751(inferred_type)
#         1    0.000    0.000    0.101    0.101 mul.py:1(<module>)
#       110    0.002    0.000    0.100    0.001 _distn_infrastructure.py:1863(__init__)
#      2074    0.009    0.000    0.099    0.000 _ops.py:1190(__getattr__)
#      2518    0.032    0.000    0.098    0.000 inspect.py:2393(_signature_from_function)
#         1    0.000    0.000    0.097    0.097 _arraypad_impl.py:1(<module>)
#       227    0.001    0.000    0.097    0.000 artist.py:1413(__init__)
#      1362    0.008    0.000    0.096    0.000 inspect.py:951(getsourcefile)
#         1    0.000    0.000    0.096    0.096 _index_tricks_impl.py:1(<module>)
#         1    0.000    0.000    0.096    0.096 partfrac.py:1(<module>)
#         1    0.000    0.000    0.096    0.096 decorator.py:65(xthreaded)
#         1    0.000    0.000    0.096    0.096 decorator.py:16(threaded_factory)
#      2610    0.012    0.000    0.096    0.000 <frozen importlib._bootstrap>:733(_init_module_attrs)
#      4400    0.008    0.000    0.096    0.000 <frozen importlib._bootstrap>:463(_lock_unlock_module)
#        17    0.000    0.000    0.095    0.006 indexing.py:2668(check_bool_indexer)
#       227    0.031    0.000    0.095    0.000 artist.py:1433(get_aliases)
#       157    0.000    0.000    0.095    0.001 generic.py:6306(__getattr__)
#        17    0.000    0.000    0.095    0.006 utils.py:419(check_array_indexer)
#       102    0.000    0.000    0.095    0.001 base.py:5564(equals)
#        68    0.000    0.000    0.095    0.001 base.py:5449(_can_hold_identifiers_and_holds_name)
#        71    0.000    0.000    0.094    0.001 managers.py:1801(_consolidate_inplace)
#        15    0.000    0.000    0.094    0.006 missing.py:466(array_equivalent)
#        15    0.094    0.006    0.094    0.006 missing.py:564(_array_equivalent_object)
#         4    0.000    0.000    0.094    0.023 managers.py:2278(_consolidate)
#         1    0.000    0.000    0.094    0.094 patches.py:1(<module>)
#       341    0.093    0.000    0.093    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.093    0.093 nested_tensor.py:1(<module>)
#      2801    0.014    0.000    0.093    0.000 textwrap.py:419(dedent)
#         1    0.000    0.000    0.092    0.092 nested_int.py:1(<module>)
#         1    0.000    0.000    0.091    0.091 _classification_threshold.py:1(<module>)
#       113    0.005    0.000    0.091    0.001 autograd.py:23(make_autograd_impl)
#       816    0.004    0.000    0.088    0.000 _pytree.py:1379(tree_map_)
#         5    0.000    0.000    0.088    0.018 memory.py:1(<module>)
#        63    0.001    0.000    0.087    0.001 _axis_nan_policy.py:418(axis_nan_policy_decorator)
#         1    0.000    0.000    0.085    0.085 font_manager.py:1(<module>)
#        15    0.085    0.006    0.085    0.006 {built-in method torch.min}
#        15    0.085    0.006    0.085    0.006 {built-in method torch._C._get_tracing_state}
#        61    0.001    0.000    0.084    0.001 typing_extensions.py:2942(__call__)
#      1140    0.006    0.000    0.084    0.000 _ops.py:1350(__getattr__)
#         1    0.000    0.000    0.082    0.082 ctx_fp.py:1(<module>)
#      3341    0.003    0.000    0.081    0.000 <frozen importlib._bootstrap_external>:1469(_path_importer_cache)
#       448    0.002    0.000    0.080    0.000 frame.py:4073(__getitem__)
#        64    0.001    0.000    0.080    0.001 _array_api.py:806(decorator)
#         4    0.000    0.000    0.079    0.020 functional.py:1(<module>)
#         1    0.000    0.000    0.078    0.078 defmatrix.py:1(<module>)
#         2    0.000    0.000    0.077    0.039 _pytree.py:1(<module>)
#       318    0.002    0.000    0.077    0.000 <frozen importlib._bootstrap_external>:1456(_path_hooks)
#         1    0.000    0.000    0.077    0.077 ctx_base.py:1(<module>)
#      1197    0.005    0.000    0.077    0.000 _docscrape.py:201(_read_to_next_section)
#         1    0.000    0.000    0.077    0.077 _vmap_internals.py:1(<module>)
#      2719    0.004    0.000    0.076    0.000 <frozen importlib._bootstrap>:416(__enter__)
#         3    0.000    0.000    0.076    0.025 _linalg.py:1(<module>)
#        50    0.000    0.000    0.076    0.002 fromnumeric.py:51(_wrapfunc)
#      4976    0.003    0.000    0.075    0.000 <frozen importlib._bootstrap>:632(cached)
#       579    0.075    0.000    0.075    0.000 {built-in method numpy.empty}
#       923    0.005    0.000    0.074    0.000 __init__.py:64(_add_op_to_registry)
#       957    0.074    0.000    0.074    0.000 {built-in method nt._path_exists}
#         3    0.000    0.000    0.073    0.024 __config__.py:1(<module>)
#      2582    0.005    0.000    0.072    0.000 <frozen importlib._bootstrap_external>:611(_get_cached)
#        24    0.001    0.000    0.072    0.003 utils.py:1(<module>)
#      5363    0.045    0.000    0.071    0.000 {method 'sub' of 're.Pattern' objects}
#     58/56    0.000    0.000    0.071    0.001 missing.py:101(isna)
#     58/56    0.000    0.000    0.071    0.001 missing.py:184(_isna)
#        68    0.001    0.000    0.071    0.001 _util.py:1202(decorator)
#         1    0.000    0.000    0.071    0.071 axes3d.py:1(<module>)
#      2835    0.070    0.000    0.070    0.000 {method 'findall' of 're.Pattern' objects}
#         1    0.000    0.000    0.070    0.070 f2py2e.py:1(<module>)
#       549    0.001    0.000    0.070    0.000 __init__.py:205(decomposition_decorator)
#      1229    0.003    0.000    0.070    0.000 _docscrape.py:212(_read_sections)
#        37    0.069    0.002    0.069    0.002 missing.py:261(_isna_array)
#        17    0.000    0.000    0.069    0.004 nanops.py:209(_maybe_get_mask)
#         1    0.000    0.000    0.069    0.069 plistlib.py:1(<module>)
#         1    0.000    0.000    0.069    0.069 graph_settings.py:1(<module>)
#         6    0.000    0.000    0.067    0.011 managers.py:2295(_merge_blocks)
#         6    0.000    0.000    0.067    0.011 fromnumeric.py:1129(argsort)
#         6    0.067    0.011    0.067    0.011 {method 'argsort' of 'numpy.ndarray' objects}
#        86    0.000    0.000    0.067    0.001 dispatcher.py:178(add)
#        96    0.018    0.000    0.067    0.001 _tensor.py:38(wrapped)
#        86    0.000    0.000    0.066    0.001 dispatcher.py:222(reorder)
#        22    0.066    0.003    0.066    0.003 {built-in method torch.full}
#       430    0.013    0.000    0.066    0.000 doccer.py:29(docformat)
#       433    0.029    0.000    0.065    0.000 assumptions.py:614(_prepare_class_assumptions)
#         6    0.000    0.000    0.065    0.011 linear_relu.py:1(<module>)
#  1228/878    0.001    0.000    0.065    0.000 typing.py:515(__getitem__)
#      2809    0.064    0.000    0.064    0.000 _parser.py:113(__init__)
#         1    0.000    0.000    0.064    0.064 polytools.py:1(<module>)
#         1    0.000    0.000    0.063    0.063 graph_drawer.py:1(<module>)
#      4579    0.046    0.000    0.063    0.000 functools.py:35(update_wrapper)
#         2    0.000    0.000    0.063    0.031 _delegation.py:1(<module>)
#       240    0.045    0.000    0.062    0.000 frame.py:1051(shape)
#         2    0.000    0.000    0.062    0.031 array.py:1(<module>)
#       227    0.020    0.000    0.062    0.000 artist.py:1511(get_setters)
#         1    0.000    0.000    0.062    0.062 widgets.py:1(<module>)
#         1    0.000    0.000    0.061    0.061 _optimize.py:1(<module>)
#    222963    0.061    0.000    0.061    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.061    0.061 shape_prop.py:1(<module>)
#      1771    0.004    0.000    0.060    0.000 {built-in method builtins.next}
#       131    0.001    0.000    0.060    0.000 _distn_infrastructure.py:830(_construct_doc)
#         1    0.000    0.000    0.059    0.059 collections.py:1(<module>)
#         1    0.000    0.000    0.058    0.058 bsplines.py:1(<module>)
#         1    0.000    0.000    0.058    0.058 eval.py:1(<module>)
#         2    0.000    0.000    0.058    0.029 _funcs.py:1(<module>)
#       570    0.000    0.000    0.057    0.000 __init__.py:214(register)
#        32    0.057    0.002    0.057    0.002 {built-in method torch.sqrt}
#       113    0.057    0.001    0.057    0.001 {method 'unsqueeze' of 'torch._C.TensorBase' objects}
#      1391    0.007    0.000    0.056    0.000 typing.py:1269(__init__)
#       836    0.005    0.000    0.056    0.000 typing.py:694(Union)
#         1    0.000    0.000    0.056    0.056 _distn_infrastructure.py:1(<module>)
#         2    0.000    0.000    0.055    0.028 _at.py:1(<module>)
#        37    0.025    0.001    0.055    0.001 base.py:6971(delete)
#       438    0.005    0.000    0.055    0.000 _docscrape.py:224(_parse_param_list)
#         1    0.000    0.000    0.055    0.055 colors.py:1(<module>)
#        70    0.001    0.000    0.055    0.001 _param_validation.py:187(wrapper)
#         1    0.000    0.000    0.054    0.054 _invoke_quant.py:26(__init__)
#      7119    0.012    0.000    0.054    0.000 <frozen importlib._bootstrap>:162(__enter__)
#      4277    0.016    0.000    0.054    0.000 _ops.py:1137(_has_script_object_arg)
#         2    0.000    0.000    0.054    0.027 __init__.py:901(entry_points)
#      5933    0.004    0.000    0.054    0.000 __init__.py:174(search)
#         9    0.000    0.000    0.053    0.006 _base.py:783(__init_subclass__)
#       110    0.000    0.000    0.053    0.000 __init__.py:910(<genexpr>)
#         1    0.053    0.053    0.053    0.053 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.053    0.053 constructor.py:1(<module>)
#         1    0.000    0.000    0.053    0.053 _invoke_quant.py:12(__init__)
#         1    0.000    0.000    0.053    0.053 engines.py:1(<module>)
# 17745/16710    0.030    0.000    0.053    0.000 {built-in method __new__ of type object at 0x00007FFA573338F0}
#       325    0.003    0.000    0.052    0.000 dataclasses.py:568(_init_fn)
#         1    0.000    0.000    0.052    0.052 _fontconfig_pattern.py:1(<module>)
#         1    0.000    0.000    0.052    0.052 fake_tensor.py:1(<module>)
#         1    0.000    0.000    0.051    0.051 _cloudpickle_wrapper.py:1(<module>)
#       255    0.051    0.000    0.051    0.000 {built-in method torch.empty}
#         1    0.000    0.000    0.051    0.051 base_events.py:1(<module>)
#         4    0.000    0.000    0.051    0.013 _helpers.py:1(<module>)
#         1    0.000    0.000    0.051    0.051 immutable.py:1(<module>)
#         1    0.000    0.000    0.051    0.051 _unsupervised.py:1(<module>)
#         1    0.000    0.000    0.050    0.050 capi_maps.py:1(<module>)
#         8    0.001    0.000    0.050    0.006 core.py:1(<module>)
#         1    0.000    0.000    0.050    0.050 _minimize.py:1(<module>)
#         8    0.000    0.000    0.049    0.006 random.py:889(getrandbits)
#         9    0.049    0.005    0.049    0.005 {built-in method nt.urandom}
#         1    0.000    0.000    0.049    0.049 point.py:1(<module>)
#         1    0.000    0.000    0.049    0.049 pairwise.py:1(<module>)
#        96    0.048    0.001    0.048    0.001 {method 'pow' of 'torch._C.TensorBase' objects}
#     14006    0.026    0.000    0.048    0.000 inspect.py:2739(__init__)
#       131    0.001    0.000    0.048    0.000 traceback.py:221(extract_stack)
#         1    0.000    0.000    0.048    0.048 _linprog.py:1(<module>)
#       131    0.000    0.000    0.047    0.000 traceback.py:377(extract)
#         1    0.000    0.000    0.047    0.047 entity.py:1(<module>)
#       131    0.003    0.000    0.046    0.000 traceback.py:399(_extract_from_extended_frame_gen)
#       424    0.001    0.000    0.046    0.000 linecache.py:52(checkcache)
#       457    0.007    0.000    0.046    0.000 wrappers.py:255(_out_wrapper)
#         2    0.000    0.000    0.046    0.023 _support_alternative_backends.py:1(<module>)
#   128/117    0.001    0.000    0.046    0.000 _docstring.py:122(__call__)
#        19    0.045    0.002    0.045    0.002 indexing.py:162(iloc)
#         1    0.000    0.000    0.045    0.045 _split.py:2757(train_test_split)
#       318    0.007    0.000    0.045    0.000 <frozen importlib._bootstrap_external>:1644(_fill_cache)
#        42    0.000    0.000    0.045    0.001 fromnumeric.py:69(_wrapreduction)
#         1    0.000    0.000    0.045    0.045 interpreter.py:1(<module>)
#         2    0.000    0.000    0.045    0.022 _split.py:1897(split)
#         7    0.000    0.000    0.045    0.006 fromnumeric.py:3052(max)
#       381    0.001    0.000    0.045    0.000 _compiler.py:573(_code)
#         2    0.031    0.016    0.045    0.022 _split.py:1931(_iter_indices)
#      4871    0.015    0.000    0.044    0.000 _docscrape.py:67(read_to_condition)
#       978    0.002    0.000    0.044    0.000 _ops.py:1146(__init__)
#         3    0.000    0.000    0.044    0.015 _basic.py:1(<module>)
#       127    0.001    0.000    0.043    0.000 library.py:95(__init__)
#         1    0.000    0.000    0.043    0.043 crackfortran.py:1(<module>)
#         1    0.000    0.000    0.043    0.043 _python_dispatch.py:1(<module>)
#        50    0.042    0.001    0.042    0.001 {method 'flatten' of 'torch._C.TensorBase' objects}
#        77    0.042    0.001    0.042    0.001 _validators.py:226(validate_bool_kwarg)
#       978    0.001    0.000    0.042    0.000 __init__.py:751(__setitem__)
#         1    0.000    0.000    0.041    0.041 device_mesh.py:1(<module>)
#       199    0.041    0.000    0.041    0.000 warnings.py:484(__enter__)
#       206    0.041    0.000    0.041    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.040    0.040 _registrations.py:1(<module>)
#        17    0.036    0.002    0.040    0.002 script.py:70(rmse)
#        31    0.006    0.000    0.040    0.001 __init__.py:887(_rc_params_in_file)
#      7119    0.019    0.000    0.040    0.000 <frozen importlib._bootstrap>:124(setdefault)
#         4    0.000    0.000    0.040    0.010 _internal.py:1(<module>)
#         1    0.000    0.000    0.039    0.039 plot.py:1(<module>)
#       108    0.000    0.000    0.039    0.000 __init__.py:469(entry_points)
#       129    0.000    0.000    0.039    0.000 {method 'any' of 'numpy.ndarray' objects}
#       129    0.000    0.000    0.039    0.000 _methods.py:57(_any)
#         3    0.000    0.000    0.038    0.013 generic.py:4164(_take_with_is_copy)
#         3    0.000    0.000    0.038    0.013 generic.py:4049(take)
#      3616    0.003    0.000    0.038    0.000 _docscrape.py:77(read_to_next_empty_line)
#         2    0.000    0.000    0.038    0.019 dense.py:1(<module>)
#         3    0.000    0.000    0.038    0.013 managers.py:888(take)
#        66    0.038    0.001    0.038    0.001 base.py:3962(_get_indexer)
#       318    0.002    0.000    0.038    0.000 <frozen zipimport>:64(__init__)
#        43    0.000    0.000    0.038    0.001 dispatcher.py:147(_)
#      3832    0.016    0.000    0.038    0.000 _docscrape.py:168(_is_at_section)
#         3    0.000    0.000    0.038    0.013 datetimes.py:1(<module>)
#         1    0.000    0.000    0.038    0.038 distributed_c10d.py:1(<module>)
#         3    0.000    0.000    0.038    0.013 platform.py:1016(machine)
#         5    0.000    0.000    0.038    0.008 platform.py:890(uname)
#         2    0.000    0.000    0.038    0.019 platform.py:322(_wmi_query)
#         2    0.038    0.019    0.038    0.019 {built-in method _wmi.exec_query}
#         2    0.000    0.000    0.037    0.019 indexing.py:1(<module>)
#        14    0.000    0.000    0.037    0.003 _docstring.py:73(__missing__)
#       318    0.001    0.000    0.037    0.000 <frozen importlib._bootstrap_external>:1685(path_hook_for_FileFinder)
#      2478    0.037    0.000    0.037    0.000 {method '__exit__' of '_io._IOBase' objects}
#      2582    0.006    0.000    0.037    0.000 <frozen importlib._bootstrap_external>:1588(_get_spec)
#      1972    0.034    0.000    0.036    0.000 _ops.py:773(__init__)
#        24    0.001    0.000    0.036    0.002 _util.py:277(decorator)
#       447    0.002    0.000    0.036    0.000 frame.py:4637(_get_item_cache)
#         1    0.000    0.000    0.036    0.036 __init__.py:2817(_import_device_backends)
#  2729/381    0.015    0.000    0.036    0.000 _compiler.py:37(_compile)
#         1    0.000    0.000    0.036    0.036 art3d.py:1(<module>)
#       113    0.000    0.000    0.036    0.000 custom_ops.py:902(get_library_allowing_overwrite)
#       151    0.036    0.000    0.036    0.000 {method 'permute' of 'torch._C.TensorBase' objects}
#         2    0.000    0.000    0.035    0.018 bn_relu.py:1(<module>)
#       328    0.001    0.000    0.035    0.000 dataclasses.py:661(_cmp_fn)
#         1    0.000    0.000    0.035    0.035 sympify.py:1(<module>)
#         1    0.000    0.000    0.035    0.035 _new_distributions.py:1(<module>)
#        86    0.006    0.000    0.035    0.000 conflict.py:24(ambiguities)
#       109    0.001    0.000    0.035    0.000 __init__.py:811(read_text)
#         1    0.000    0.000    0.035    0.035 _symbolic_trace.py:1(<module>)
#         1    0.000    0.000    0.035    0.035 _utils_internal.py:1(<module>)
#       426    0.034    0.000    0.034    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#       460    0.002    0.000    0.034    0.000 frame.py:3994(_ixs)
#         3    0.000    0.000    0.034    0.011 _distribution_infrastructure.py:1317(_combine_docs)
#       334    0.034    0.000    0.034    0.000 {built-in method nt.listdir}
#         1    0.000    0.000    0.034    0.034 _axes.py:67(Axes)
#       322    0.001    0.000    0.034    0.000 dataclasses.py:627(_repr_fn)
#      7119    0.016    0.000    0.034    0.000 <frozen importlib._bootstrap>:426(_get_module_lock)
#    146433    0.033    0.000    0.033    0.000 {method 'lstrip' of 'str' objects}
#       169    0.033    0.000    0.033    0.000 {method 'tolist' of 'torch._C.TensorBase' objects}
#    133880    0.033    0.000    0.033    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.033    0.017 _adapters.py:1(<module>)
#       111    0.000    0.000    0.033    0.000 pathlib.py:1022(read_text)
#      1140    0.002    0.000    0.033    0.000 _ops.py:1387(_get_packet)
#         1    0.000    0.000    0.033    0.033 _guards.py:1(<module>)
#       439    0.017    0.000    0.033    0.000 doccer.py:225(indentcount_lines)
#      5226    0.004    0.000    0.032    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000    0.032    0.032 _morestats.py:1(<module>)
#     18498    0.027    0.000    0.032    0.000 _ops.py:1138(<genexpr>)
#      4404    0.021    0.000    0.032    0.000 inspect.py:3025(__init__)
#         2    0.000    0.000    0.032    0.016 _ops.py:1(<module>)
#       140    0.004    0.000    0.031    0.000 _dtype.py:342(_name_get)
#         1    0.000    0.000    0.031    0.031 _linprog_ip.py:1(<module>)
#        86    0.004    0.000    0.031    0.000 conflict.py:56(ordering)
#         1    0.000    0.000    0.031    0.031 slice.py:1(<module>)
#     21489    0.030    0.000    0.031    0.000 {built-in method builtins.issubclass}
#      3283    0.002    0.000    0.031    0.000 _ops.py:1160(<genexpr>)
#         1    0.000    0.000    0.031    0.031 minimize_trustregion_constr.py:1(<module>)
#       398    0.005    0.000    0.031    0.000 _util.py:511(getfullargspec_no_self)
#         1    0.000    0.000    0.031    0.031 torchbind.py:1(<module>)
#         2    0.000    0.000    0.031    0.015 quantization_mappings.py:1(<module>)
#         1    0.000    0.000    0.030    0.030 message.py:1(<module>)
#         1    0.000    0.000    0.030    0.030 von_mises.py:1(<module>)
#       228    0.011    0.000    0.030    0.000 __init__.py:355(namedtuple)
#        37    0.029    0.001    0.030    0.001 _function_base_impl.py:5289(delete)
#        34    0.000    0.000    0.030    0.001 core.py:59(_)
#       324    0.000    0.000    0.030    0.000 <frozen importlib._bootstrap_external>:164(_path_isdir)
#         1    0.000    0.000    0.030    0.030 matrixbase.py:1(<module>)
#         1    0.000    0.000    0.030    0.030 matexpr.py:1(<module>)
#      2582    0.010    0.000    0.030    0.000 <frozen importlib._bootstrap_external>:802(spec_from_file_location)
#         1    0.000    0.000    0.030    0.030 torchbind.py:30(__init__)
#      1140    0.029    0.000    0.029    0.000 {built-in method torch._C._jit_get_operation}
#      1819    0.002    0.000    0.029    0.000 _docscrape.py:573(dedent_lines)
#        18    0.000    0.000    0.029    0.002 frame.py:5658(rename)
#         1    0.000    0.000    0.029    0.029 _twodim_base_impl.py:1(<module>)
#        18    0.000    0.000    0.029    0.002 generic.py:1073(_rename)
#  8349/217    0.013    0.000    0.028    0.000 copy.py:118(deepcopy)
#         9    0.000    0.000    0.028    0.003 _typing.py:1(<module>)
#      4904    0.002    0.000    0.028    0.000 <frozen abc>:117(__instancecheck__)
#         3    0.000    0.000    0.028    0.009 config.py:1(<module>)
#         1    0.000    0.000    0.028    0.028 _linprog_util.py:1(<module>)
#         2    0.000    0.000    0.027    0.014 datetimelike.py:1(<module>)
#       133    0.004    0.000    0.027    0.000 enum.py:528(__new__)
#      5715    0.025    0.000    0.027    0.000 <frozen importlib._bootstrap>:645(parent)
#       108    0.001    0.000    0.027    0.000 dataclasses.py:638(_frozen_get_del_attr)
#         1    0.000    0.000    0.027    0.027 _jit_internal.py:1(<module>)
#   442/217    0.003    0.000    0.027    0.000 copy.py:217(_deepcopy_dict)
#      4788    0.010    0.000    0.027    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#         3    0.001    0.000    0.027    0.009 series.py:1(<module>)
#         1    0.000    0.000    0.027    0.027 _mgc.py:1(<module>)
#         2    0.000    0.000    0.027    0.013 pickle.py:1(<module>)
#         1    0.000    0.000    0.027    0.027 _lazy_graph_module.py:1(<module>)
#         1    0.000    0.000    0.027    0.027 intersection.py:1(<module>)
#       110    0.000    0.000    0.027    0.000 numerictypes.py:475(issubdtype)
#       113    0.001    0.000    0.027    0.000 fake_impl.py:88(construct_meta_kernel)
#         6    0.001    0.000    0.027    0.004 __init__.py:331(_compile_template)
#        26    0.000    0.000    0.027    0.001 managers.py:2283(<lambda>)
#        13    0.000    0.000    0.027    0.002 blocks.py:227(_consolidate_key)
#       140    0.000    0.000    0.027    0.000 _dtype.py:326(_name_includes_bit_suffix)
#       220    0.000    0.000    0.027    0.000 numerictypes.py:293(issubclass_)
#        15    0.027    0.002    0.027    0.002 {built-in method torch.square}
#      7119    0.017    0.000    0.027    0.000 <frozen importlib._bootstrap>:372(release)
#         1    0.000    0.000    0.026    0.026 _remove_redundancy.py:1(<module>)
#         1    0.000    0.000    0.026    0.026 net_min_base.py:1(<module>)
#      6054    0.009    0.000    0.026    0.000 typing.py:1546(__getitem__)
#         1    0.000    0.000    0.026    0.026 algorithms.py:1(<module>)
#         1    0.000    0.000    0.026    0.026 platform.py:446(win32_ver)
#         1    0.000    0.000    0.026    0.026 platform.py:384(_win32_ver)
#         2    0.000    0.000    0.026    0.013 core.py:198(read_style_directory)
#      4904    0.022    0.000    0.026    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.026    0.026 multiarray.py:1(<module>)
#         1    0.001    0.001    0.026    0.026 dataframes.py:1(<module>)
#         4    0.000    0.000    0.026    0.006 graph.py:1(<module>)
#         6    0.000    0.000    0.026    0.004 _docscrape.py:626(__init__)
#       267    0.001    0.000    0.026    0.000 _meta_registrations.py:55(wrapper)
#         1    0.000    0.000    0.026    0.026 cm.py:1(<module>)
#         1    0.000    0.000    0.025    0.025 graph_module.py:1(<module>)
#        23    0.000    0.000    0.025    0.001 _support_alternative_backends.py:46(wrapper)
#         1    0.000    0.000    0.025    0.025 interpolative.py:1(<module>)
#         6    0.025    0.004    0.025    0.004 _parser.py:996(parse_template)
#       152    0.001    0.000    0.025    0.000 base.py:5180(_get_engine_target)
#    107055    0.025    0.000    0.025    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.025    0.025 dynamic_shapes.py:1(<module>)
#         1    0.000    0.000    0.025    0.025 ssl.py:1(<module>)
#      1488    0.007    0.000    0.025    0.000 typing_extensions.py:3228(_collect_parameters)
#       216    0.001    0.000    0.025    0.000 _docscrape.py:366(_parse_summary)
#         6    0.000    0.000    0.025    0.004 rnn.py:1(<module>)
#       350    0.001    0.000    0.025    0.000 typing.py:747(Optional)
#         1    0.000    0.000    0.024    0.024 products.py:1(<module>)
#      5923    0.003    0.000    0.024    0.000 conflict.py:19(ambiguous)
#         1    0.000    0.000    0.024    0.024 power.py:1(<module>)
#         1    0.000    0.000    0.024    0.024 geo.py:1(<module>)
#     76398    0.024    0.000    0.024    0.000 {method 'endswith' of 'str' objects}
#     10376    0.024    0.000    0.024    0.000 {method 'search' of 're.Pattern' objects}
#         1    0.000    0.000    0.024    0.024 descriptors.py:1(<module>)
#      3159    0.024    0.000    0.024    0.000 {built-in method torch._C._dispatch_has_kernel_for_dispatch_key}
#         1    0.000    0.000    0.024    0.024 simplify.py:1(<module>)
#        86    0.022    0.000    0.024    0.000 cast.py:123(maybe_convert_platform)
#      3174    0.010    0.000    0.023    0.000 typing.py:175(_type_check)
#        18    0.000    0.000    0.023    0.001 base.py:6566(_transform_index)
#         1    0.000    0.000    0.023    0.023 reusable_executor.py:1(<module>)
#        33    0.000    0.000    0.023    0.001 arrayprint.py:1061(<genexpr>)
#        33    0.000    0.000    0.023    0.001 arrayprint.py:1056(<genexpr>)
#        54    0.023    0.000    0.023    0.000 {built-in method numpy._core._multiarray_umath.dragon4_positional}
#         2    0.000    0.000    0.023    0.012 conv_fused.py:1(<module>)
#       120    0.006    0.000    0.023    0.000 common.py:538(is_string_dtype)
#     12694    0.005    0.000    0.023    0.000 conflict.py:43(edge)
#         1    0.000    0.000    0.023    0.023 autograd_function.py:741(__init__)
#         1    0.000    0.000    0.022    0.022 rnn.py:1165(GRU)
#        27    0.000    0.000    0.022    0.001 managers.py:317(apply)
#       228    0.001    0.000    0.022    0.000 function.py:164(__init__)
#         1    0.000    0.000    0.022    0.022 rng_prims.py:318(__init__)
#       533    0.022    0.000    0.022    0.000 {built-in method builtins.dir}
#         1    0.000    0.000    0.022    0.022 process_executor.py:1(<module>)
#         1    0.000    0.000    0.022    0.022 windows_events.py:1(<module>)
#       167    0.018    0.000    0.022    0.000 {built-in method _io.open}
#        32    0.022    0.001    0.022    0.001 {built-in method torch.dot}
#         6    0.000    0.000    0.022    0.004 generic.py:6684(copy)
#         1    0.000    0.000    0.022    0.022 _discrete_distns.py:1(<module>)
#         1    0.000    0.000    0.022    0.022 hashlib.py:1(<module>)
#        52    0.000    0.000    0.022    0.000 blocks.py:816(copy)
#         1    0.000    0.000    0.022    0.022 _decorator.py:1(<module>)
#         6    0.000    0.000    0.022    0.004 conv.py:1(<module>)
#         1    0.000    0.000    0.022    0.022 Image.py:1(<module>)
#         2    0.000    0.000    0.022    0.011 frame.py:6261(reset_index)
#        25    0.021    0.001    0.021    0.001 {method 'reset' of '_contextvars.ContextVar' objects}
#        11    0.000    0.000    0.021    0.002 _ufunc_config.py:464(__exit__)
#         1    0.000    0.000    0.021    0.021 offsetbox.py:1(<module>)
#       131    0.002    0.000    0.021    0.000 _distn_infrastructure.py:749(_construct_argparser)
#       131    0.001    0.000    0.021    0.000 _distn_infrastructure.py:735(_attach_argparser_methods)
#        30    0.021    0.001    0.021    0.001 {built-in method torch.squeeze}
#        17    0.000    0.000    0.021    0.001 frame.py:5800(pop)
#        17    0.000    0.000    0.021    0.001 generic.py:949(pop)
#       531    0.003    0.000    0.021    0.000 <frozen abc>:105(__new__)
#         1    0.000    0.000    0.021    0.021 rnn.py:800(LSTM)
#      9191    0.011    0.000    0.021    0.000 typing.py:1215(__setattr__)
#         1    0.000    0.000    0.020    0.020 summations.py:1(<module>)
#       200    0.000    0.000    0.020    0.000 pyplot.py:175(_copy_docstring_and_deprecators)
#       110    0.001    0.000    0.020    0.000 _distn_infrastructure.py:1923(_attach_methods)
#       306    0.020    0.000    0.020    0.000 {method 'sort' of 'list' objects}
#      5923    0.010    0.000    0.020    0.000 conflict.py:12(consistent)
#         1    0.000    0.000    0.020    0.020 matmul.py:1(<module>)
#         1    0.000    0.000    0.020    0.020 compile_time_profiler.py:1(<module>)
#         1    0.000    0.000    0.020    0.020 axis.py:1(<module>)
#      2900    0.002    0.000    0.020    0.000 <frozen importlib._bootstrap_external>:185(_path_abspath)
#         4    0.000    0.000    0.020    0.005 basic.py:1(<module>)
#         1    0.000    0.000    0.019    0.019 rnn.py:470(RNN)
#     15502    0.012    0.000    0.019    0.000 conflict.py:7(supercedes)
#        21    0.000    0.000    0.019    0.001 _distn_infrastructure.py:3319(__init__)
#        17    0.000    0.000    0.019    0.001 generic.py:4499(__delitem__)
#       270    0.002    0.000    0.019    0.000 _decorators.py:363(decorator)
#        50    0.019    0.000    0.019    0.000 {method 'squeeze' of 'torch._C.TensorBase' objects}
# 9251/2824    0.013    0.000    0.019    0.000 {built-in method builtins.any}
#        17    0.000    0.000    0.019    0.001 managers.py:1453(idelete)
#       120    0.006    0.000    0.019    0.000 take.py:564(_take_preprocess_indexer_and_fill_value)
# ...
#         1    0.000    0.000    0.000    0.000 hyperexpand.py:1140(MeijerShiftC)
#         1    0.000    0.000    0.000    0.000 hyperexpand.py:1151(MeijerShiftD)
#         1    0.000    0.000    0.000    0.000 hyperexpand.py:1298(MeijerUnShiftD)
#         1    0.000    0.000    0.000    0.000 diophantine.py:918(InhomogeneousGeneralQuadratic)
#         1    0.000    0.000    0.000    0.000 diophantine.py:938(HomogeneousGeneralQuadratic)
#         1    0.000    0.000    0.000    0.000 systems.py:37(ODENonlinearError)
#         1    0.000    0.000    0.000    0.000 base.py:1132(MetaEstimatorMixin)
#         1    0.000    0.000    0.000    0.000 process.py:648(BrokenProcessPool)
#         1    0.000    0.000    0.000    0.000 process.py:146(_WorkItem)
#         1    0.000    0.000    0.000    0.000 process_executor.py:1021(LokyRecursionError)
#         1    0.000    0.000    0.000    0.000 compressor.py:194(__init__)
#         1    0.000    0.000    0.000    0.000 deprecation.py:306(_deprecated_parameter_class)
#         1    0.000    0.000    0.000    0.000 rcsetup.py:375(validate_fontsize_None)
#         1    0.000    0.000    0.000    0.000 bezier.py:25(NonIntersectingPathException)
#         1    0.000    0.000    0.000    0.000 ticker.py:1124(LogFormatterSciNotation)
#         1    0.000    0.000    0.000    0.000 exceptions.py:20(_ExceptionWordUnicodeSet)
#         1    0.000    0.000    0.000    0.000 exceptions.py:33(UnknownConstraint)
#         1    0.000    0.000    0.000    0.000 exceptions.py:40(UnknownEditVariable)
#         1    0.000    0.000    0.000    0.000 backend_tools.py:622(ConfigureSubplotsBase)
#         1    0.000    0.000    0.000    0.000 cp1251.py:28(StreamReader)
#         1    0.000    0.000    0.000    0.000 cp1251.py:21(IncrementalDecoder)
#         1    0.000    0.000    0.000    0.000 patches.py:3529(CurveB)
#         1    0.000    0.000    0.000    0.000 patches.py:3534(CurveAB)
#         1    0.000    0.000    0.000    0.000 patches.py:3539(CurveFilledA)
#         1    0.000    0.000    0.000    0.000 _mathtext.py:1055(Hbox)
#         1    0.000    0.000    0.000    0.000 _blocking_input.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 units.py:161(Registry)
#         1    0.000    0.000    0.000    0.000 streamplot.py:434(InvalidIndexError)
#         1    0.000    0.000    0.000    0.000 streamplot.py:510(OutOfBounds)
#         1    0.000    0.000    0.000    0.000 legend_handler.py:503(HandlerPathCollection)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.gt}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_native_id}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencodeerrors}
#         1    0.000    0.000    0.000    0.000 copy.py:102(_copy_immutable)
#         1    0.000    0.000    0.000    0.000 contextlib.py:357(__enter__)
#         1    0.000    0.000    0.000    0.000 __init__.py:203(c_longdouble)
#         1    0.000    0.000    0.000    0.000 __init__.py:213(c_longlong)
#         1    0.000    0.000    0.000    0.000 __init__.py:217(c_ulonglong)
#         1    0.000    0.000    0.000    0.000 __init__.py:224(c_ubyte)
#         1    0.000    0.000    0.000    0.000 __init__.py:231(c_byte)
#         1    0.000    0.000    0.000    0.000 __init__.py:236(c_char)
#         1    0.000    0.000    0.000    0.000 __init__.py:247(c_void_p)
#         1    0.000    0.000    0.000    0.000 glob.py:214(_join)
#         1    0.000    0.000    0.000    0.000 _endian.py:35(_swapped_union_meta)
#         1    0.000    0.000    0.000    0.000 threading.py:833(BrokenBarrierError)
#         1    0.000    0.000    0.000    0.000 typing_extensions.py:2098(_EllipsisDummy)
#         1    0.000    0.000    0.000    0.000 shutil.py:73(SpecialFileError)
#         1    0.000    0.000    0.000    0.000 shutil.py:83(RegistryError)
#         1    0.000    0.000    0.000    0.000 random.py:903(seed)
#         1    0.000    0.000    0.000    0.000 exceptions.py:76(VisibleDeprecationWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:87(RankWarning)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:105(_take_dispatcher)
#         1    0.000    0.000    0.000    0.000 pickle.py:84(UnpicklingError)
#         1    0.000    0.000    0.000    0.000 _nbit_base.py:76(_64Bit)
#         1    0.000    0.000    0.000    0.000 _nbit_base.py:81(_32Bit)
#         1    0.000    0.000    0.000    0.000 _nbit_base.py:86(_16Bit)
#         1    0.000    0.000    0.000    0.000 _iotools.py:431(ConverterLockError)
#         1    0.000    0.000    0.000    0.000 _iotools.py:439(ConversionWarning)
#         1    0.000    0.000    0.000    0.000 tarfile.py:276(ReadError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:282(StreamError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:285(HeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:288(EmptyHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:294(EOFHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:297(InvalidHeaderError)
#         1    0.000    0.000    0.000    0.000 tarfile.py:300(SubsequentHeaderError)
#         1    0.000    0.000    0.000    0.000 events.py:734(_RunningLoop)
#         1    0.000    0.000    0.000    0.000 exceptions.py:61(BrokenBarrierError)
#         1    0.000    0.000    0.000    0.000 context.py:17(BufferTooShort)
#         1    0.000    0.000    0.000    0.000 context.py:20(TimeoutError)
#         1    0.000    0.000    0.000    0.000 parse.py:421(_checknetloc)
#         1    0.000    0.000    0.000    0.000 dataframes.py:385(CaptureDataFrame)
#         1    0.000    0.000    0.000    0.000 _typing.py:38(Integer)
#         1    0.000    0.000    0.000    0.000 errors.py:24(MultipartConversionError)
#         1    0.000    0.000    0.000    0.000 errors.py:32(HeaderWriteError)
#         1    0.000    0.000    0.000    0.000 errors.py:45(NoBoundaryInMultipartDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:48(StartBoundaryNotFoundDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:54(FirstHeaderLineIsContinuationDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:57(MisplacedEnvelopeHeaderDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:60(MissingHeaderBodySeparatorDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:65(MultipartInvariantViolationDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:68(InvalidMultipartContentTransferEncodingDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:71(UndecodableBytesDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:74(InvalidBase64PaddingDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:77(InvalidBase64CharactersDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:94(HeaderMissingRequiredValue)
#         1    0.000    0.000    0.000    0.000 errors.py:108(ObsoleteHeaderDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:111(NonASCIILocalPartDefect)
#         1    0.000    0.000    0.000    0.000 errors.py:116(InvalidDateDefect)
#         1    0.000    0.000    0.000    0.000 abc.py:186(FileLoader)
#         1    0.000    0.000    0.000    0.000 __init__.py:17(is_available)
#         1    0.000    0.000    0.000    0.000 _script.py:347(ScriptWarning)
#         1    0.000    0.000    0.000    0.000 frontend.py:178(FrontendTypeError)
#         1    0.000    0.000    0.000    0.000 client.py:1487(NotConnected)
#         1    0.000    0.000    0.000    0.000 client.py:1498(UnknownTransferEncoding)
#         1    0.000    0.000    0.000    0.000 client.py:1501(UnimplementedFileMode)
#         1    0.000    0.000    0.000    0.000 client.py:1518(ImproperConnectionState)
#         1    0.000    0.000    0.000    0.000 client.py:1527(ResponseNotReady)
#         1    0.000    0.000    0.000    0.000 case.py:34(_ShouldStop)
#         1    0.000    0.000    0.000    0.000 mock.py:2170(AsyncMagicMixin)
#         1    0.000    0.000    0.000    0.000 exceptions.py:42(AmbiguousTimeError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:53(NonExistentTimeError)
#         1    0.000    0.000    0.000    0.000 config_init.py:673(register_plotting_backend_cb)
#         1    0.000    0.000    0.000    0.000 __init__.py:11(DeprecatedTzFormatWarning)
#         1    0.000    0.000    0.000    0.000 six.py:382(Module_six_moves_urllib_error)
#         1    0.000    0.000    0.000    0.000 six.py:459(Module_six_moves_urllib_response)
#         1    0.000    0.000    0.000    0.000 six.py:480(Module_six_moves_urllib_robotparser)
#         1    0.000    0.000    0.000    0.000 _parser.py:1608(UnknownTimezoneWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:328(DuplicateLabelError)
#         1    0.000    0.000    0.000    0.000 __init__.py:367(DataError)
#         1    0.000    0.000    0.000    0.000 __init__.py:411(SettingWithCopyError)
#         1    0.000    0.000    0.000    0.000 __init__.py:433(SettingWithCopyWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:742(ValueLabelTypeMismatch)
#         1    0.000    0.000    0.000    0.000 __init__.py:793(NoBufferPresent)
#         1    0.000    0.000    0.000    0.000 __init__.py:799(InvalidComparison)
#         1    0.000    0.000    0.000    0.000 nanops.py:57(set_use_bottleneck)
#         1    0.000    0.000    0.000    0.000 range.py:216(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 pytables.py:401(UnaryOp)
#         1    0.000    0.000    0.000    0.000 _ccallback.py:9(CData)
#         1    0.000    0.000    0.000    0.000 _optimize.py:157(OptimizeWarning)
#         1    0.000    0.000    0.000    0.000 release.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 expr.py:1021(_eval_power)
#         1    0.000    0.000    0.000    0.000 function.py:118(BadArgumentsError)
#         1    0.000    0.000    0.000    0.000 boolalg.py:371(__eq__)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:67(HeuristicGCDFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:71(ModularGCDFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:74(HomomorphismFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:78(IsomorphismFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:82(ExtraneousFactors)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:86(EvaluationFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:90(RefinementFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:94(CoercionFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:98(NotInvertible)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:102(NotReversible)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:106(NotAlgebraic)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:110(DomainError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:114(PolynomialError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:118(UnificationFailed)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:128(GeneratorsError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:132(GeneratorsNeeded)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:147(UnivariatePolynomialError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:177(OptionError)
#         1    0.000    0.000    0.000    0.000 polyerrors.py:181(FlagError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:23(DMDomainError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:28(DMNotAField)
#         1    0.000    0.000    0.000    0.000 exceptions.py:33(DMFormatError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:38(DMNonInvertibleMatrixError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:43(DMRankError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:58(DMValueError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:47(MissingUnityError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:19(NonInvertibleMatrixError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:94(DataDimensionalityWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:108(EfficiencyWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:131(SkipTestWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:140(UndefinedMetricWarning)
#         1    0.000    0.000    0.000    0.000 process_executor.py:1025(BrokenProcessPool)
#         1    0.000    0.000    0.000    0.000 process_executor.py:1046(ShutdownExecutorError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:302(ParseFatalException)
#         1    0.000    0.000    0.000    0.000 exceptions.py:309(ParseSyntaxException)
#         1    0.000    0.000    0.000    0.000 unicode.py:304(CJK)
#         1    0.000    0.000    0.000    0.000 cp1251.py:25(StreamWriter)
#         1    0.000    0.000    0.000    0.000 patches.py:3544(CurveFilledB)
#         1    0.000    0.000    0.000    0.000 patches.py:3549(CurveFilledAB)
#         1    0.000    0.000    0.000    0.000 _mathtext.py:960(DejaVuSerifFontConstants)
#         1    0.000    0.000    0.000    0.000 _mathtext.py:964(DejaVuSansFontConstants)
#         1    0.000    0.000    0.000    0.000 streamplot.py:438(TerminateTrajectory)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy._core._multiarray_umath._set_madvise_hugepage}
#         1    0.000    0.000    0.000    0.000 __init__.py:178(c_ulong)
#         1    0.000    0.000    0.000    0.000 __init__.py:262(c_wchar)
#         1    0.000    0.000    0.000    0.000 shutil.py:80(ReadError)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2584(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 _nbit_base.py:91(_8Bit)
#         1    0.000    0.000    0.000    0.000 context.py:23(AuthenticationError)
#         1    0.000    0.000    0.000    0.000 errors.py:51(CloseBoundaryNotFoundDefect)
#         1    0.000    0.000    0.000    0.000 __init__.py:91(__init__)
#         1    0.000    0.000    0.000    0.000 client.py:1521(CannotSendRequest)
#         1    0.000    0.000    0.000    0.000 _environment.py:1(is_fbcode)
#         1    0.000    0.000    0.000    0.000 _tzpath.py:36(_parse_python_tzpath)
#         1    0.000    0.000    0.000    0.000 six.py:239(exec_module)
#         1    0.000    0.000    0.000    0.000 managers.py:1847(ndim)
#         1    0.000    0.000    0.000    0.000 readers.py:1987(__enter__)
#         1    0.000    0.000    0.000    0.000 _new_distributions.py:93(_median_formula)
#         1    0.000    0.000    0.000    0.000 rationalfield.py:45(__init__)
#         1    0.000    0.000    0.000    0.000 gaussiandomains.py:647(__init__)
#         1    0.000    0.000    0.000    0.000 expressiondomain.py:163(__init__)
#         1    0.000    0.000    0.000    0.000 expressionrawdomain.py:28(__init__)
#         1    0.000    0.000    0.000    0.000 alphabets.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 exceptions.py:119(FitFailedWarning)
#         1    0.000    0.000    0.000    0.000 exceptions.py:148(PositiveSpectrumWarning)
#         1    0.000    0.000    0.000    0.000 _new_distributions.py:96(_mode_formula)
#         1    0.000    0.000    0.000    0.000 integerring.py:51(__init__)
#         1    0.000    0.000    0.000    0.000 gaussiandomains.py:442(__init__)
#       1/0    0.000    0.000    0.000          custom_ops.py:144(inner)
#    2687/0    0.030    0.000    0.000          <frozen importlib._bootstrap>:1349(_find_and_load)
#    2654/0    0.015    0.000    0.000          <frozen importlib._bootstrap>:1304(_find_and_load_unlocked)
#    2361/0    0.010    0.000    0.000          <frozen importlib._bootstrap_external>:989(exec_module)
#    3857/0    0.168    0.000    0.000          {built-in method builtins.exec}
